# %% [markdown]
# # Question Answering Receiver Evaluation

# %%
import json
import tqdm
import sys

sys.path.append('../natural-questions/')
import text_utils

# %% [markdown]
# ## Discussion Points
#
# 1. The document_text **does still contain** HTML elements, but only those that are used in identifying long_answer spans (H-tags, p-tags, table-tags, list-tags). How do we want to handle this?
#     - Implications on search
#     - Implication on the reader
#
#
#
# 2. What is ideal format that you want the data in to be compatible with SQuAD training? How to format multiple short answers for a question?

# %% [markdown]
# ## Load Data

# %% [markdown]
# #### Train Set

# %%
jsonfilename = "../data/v1.0-simplified_simplified-nq-train.jsonl"

data = []
with open(jsonfilename, 'rb') as f:
    for line in tqdm.tqdm(f):
        data.append(json.loads(line.decode('utf-8')))
# Out:
# 307373it [04:08, 1236.59it/s]

# %%
len(data)
# Out:
# 307373

# %% [markdown]
# #### Dev Set

# %%
jsonfilename = "../data/v1.0-simplified_nq-dev-all.jsonl"

dev_data = []
with open(jsonfilename, 'rb') as f:
    for line in tqdm.tqdm(f):
        dev_data.append(json.loads(line.decode('utf-8')))
# Out:
# 7830it [03:00, 43.33it/s]

# %%
len(dev_data)
# Out:
# 7830

# %% [markdown]
# ## Explore Train Data

# %% [markdown]
# ### General Exploration

# %%
example = data[11]

# %%
example.keys()
# Out:
# dict_keys(['document_text', 'long_answer_candidates', 'question_text', 'annotations', 'document_url', 'example_id'])

# %%
example['document_text']
# Out:
# 'Bangko Sentral ng Pilipinas - wikipedia <H1> Bangko Sentral ng Pilipinas </H1> <P> </P> <Table> Bangko Sentral ng Pilipinas <Tr> <Td_colspan="2"> <Table> <Tr> <Td> Logo </Td> <Td> The BSP complex in Manila </Td> </Tr> </Table> </Td> </Tr> <Tr> <Th> Headquarters </Th> <Td> Manila , Philippines </Td> </Tr> <Tr> <Th> Coordinates </Th> <Td> 14 ° 33 ′ 39 \'\' N 120 ° 59 ′ 18 \'\' E \ufeff / \ufeff 14.56083 ° N 120.98833 ° E \ufeff / 14.56083 ; 120.98833 Coordinates : 14 ° 33 ′ 39 \'\' N 120 ° 59 ′ 18 \'\' E \ufeff / \ufeff 14.56083 ° N 120.98833 ° E \ufeff / 14.56083 ; 120.98833 </Td> </Tr> <Tr> <Th> Established </Th> <Td> January 3 , 1949 ; 69 years ago ( January 3 , 1949 ) ( original , bankrupt ) July 3 , 1993 ; 25 years ago ( July 3 , 1993 ) ( re-established due to the New Central Bank Act ) </Td> </Tr> <Tr> <Th> Governor </Th> <Td> Nestor Espenilla , Jr . </Td> </Tr> <Tr> <Th> Central bank of </Th> <Td> Philippines </Td> </Tr> <Tr> <Th> Currency </Th> <Td> Philippine peso PHP ( ISO 4217 ) </Td> </Tr> <Tr> <Th> Reserves </Th> <Td> US $81 billion </Td> </Tr> <Tr> <Th> Bank rate </Th> <Td> 3.50 % </Td> </Tr> <Tr> <Th> Website </Th> <Td> www.bsp.gov.ph </Td> </Tr> </Table> <P> The Bangko Sentral ng Pilipinas ( lit . Central Bank of the Philippines ; commonly abbreviated as BSP in both Filipino and English ) is the central bank of the Philippines . It was established on 3 July 1993 , pursuant to the provision of Republic Act 7653 or the New Central Bank Act of 1993 . </P> <H2> Contents </H2> <Ul> <Li> 1 History <Ul> <Li> 1.1 American era and World War II </Li> <Li> 1.2 Third Republic and martial law </Li> <Li> 1.3 Present </Li> </Ul> </Li> <Li> 2 Roles and responsibilities </Li> <Li> 3 Organization of the Bangko Sentral </Li> <Li> 4 Convertible currencies </Li> <Li> 5 Microfinance and financial inclusion </Li> <Li> 6 Anti-money laundering </Li> <Li> 7 Governors </Li> <Li> 8 Museum </Li> <Li> 9 Security Plant Complex </Li> <Li> 10 References </Li> <Li> 11 Publications </Li> <Li> 12 External links </Li> </Ul> <H2> History ( edit ) </H2> <H3> American era and World War ii ( edit ) </H3> <Table> <Tr> <Td> </Td> <Td> This section needs additional citations for verification . Please help improve this article by adding citations to reliable sources . Unsourced material may be challenged and removed . ( December 2017 ) ( Learn how and when to remove this template message ) </Td> </Tr> </Table> <P> In 1900 , the First Philippine Commission passed Act No. 52 , which placed all banks under the Bureau of the Treasury and authorizing the Insular Treasurer to supervise and examine banks and all banking activity . In 1929 , the Department of Finance , through the Bureau of Banking , took over bank supervision . </P> <P> By 1933 , a group of Filipinos had conceptualised a central bank for the Philippine Islands . It came up with the rudiments of a bill for the establishment of a central bank after a careful study of the economic provisions of the Hare -- Hawes -- Cutting Act , which would grant Philippine independence after 12 years , but reserving military and naval bases for the United States and imposing tariffs and quotas on Philippine exports . However , the Hare -- Hawes -- Cutting Act would be rejected by the Senate of the Philippines at the urging of Commonwealth President Manuel L. Quezon . This Senate then advocated a new bill that won United States President Franklin D. Roosevelt \'s support , this would be the Tydings -- McDuffie Act , which would grant Philippine independence on July 4 , 1946 . </P> <P> Under the Commonwealth , discussions continued regarding the idea of a Philippine central bank that would promote price stability and economic growth . The country \'s monetary system then was administered by the Department of Finance and the National Treasury , and the Philippine piso was on the exchange standard using the United States dollar , which was backed by 100 percent gold reserve , as the standard currency . </P> <P> As requ ...

# %%
example['long_answer_candidates']
# Out:
# [{'start_token': 14, 'top_level': True, 'end_token': 227},
#  {'start_token': 19, 'top_level': False, 'end_token': 37},
#  {'start_token': 21, 'top_level': False, 'end_token': 35},
#  {'start_token': 22, 'top_level': False, 'end_token': 34},
#  {'start_token': 37, 'top_level': False, 'end_token': 47},
#  {'start_token': 47, 'top_level': False, 'end_token': 112},
#  {'start_token': 112, 'top_level': False, 'end_token': 162},
#  {'start_token': 162, 'top_level': False, 'end_token': 174},
#  {'start_token': 174, 'top_level': False, 'end_token': 184},
#  {'start_token': 184, 'top_level': False, 'end_token': 198},
#  {'start_token': 198, 'top_level': False, 'end_token': 208},
#  {'start_token': 208, 'top_level': False, 'end_token': 218},
#  {'start_token': 218, 'top_level': False, 'end_token': 226},
#  {'start_token': 227, 'top_level': True, 'end_token': 286},
#  {'start_token': 393, 'top_level': True, 'end_token': 444},
#  {'start_token': 394, 'top_level': False, 'end_token': 443},
#  {'start_token': 444, 'top_level': True, 'end_token': 502},
#  {'start_token': 502, 'top_level': True, 'end_token': 648},
#  {'start_token': 648, 'top_level': True, 'end_token': 720},
#  {'start_token': 720, 'top_level': True, 'end_token': 816},
#  {'start_token': 826, 'top_level': True, 'end_token': 932},
#  {'start_token': 932, 'top_level': True, 'end_token': 1044},
#  {'start_token': 1044, 'top_level': True, 'end_token': 1171},
#  {'start_token': 1171, 'top_level': True, 'end_token': 1253},
#  {'start_token': 1259, 'top_level': True, 'end_token': 1375},
#  {'start_token': 1381, 'top_level': True, 'end_token': 1433},
#  {'start_token': 1433, 'top_level': True, 'end_token': 1535},
#  {'start_token': 1543, 'top_level': True, 'end_token': 1563},
#  {'start_token': 1563, 'top_level': True, 'end_token': 1768},
#  {'start_token': 1564, 'top_level': False, 'end_token': 1591},
#  {'start_token': 1591, 'top_level': False, 'end_token': 1634},
#  {'start_token': 1634, 'top_level': False, 'end_token': 1655},
#  {'start_token': 1655, 'top_level': False, 'end_token': 1674},
#  {'start_token': 1674, 'top_level': False, 'end_token': 1710},
#  {'start_token': 1710, 'top_level': False, 'end_token': 1744},
#  {'start_token': 1744, 'top_level': False, 'end_token': 1767},
#  {'start_token': 1778, 'top_level': True, 'end_token': 1789},
#  {'start_token': 1789, 'top_level': True, 'end_token': 1912},
#  {'start_token': 1790, 'top_level': False, 'end_token': 1820},
#  {'start_token': 1820, 'top_level': False, 'end_token': 1864},
#  {'start_token': 1864, 'top_level': False, 'end_token': 1890},
#  {'start_token': 1890, 'top_level': False, 'end_token': 1911},
#  {'start_token': 1912, 'top_level': True, 'end_token': 2016},
#  {'start_token': 2016, 'top_level': True, 'end_token': 2027},
#  {'start_token': 2027, 'top_level': True, 'end_token': 2089},
#  {'start_token': 2028, 'top_level': False, 'end_token': 2043},
#  {'start_token': 2043, 'top_level': False, 'end_token': 2055},
#  {'start_token': 2055, 'top_level': False, 'end_token': 2063},
#  {'start_token': 2063, 'top_level': False, 'end_token': 2072},
#  {'start_token': 2072, 'top_level': False, 'end_token': 2078},
#  {'start_token': 2078, 'top_level': False, 'end_token': 2083},
#  {'start_token': 2083, 'top_level': False, 'end_token': 2088},
#  {'start_token': 2096, 'top_level': True, 'end_token': 2121},
#  {'start_token': 2121, 'top_level': True, 'end_token': 2294},
#  {'start_token': 2122, 'top_level': False, 'end_token': 2293},
#  {'start_token': 2124, 'top_level': False, 'end_token': 2189},
#  {'start_token': 2125, 'top_level': False, 'end_token': 2132},
#  {'start_token': 2132, 'top_level': False, 'end_token': 2139},
#  {'start_token': 2139, 'top_level': False, 'end_token': 2146},
#  {'start_token': 2146, 'top_level': False, 'end_token': 2153},
#  {'start_token': 2153, 'top_level': False, 'end_token': 2160},
#  {'start_token': 2160, 'top_level': False, 'end_token': 2167},
#  {'start_token': 2167, 'top_level': False, 'end_token': 2174},
#  {'start_token': 2174, 'top_level': False, 'end_token': 2180},
#  {'start_token': 2180, 'top_level': False, 'end_token': 2188},
#  {'start_token': 2193, 'top_level': False, 'end_token': 2251},
#  {'start_token': 2194, 'top_level': False, 'end_token': 2201},
#  {'start_token': 2201, 'top_level': False, 'end_token': 2208},
#  {'start_token': 2208, 'top_level': False, 'end_token': 2215},
#  {'start_token': 2215, 'top_level': False, 'end_token': 2222},
#  {'start_token': 2222, 'top_level': False, 'end_token': 2229},
#  {'start_token': 2229, 'top_level': False, 'end_token': 2236},
#  {'start_token': 2236, 'top_level': False, 'end_token': 2243},
#  {'start_token': 2243, 'top_level': False, 'end_token': 2250},
#  {'start_token': 2255, 'top_level': False, 'end_token': 2289},
#  {'start_token': 2256, 'top_level': False, 'end_token': 2263},
#  {'start_token': 2263, 'top_level': False, 'end_token': 2271},
#  {'start_token': 2271, 'top_level': False, 'end_token': 2280},
#  {'start_token': 2280, 'top_level': False, 'end_token': 2288},
#  {'start_token': 2303, 'top_level': True, 'end_token': 2378},
#  {'start_token': 2378, 'top_level': True, 'end_token': 2421},
#  {'start_token': 2379, 'top_level': False, 'end_token': 2389},
#  {'start_token': 2389, 'top_level': False, 'end_token': 2405},
#  {'start_token': 2405, 'top_level': False, 'end_token': 2420},
#  {'start_token': 2421, 'top_level': True, 'end_token': 2477},
#  {'start_token': 2484, 'top_level': True, 'end_token': 2618},
#  {'start_token': 2618, 'top_level': True, 'end_token': 2673},
#  {'start_token': 2695, 'top_level': True, 'end_token': 2761},
#  {'start_token': 2761, 'top_level': True, 'end_token': 2814},
#  {'start_token': 2814, 'top_level': True, 'end_token': 2874},
#  {'start_token': 2874, 'top_level': True, 'end_token': 2925},
#  {'start_token': 2933, 'top_level': True, 'end_token': 3036},
#  {'start_token': 3036, 'top_level': True, 'end_token': 3067},
#  {'start_token': 3067, 'top_level': True, 'end_token': 3100},
#  {'start_token': 3100, 'top_level': True, 'end_token': 3113},
#  {'start_token': 3101, 'top_level': False, 'end_token': 3107},
#  {'start_token': 3107, 'top_level': False, 'end_token': 3112}]

# %%
example['question_text']
# Out:
# 'bangko sentral ng pilipinas (central bank of the philippines)'

# %%
example['annotations']
# Out:
# [{'yes_no_answer': 'NONE',
#   'long_answer': {'start_token': -1, 'candidate_index': -1, 'end_token': -1},
#   'short_answers': [],
#   'annotation_id': 16194740675034335824}]

# %%
example['document_url']
# Out:
# 'https://en.wikipedia.org//w/index.php?title=Bangko_Sentral_ng_Pilipinas&amp;oldid=856719956'

# %%
example['example_id']
# Out:
# 3008113339755798094

# %% [markdown]
# ### The data isn't consistently good.

# %%
# example of a non-sensical question
ex11 = data[11]
print(ex11['question_text'])
# Out:
# bangko sentral ng pilipinas (central bank of the philippines)

# %%
# example of typo in question
ex1 = data[1]
print(ex1['question_text'])
# Out:
# how i.met your mother who is the mother

# %% [markdown]
# ### The "clean" full text still contains some HTML tags (tags used for long_answer designation)

# %%
ex1['document_text']
# Out:
# 'The Mother ( How I Met Your Mother ) - wikipedia <H1> The Mother ( How I Met Your Mother ) </H1> Jump to : navigation , search <Table> <Tr> <Th_colspan="2"> Tracy McConnell </Th> </Tr> <Tr> <Td_colspan="2"> How I Met Your Mother character </Td> </Tr> <Tr> <Td_colspan="2"> The Mother appearing in `` The Locket \'\' </Td> </Tr> <Tr> <Th> First appearance </Th> <Td> `` Lucky Penny ( unseen ) \'\' `` Something New \'\' ( seen ) </Td> </Tr> <Tr> <Th> Last appearance </Th> <Td> `` Last Forever \'\' </Td> </Tr> <Tr> <Th> Created by </Th> <Td> Carter Bays Craig Thomas </Td> </Tr> <Tr> <Th> Portrayed by </Th> <Td> Cristin Milioti </Td> </Tr> <Tr> <Th_colspan="2"> Information </Th> </Tr> <Tr> <Th> Aliases </Th> <Td> The Mother </Td> </Tr> <Tr> <Th> Gender </Th> <Td> Female </Td> </Tr> <Tr> <Th> Spouse ( s ) </Th> <Td> Ted Mosby </Td> </Tr> <Tr> <Th> Significant other ( s ) </Th> <Td> Max ( deceased former boyfriend ) Louis ( ex-boyfriend ) </Td> </Tr> <Tr> <Th> Children </Th> <Td> Penny Mosby ( daughter , born in 2015 , played by Lyndsy Fonseca ) Luke Mosby ( son , born in 2017 , played by David Henrie ) </Td> </Tr> <Tr> <Th> Nationality </Th> <Td> American </Td> </Tr> </Table> <P> Tracy McConnell , better known as `` The Mother \'\' , is the title character from the CBS television sitcom How I Met Your Mother . The show , narrated by Future Ted , tells the story of how Ted Mosby met The Mother . Tracy McConnell appears in 8 episodes from `` Lucky Penny \'\' to `` The Time Travelers \'\' as an unseen character ; she was first seen fully in `` Something New \'\' and was promoted to a main character in season 9 . The Mother is played by Cristin Milioti . </P> <P> The story of how Ted met The Mother is the framing device behind the series ; many facts about her are revealed throughout the series , including the fact that Ted once unwittingly owned her umbrella before accidentally leaving it behind in her apartment . Ted and The Mother meet at the Farhampton train station following Barney Stinson and Robin Scherbatsky \'s wedding ; this scene is shown in `` Last Forever \'\' , the series finale . The Mother \'s death from an unspecified terminal illness in 2024 , also revealed in the series finale , received a mixed reaction from fans . </P> <P> An alternate ending was released in the ninth season DVD . In the alternate ending , Tracy Mosby is still living when Ted is telling the story in 2030 . In the video , future Ted is heard saying , `` ... When I think how lucky I am to wake up next to your mom every morning , I ca n\'t help but be amazed how easy it all really was ... \'\' , indirectly stating that The Mother is alive . The video ends right after the train passes at Farhampton station and credits start rolling , implying that Ted never went back to Robin as he lived a successful married life with Tracy Mosby . </P> <P> </P> <H2> Contents </H2> ( hide ) <Ul> <Li> 1 Casting </Li> <Li> 2 Character history <Ul> <Li> 2.1 Name </Li> </Ul> </Li> <Li> 3 Death </Li> <Li> 4 Notes </Li> <Li> 5 References </Li> </Ul> <P> </P> <H2> Casting ( edit ) </H2> <P> During its first eight seasons , the successful sitcom How I Met Your Mother often hinted at the unseen character of The Mother . Well - known actresses often made guest appearances on the show . Many fans expected that another would play one of the most - wanted roles in Hollywood , but creators Carter Bays and Craig Thomas wanted an unknown . Using Anne Hathaway and Amy Adams as examples , Thomas said that `` We did n\'t want it to be a big famous star because we did n\'t want the wider audience to have associations with whatever actress this would be ... The whole idea is that Ted \'s never seen this woman before , so it better feel that way to the audience \'\' , similar to how Cobie Smulders being cast as Robin Scherbatsky had `` kept the show alive \'\' when it began . Bays and Thomas also did not want a large casting call . </P> <P> They chose Cristin Milioti after seeing her on 30 Ro ...

# %% [markdown]
# ### Questions can have multiple short answers

# %%
ex45 = data[45]

# %%
ex45['annotations']
# Out:
# [{'yes_no_answer': 'NONE',
#   'long_answer': {'start_token': 22, 'candidate_index': 0, 'end_token': 235},
#   'short_answers': [{'start_token': 204, 'end_token': 210},
#    {'start_token': 211, 'end_token': 217},
#    {'start_token': 218, 'end_token': 224},
#    {'start_token': 226, 'end_token': 233}],
#   'annotation_id': 12271164458330946017}]

# %%
def get_answers_from_span(example):
    '''
    Use the long and short answer spans from a NQ json record to retreive
    and print the corresponding long/short answer text.
    
    Args:
        example - a jsonl record from NQ simplified dataset
    
    '''
    print('Question:', example['question_text'], '\n')
    
    long_answer_span = example['annotations'][0]['long_answer']
    
    print('Long Answer:', " ".join(example['document_text'].split(" ")\
                                    [long_answer_span['start_token']:long_answer_span['end_token']]), '\n')
    
    for i, short_answer_span in enumerate(example['annotations'][0]['short_answers']):
    
        print(f'Answer {i}:', " ".join(example['document_text'].split(" ")\
                                        [short_answer_span['start_token']:short_answer_span['end_token']]))

# %%
get_answers_from_span(ex45)
# Out:
# Question: where are the upcoming olympics to be held
#
# Long Answer: <P> This is a list of host cities of the Olympic Games , both summer and winter , since the modern Olympics began in 1896 . Since then , summer games have usually -- but not always -- celebrated a four - year period known as an Olympiad . There have been 28 Summer Olympic Games held in 24 cities , and 23 Winter Olympic Games held in 20 cities . In addition , three summer and two winter editions of the Games were scheduled to take place but later cancelled due to war : Berlin ( summer ) in 1916 ; Tokyo / Helsinki ( summer ) and Sapporo / Garmisch - Partenkirchen ( winter ) in 1940 ; and London ( summer ) and Cortina d'Ampezzo , Italy ( winter ) in 1944 . The 1906 Summer Olympics were officially sanctioned and held in Athens . However , in 1949 , the International Olympic Committee ( IOC ) , decided to unrecognize the 1906 Games . Four cities have been chosen by the IOC to host upcoming Olympic Games : Tokyo for the 2020 Summer Olympics , Beijing for the 2022 Winter Olympics , Paris for the 2024 Summer Olympics , and Los Angeles for the 2028 Summer Olympics . </P>
#
# Answer 0: Tokyo for the 2020 Summer Olympics
# Answer 1: Beijing for the 2022 Winter Olympics
# Answer 2: Paris for the 2024 Summer Olympics
# Answer 3: Los Angeles for the 2028 Summer Olympics

# %% [markdown]
# ## Explore Dev Data

# %% [markdown]
# #### General

# %%
dev_example = dev_data[0]

# %%
dev_example.keys()
# Out:
# dict_keys(['annotations', 'document_html', 'document_title', 'document_tokens', 'document_url', 'example_id', 'long_answer_candidates', 'question_text', 'question_tokens'])

# %% [markdown]
# #### Google's provided simplify function works

# %%
simplified_dev_example = text_utils.simplify_nq_example(dev_example)

# %%
simplified_dev_example.keys()
# Out:
# dict_keys(['question_text', 'example_id', 'document_url', 'document_text', 'long_answer_candidates', 'annotations'])

# %% [markdown]
# #### Dev data has 5 annotations

# %%
simplified_dev_example['annotations']
# Out:
# [{'annotation_id': 13591449469826568799,
#   'long_answer': {'candidate_index': 92, 'end_token': 925, 'start_token': 808},
#   'short_answers': [{'end_token': 837, 'start_token': 816}],
#   'yes_no_answer': 'NONE'},
#  {'annotation_id': 6237931520544082939,
#   'long_answer': {'candidate_index': 92, 'end_token': 925, 'start_token': 808},
#   'short_answers': [{'end_token': 819, 'start_token': 816}],
#   'yes_no_answer': 'NONE'},
#  {'annotation_id': 12127791536449879527,
#   'long_answer': {'candidate_index': 92, 'end_token': 925, 'start_token': 808},
#   'short_answers': [],
#   'yes_no_answer': 'NONE'},
#  {'annotation_id': 6421980561691125452,
#   'long_answer': {'candidate_index': 92, 'end_token': 925, 'start_token': 808},
#   'short_answers': [{'end_token': 837, 'start_token': 826}],
#   'yes_no_answer': 'NONE'},
#  {'annotation_id': 5015853435362506856,
#   'long_answer': {'candidate_index': 92, 'end_token': 925, 'start_token': 808},
#   'short_answers': [{'end_token': 819, 'start_token': 817}],
#   'yes_no_answer': 'NONE'}]

# %%
text_utils.get_nq_tokens(simplified_dev_example)
# Out:
# ['Therefore',
#  'sign',
#  '-',
#  'wikipedia',
#  '<H1>',
#  'Therefore',
#  'sign',
#  '</H1>',
#  'Jump',
#  'to',
#  ':',
#  'navigation',
#  ',',
#  'search',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  '∴',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  'Therefore',
#  'sign',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'Punctuation',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'apostrophe',
#  '</Td>',
#  '<Td>',
#  "'",
#  "'",
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'brackets',
#  '</Td>',
#  '<Td>',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  ')',
#  '⟨',
#  '⟩',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'colon',
#  '</Td>',
#  '<Td>',
#  ':',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'comma',
#  '</Td>',
#  '<Td>',
#  ',',
#  '،',
#  '、',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'dash',
#  '</Td>',
#  '<Td>',
#  '‒',
#  '--',
#  '--',
#  '―',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'ellipsis',
#  '</Td>',
#  '<Td>',
#  '...',
#  '...',
#  '⋯',
#  '᠁',
#  'ฯ',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'exclamation',
#  'mark',
#  '</Td>',
#  '<Td>',
#  '!',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'full',
#  'stop',
#  ',',
#  'period',
#  '</Td>',
#  '<Td>',
#  '.',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'guillemets',
#  '</Td>',
#  '<Td>',
#  '``',
#  "''",
#  '``',
#  "''",
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'hyphen',
#  '</Td>',
#  '<Td>',
#  '‐',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'hyphen',
#  '-',
#  'minus',
#  '</Td>',
#  '<Td>',
#  '-',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'question',
#  'mark',
#  '</Td>',
#  '<Td>',
#  '?',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'quotation',
#  'marks',
#  '</Td>',
#  '<Td>',
#  "'",
#  "'",
#  '``',
#  "''",
#  "'",
#  "'",
#  '``',
#  "''",
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'semicolon',
#  '</Td>',
#  '<Td>',
#  ';',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'slash',
#  ',',
#  'stroke',
#  ',',
#  'solidus',
#  '</Td>',
#  '<Td>',
#  '/',
#  '⁄',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'Word',
#  'dividers',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'interpunct',
#  '</Td>',
#  '<Td>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'space',
#  '</Td>',
#  '<Td>',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'General',
#  'typography',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'ampersand',
#  '</Td>',
#  '<Td>',
#  '&',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'asterisk',
#  '</Td>',
#  '<Td>',
#  '*',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'at',
#  'sign',
#  '</Td>',
#  '<Td>',
#  '@',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'backslash',
#  '</Td>',
#  '<Td>',
#  '\\',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'bullet',
#  '</Td>',
#  '<Td>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'caret',
#  '</Td>',
#  '<Td>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'dagger',
#  '</Td>',
#  '<Td>',
#  '†',
#  '‡',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'degree',
#  '</Td>',
#  '<Td>',
#  '°',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'ditto',
#  'mark',
#  '</Td>',
#  '<Td>',
#  "''",
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'inverted',
#  'exclamation',
#  'mark',
#  '</Td>',
#  '<Td>',
#  '¡',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'inverted',
#  'question',
#  'mark',
#  '</Td>',
#  '<Td>',
#  '¿',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'komejirushi',
#  ',',
#  'kome',
#  ',',
#  'reference',
#  'mark',
#  '</Td>',
#  '<Td>',
#  '※',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'number',
#  'sign',
#  ',',
#  'pound',
#  ',',
#  'hash',
#  '</Td>',
#  '<Td>',
#  '#',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'numero',
#  'sign',
#  '</Td>',
#  '<Td>',
#  'No',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'obelus',
#  '</Td>',
#  '<Td>',
#  '÷',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'multiplication',
#  'sign',
#  '</Td>',
#  '<Td>',
#  '×',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'ordinal',
#  'indicator',
#  '</Td>',
#  '<Td>',
#  'o',
#  'a',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'percent',
#  ',',
#  'per',
#  'mil',
#  '</Td>',
#  '<Td>',
#  '%',
#  '‰',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'plus',
#  'and',
#  'minus',
#  '</Td>',
#  '<Td>',
#  '+',
#  '−',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'equals',
#  'sign',
#  '</Td>',
#  '<Td>',
#  '=',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'basis',
#  'point',
#  '</Td>',
#  '<Td>',
#  '‱',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'pilcrow',
#  '</Td>',
#  '<Td>',
#  '¶',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'prime',
#  '</Td>',
#  '<Td>',
#  '′',
#  "''",
#  '′′′',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'section',
#  'sign',
#  '</Td>',
#  '<Td>',
#  '§',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'tilde',
#  '</Td>',
#  '<Td>',
#  '~',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'underscore',
#  ',',
#  'understrike',
#  '</Td>',
#  '<Td>',
#  '_',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'vertical',
#  'bar',
#  ',',
#  'pipe',
#  ',',
#  'broken',
#  'bar',
#  '</Td>',
#  '<Td>',
#  '‖',
#  '¦',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'Intellectual',
#  'property',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'copyright',
#  '</Td>',
#  '<Td>',
#  '©',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'sound',
#  '-',
#  'recording',
#  'copyright',
#  '</Td>',
#  '<Td>',
#  '℗',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'registered',
#  'trademark',
#  '</Td>',
#  '<Td>',
#  '®',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'service',
#  'mark',
#  '</Td>',
#  '<Td>',
#  'SM',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'trademark',
#  '</Td>',
#  '<Td>',
#  'TM',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'Currency',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'currency',
#  'sign',
#  '</Td>',
#  '<Td>',
#  '¤',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  'currency',
#  'symbols',
#  '<P>',
#  '؋',
#  '\u200b',
#  '₳',
#  '\u200b',
#  '฿',
#  '\u200b',
#  '₿',
#  '\u200b',
#  '₵',
#  '\u200b',
#  '¢',
#  '\u200b',
#  '₡',
#  '\u200b',
#  '₢',
#  '\u200b',
#  '$',
#  '\u200b',
#  '₫',
#  '\u200b',
#  '₯',
#  '\u200b',
#  '֏',
#  '\u200b',
#  '₠',
#  '\u200b',
#  '€',
#  '\u200b',
#  'ƒ',
#  '\u200b',
#  '₣',
#  '\u200b',
#  '₲',
#  '\u200b',
#  '₴',
#  '\u200b',
#  '₭',
#  '\u200b',
#  '₺',
#  '\u200b',
#  '₾',
#  '\u200b',
#  '₼',
#  '\u200b',
#  'M',
#  '\u200b',
#  '₥',
#  '\u200b',
#  '₦',
#  '\u200b',
#  '₧',
#  '\u200b',
#  '₱',
#  '\u200b',
#  '₰',
#  '\u200b',
#  '£',
#  '\u200b',
#  '元',
#  '圆',
#  '圓',
#  '\u200b',
#  'ریال',
#  '\u200b',
#  '៛',
#  '\u200b',
#  '₽',
#  '\u200b',
#  '₹',
#  'Rs',
#  '\u200b',
#  '₪',
#  '\u200b',
#  '৳',
#  '\u200b',
#  '₸',
#  '\u200b',
#  '₮',
#  '\u200b',
#  '₩',
#  '\u200b',
#  '¥',
#  '円',
#  '</P>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Table>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'Uncommon',
#  'typography',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'asterism',
#  '</Td>',
#  '<Td>',
#  '⁂',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'fleuron',
#  ',',
#  'hedera',
#  '</Td>',
#  '<Td>',
#  '❧',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'index',
#  ',',
#  'fist',
#  '</Td>',
#  '<Td>',
#  '☞',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'interrobang',
#  '</Td>',
#  '<Td>',
#  '‽',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'irony',
#  'punctuation',
#  '</Td>',
#  '<Td>',
#  '⸮',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'lozenge',
#  '</Td>',
#  '<Td>',
#  '◊',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td>',
#  'tie',
#  '</Td>',
#  '<Td>',
#  '⁀',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'Related',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Ul>',
#  '<Li>',
#  '<Ul>',
#  '<Li>',
#  'Diacritics',
#  '</Li>',
#  '<Li>',
#  'Logic',
#  'symbols',
#  '</Li>',
#  '</Ul>',
#  '</Li>',
#  '<Li>',
#  'Whitespace',
#  'characters',
#  '</Li>',
#  '</Ul>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Th_colspan="2">',
#  'In',
#  'other',
#  'scripts',
#  '</Th>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Ul>',
#  '<Li>',
#  'Chinese',
#  '</Li>',
#  '<Li>',
#  'Hebrew',
#  '</Li>',
#  '<Li>',
#  'Japanese',
#  '</Li>',
#  '<Li>',
#  'Korean',
#  '</Li>',
#  '</Ul>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Ul>',
#  '<Li>',
#  '</Li>',
#  '<Li>',
#  'Portal',
#  '</Li>',
#  '</Ul>',
#  '<Ul>',
#  '<Li>',
#  'Book',
#  '</Li>',
#  '</Ul>',
#  '</Td>',
#  '</Tr>',
#  '<Tr>',
#  '<Td_colspan="2">',
#  '<Ul>',
#  '<Li>',
#  '</Li>',
#  '<Li>',
#  '</Li>',
#  '<Li>',
#  '</Li>',
#  '</Ul>',
#  '</Td>',
#  '</Tr>',
#  '</Table>',
#  '<P>',
#  'In',
#  'logical',
#  'argument',
#  'and',
#  'mathematical',
#  'proof',
#  ',',
#  'the',
#  'therefore',
#  'sign',
#  '(',
#  '∴',
#  ')',
#  'is',
#  'generally',
#  'used',
#  'before',
#  'a',
#  'logical',
#  'consequence',
#  ',',
#  'such',
#  'as',
#  'the',
#  'conclusion',
#  'of',
#  'a',
#  'syllogism',
#  '.',
#  'The',
#  'symbol',
#  'consists',
#  'of',
#  'three',
#  'dots',
#  'placed',
#  'in',
#  'an',
#  'upright',
#  'triangle',
#  'and',
#  'is',
#  'read',
#  'therefore',
#  '.',
#  'It',
#  'is',
#  'encoded',
#  'at',
#  'U',
#  '+',
#  '2234',
#  '∴',
#  'therefore',
#  '(',
#  'HTML',
#  '&',
#  '#',
#  '8756',
#  ';',
#  '&there4',
#  ';',
#  ')',
#  '.',
#  'For',
#  'common',
#  'use',
#  'in',
#  'Microsoft',
#  'Office',
#  'hold',
#  'the',
#  'ALT',
#  'key',
#  'and',
#  'type',
#  '``',
#  '8756',
#  "''",
#  '.',
#  'While',
#  'it',
#  'is',
#  'not',
#  'generally',
#  'used',
#  'in',
#  'formal',
#  'writing',
#  ',',
#  'it',
#  'is',
#  'used',
#  'in',
#  'mathematics',
#  'and',
#  'shorthand',
#  '.',
#  'It',
#  'is',
#  'complementary',
#  'to',
#  'U',
#  '+',
#  '2235',
#  '∵',
#  'because',
#  '(',
#  'HTML',
#  '&',
#  '#',
#  '8757',
#  ';',
#  ')',
#  '.',
#  '</P>',
#  '<P>',
#  '</P>',
#  '<H2>',
#  'Contents',
#  '</H2>',
#  '(',
#  'hide',
#  ')',
#  '<Ul>',
#  '<Li>',
#  '1',
#  'History',
#  '</Li>',
#  '<Li>',
#  '2',
#  'Example',
#  'of',
#  'use',
#  '</Li>',
#  '<Li>',
#  '3',
#  'Related',
#  'signs',
#  '</Li>',
#  '<Li>',
#  '4',
#  'See',
#  'also',
#  '</Li>',
#  '<Li>',
#  '5',
#  'References',
#  '</Li>',
#  '</Ul>',
#  '<P>',
#  '</P>',
#  '<H2>',
#  'History',
#  '(',
#  'edit',
#  ')',
#  '</H2>',
#  '<P>',
#  'According',
#  'to',
#  'Cajori',
#  ',',
#  'A',
#  'History',
#  'of',
#  'Mathematical',
#  'Notations',
#  ',',
#  'Johann',
#  'Rahn',
#  'used',
#  'both',
#  'the',
#  'therefore',
#  'and',
#  'because',
#  'signs',
#  'to',
#  'mean',
#  '``',
#  'therefore',
#  "''",
#  ';',
#  'in',
#  'the',
#  'German',
#  'edition',
#  'of',
#  'Teutsche',
#  'Algebra',
#  ...]

# %% [markdown]
# ## Simplify Dev Data

# %%
len(dev_data)
# Out:
# 7830

# %%
type(dev_data)
# Out:
# list

# %%
dev_data[0]
# Out:
# {'annotations': [{'annotation_id': 13591449469826568799,
#    'long_answer': {'candidate_index': 92,
#     'end_token': 925,
#     'start_token': 808},
#    'short_answers': [{'end_token': 837, 'start_token': 816}],
#    'yes_no_answer': 'NONE'},
#   {'annotation_id': 6237931520544082939,
#    'long_answer': {'candidate_index': 92,
#     'end_token': 925,
#     'start_token': 808},
#    'short_answers': [{'end_token': 819, 'start_token': 816}],
#    'yes_no_answer': 'NONE'},
#   {'annotation_id': 12127791536449879527,
#    'long_answer': {'candidate_index': 92,
#     'end_token': 925,
#     'start_token': 808},
#    'short_answers': [],
#    'yes_no_answer': 'NONE'},
#   {'annotation_id': 6421980561691125452,
#    'long_answer': {'candidate_index': 92,
#     'end_token': 925,
#     'start_token': 808},
#    'short_answers': [{'end_token': 837, 'start_token': 826}],
#    'yes_no_answer': 'NONE'},
#   {'annotation_id': 5015853435362506856,
#    'long_answer': {'candidate_index': 92,
#     'end_token': 925,
#     'start_token': 808},
#    'short_answers': [{'end_token': 819, 'start_token': 817}],
#    'yes_no_answer': 'NONE'}],
#  'document_html': '<!DOCTYPE html>\n<HTML class="client-js ve-not-available" lang="en" dir="ltr"><HEAD>\n\n<TITLE>Therefore sign - Wikipedia</TITLE>\n\n\n<LINK rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" />\n\n<STYLE>\n.referencetooltip{position:absolute;list-style:none;list-style-image:none;opacity:0;font-size:10px;margin:0;z-index:5;padding:0}.referencetooltip li{border:#080086 2px solid;max-width:260px;padding:10px 8px 13px 8px;margin:0px;background-color:#F7F7F7;-webkit-box-shadow:2px 4px 2px rgba(0,0,0,0.3);-moz-box-shadow:2px 4px 2px rgba(0,0,0,0.3);box-shadow:2px 4px 2px rgba(0,0,0,0.3)}.referencetooltip li+li{margin-left:7px;margin-top:-2px;border:0;padding:0;height:3px;width:0px;background-color:transparent;-webkit-box-shadow:none;-moz-box-shadow:none;box-shadow:none;border-top:12px #080086 solid;border-right:7px transparent solid;border-left:7px transparent solid}.referencetooltip>li+li::after{content:\'\';border-top:8px #F7F7F7 solid;border-right:5px transparent solid;border-left:5px transparent solid;margin-top:-12px;margin-left:-5px;z-index:1;height:0px;width:0px;display:block}.client-js body .referencetooltip li li{border:none;-webkit-box-shadow:none;-moz-box-shadow:none;box-shadow:none;height:auto;width:auto;margin:auto;padding:0;position:static}.RTflipped{padding-top:13px}.referencetooltip.RTflipped li+li{position:absolute;top:2px;border-top:0;border-bottom:12px #080086 solid}.referencetooltip.RTflipped li+li::after{border-top:0;border-bottom:8px #F7F7F7 solid;position:absolute;margin-top:7px}.RTsettings{float:right;height:24px;width:24px;cursor:pointer;background-image:url(//upload.wikimedia.org/wikipedia/commons/thumb/0/05/OOjs_UI_icon_advanced.svg/24px-OOjs_UI_icon_advanced.svg.png);background-image:linear-gradient(transparent,transparent),url(//upload.wikimedia.org/wikipedia/commons/0/05/OOjs_UI_icon_advanced.svg);margin-top:-9px;margin-right:-7px;-webkit-transition:opacity 0.15s;-moz-transition:opacity 0.15s;-ms-transition:opacity 0.15s;-o-transition:opacity 0.15s;transition:opacity 0.15s;opacity:0.6;filter:alpha(opacity=60)}.RTsettings:hover{opacity:1;filter:alpha(opacity=100)}.RTTarget{border:#080086 2px solid}\n.wp-teahouse-question-form{position:absolute;margin-left:auto;margin-right:auto;background-color:#f4f3f0;border:1px solid #a7d7f9;padding:1em}#wp-th-question-ask{float:right}.wp-teahouse-ask a.external{background-image:none !important}.wp-teahouse-respond-form{position:absolute;margin-left:auto;margin-right:auto;background-color:#f4f3f0;border:1px solid #a7d7f9;padding:1em}.wp-th-respond{float:right}.wp-teahouse-respond a.external{background-image:none !important}\n.cite-accessibility-label{ top:-99999px;clip:rect( 1px 1px 1px 1px ); clip:rect( 1px,1px,1px,1px ); position:absolute !important;padding:0 !important;border:0 !important;height:1px !important;width:1px !important; overflow:hidden}\n.mw-ui-icon-popups-settings:before{background-image:url(/w/load.php?modules=ext.popups.images&image=popups-settings&format=rasterized&lang=en&skin=vector&version=1cpbno1);background-image:linear-gradient(transparent,transparent),url("data:image/svg+xml,%3Csvg xmlns=%22http://www.w3.org/2000/svg%22 viewBox=%220 0 24 24%22%3E %3Cpath fill=%22%2354595d%22 d=%22M20 14.5v-2.9l-1.8-.3c-.1-.4-.3-.8-.6-1.4l1.1-1.5-2.1-2.1-1.5 1.1c-.5-.3-1-.5-1.4-.6L13.5 5h-2.9l-.3 1.8c-.5.1-.9.3-1.4.6L7.4 6.3 5.3 8.4l1 1.5c-.3.5-.4.9-.6 1.4l-1.7.2v2.9l1.8.3c.1.5.3.9.6 1.4l-1 1.5 2.1 2.1 1.5-1c.4.2.9.4 1.4.6l.3 1.8h3l.3-1.8c.5-.1.9-.3 1.4-.6l1.5 1.1 2.1-2.1-1.1-1.5c.3-.5.5-1 .6-1.4l1.5-.3zM12 16c-1.7 0-3-1.3-3-3s1.3-3 3-3 3 1.3 3 3-1.3 3-3 3z%22/%3E %3C/svg%3E")}.mw-ui-icon-popups-close:before{background-image:url(/w/load.php? ...
#  'document_title': 'Therefore sign',
#  'document_tokens': [{'end_byte': 101,
#    'html_token': False,
#    'start_byte': 92,
#    'token': 'Therefore'},
#   {'end_byte': 106, 'html_token': False, 'start_byte': 102, 'token': 'sign'},
#   {'end_byte': 108, 'html_token': False, 'start_byte': 107, 'token': '-'},
#   {'end_byte': 118,
#    'html_token': False,
#    'start_byte': 109,
#    'token': 'wikipedia'},
#   {'end_byte': 40995,
#    'html_token': True,
#    'start_byte': 40942,
#    'token': '<H1>'},
#   {'end_byte': 41004,
#    'html_token': False,
#    'start_byte': 40995,
#    'token': 'Therefore'},
#   {'end_byte': 41009,
#    'html_token': False,
#    'start_byte': 41005,
#    'token': 'sign'},
#   {'end_byte': 41014,
#    'html_token': True,
#    'start_byte': 41009,
#    'token': '</H1>'},
#   {'end_byte': 41233,
#    'html_token': False,
#    'start_byte': 41229,
#    'token': 'Jump'},
#   {'end_byte': 41236, 'html_token': False, 'start_byte': 41234, 'token': 'to'},
#   {'end_byte': 41237, 'html_token': False, 'start_byte': 41236, 'token': ':'},
#   {'end_byte': 41271,
#    'html_token': False,
#    'start_byte': 41261,
#    'token': 'navigation'},
#   {'end_byte': 41276, 'html_token': False, 'start_byte': 41275, 'token': ','},
#   {'end_byte': 41308,
#    'html_token': False,
#    'start_byte': 41302,
#    'token': 'search'},
#   {'end_byte': 41497,
#    'html_token': True,
#    'start_byte': 41427,
#    'token': '<Table>'},
#   {'end_byte': 41509,
#    'html_token': True,
#    'start_byte': 41505,
#    'token': '<Tr>'},
#   {'end_byte': 41669,
#    'html_token': True,
#    'start_byte': 41510,
#    'token': '<Th colspan="2">'},
#   {'end_byte': 41672, 'html_token': False, 'start_byte': 41669, 'token': '∴'},
#   {'end_byte': 41677,
#    'html_token': True,
#    'start_byte': 41672,
#    'token': '</Th>'},
#   {'end_byte': 41683,
#    'html_token': True,
#    'start_byte': 41678,
#    'token': '</Tr>'},
#   {'end_byte': 41688,
#    'html_token': True,
#    'start_byte': 41684,
#    'token': '<Tr>'},
#   {'end_byte': 41731,
#    'html_token': True,
#    'start_byte': 41689,
#    'token': '<Td colspan="2">'},
#   {'end_byte': 41849,
#    'html_token': False,
#    'start_byte': 41840,
#    'token': 'Therefore'},
#   {'end_byte': 41854,
#    'html_token': False,
#    'start_byte': 41850,
#    'token': 'sign'},
#   {'end_byte': 41866,
#    'html_token': True,
#    'start_byte': 41861,
#    'token': '</Td>'},
#   {'end_byte': 41872,
#    'html_token': True,
#    'start_byte': 41867,
#    'token': '</Tr>'},
#   {'end_byte': 41893,
#    'html_token': True,
#    'start_byte': 41873,
#    'token': '<Tr>'},
#   {'end_byte': 41936,
#    'html_token': True,
#    'start_byte': 41894,
#    'token': '<Td colspan="2">'},
#   {'end_byte': 42042,
#    'html_token': True,
#    'start_byte': 41937,
#    'token': '<Table>'},
#   {'end_byte': 42054,
#    'html_token': True,
#    'start_byte': 42050,
#    'token': '<Tr>'},
#   {'end_byte': 42133,
#    'html_token': True,
#    'start_byte': 42055,
#    'token': '<Th colspan="2">'},
#   {'end_byte': 42192,
#    'html_token': False,
#    'start_byte': 42181,
#    'token': 'Punctuation'},
#   {'end_byte': 42201,
#    'html_token': True,
#    'start_byte': 42196,
#    'token': '</Th>'},
#   {'end_byte': 42207,
#    'html_token': True,
#    'start_byte': 42202,
#    'token': '</Tr>'},
#   {'end_byte': 42239,
#    'html_token': True,
#    'start_byte': 42208,
#    'token': '<Tr>'},
#   {'end_byte': 42269,
#    'html_token': True,
#    'start_byte': 42240,
#    'token': '<Td>'},
#   {'end_byte': 42325,
#    'html_token': False,
#    'start_byte': 42315,
#    'token': 'apostrophe'},
#   {'end_byte': 42334,
#    'html_token': True,
#    'start_byte': 42329,
#    'token': '</Td>'},
#   {'end_byte': 42439,
#    'html_token': True,
#    'start_byte': 42335,
#    'token': '<Td>'},
#   {'end_byte': 42442, 'html_token': False, 'start_byte': 42439, 'token': "'"},
#   {'end_byte': 42479, 'html_token': False, 'start_byte': 42474, 'token': "'"},
#   {'end_byte': 42484,
#    'html_token': True,
#    'start_byte': 42479,
#    'token': '</Td>'},
#   {'end_byte': 42490,
#    'html_token': True,
#    'start_byte': 42485,
#    'token': '</Tr>'},
#   {'end_byte': 42522,
#    'html_token': True,
#    'start_byte': 42491,
#    'token': '<Tr>'},
#   {'end_byte': 42552,
#    'html_token': True,
#    'start_byte': 42523,
#    'token': '<Td>'},
#   {'end_byte': 42600,
#    'html_token': False,
#    'start_byte': 42592,
#    'token': 'brackets'},
#   {'end_byte': 42609,
#    'html_token': True,
#    'start_byte': 42604,
#    'token': '</Td>'},
#   {'end_byte': 42714,
#    'html_token': True,
#    'start_byte': 42610,
#    'token': '<Td>'},
#   {'end_byte': 42715, 'html_token': False, 'start_byte': 42714, 'token': '('},
#   {'end_byte': 42718, 'html_token': False, 'start_byte': 42717, 'token': ')'},
#   {'end_byte': 42751, 'html_token': False, 'start_byte': 42750, 'token': '('},
#   {'end_byte': 42754, 'html_token': False, 'start_byte': 42753, 'token': ')'},
#   {'end_byte': 42787, 'html_token': False, 'start_byte': 42786, 'token': '('},
#   {'end_byte': 42790, 'html_token': False, 'start_byte': 42789, 'token': ')'},
#   {'end_byte': 42825, 'html_token': False, 'start_byte': 42822, 'token': '⟨'},
#   {'end_byte': 42830, 'html_token': False, 'start_byte': 42827, 'token': '⟩'},
#   {'end_byte': 42835,
#    'html_token': True,
#    'start_byte': 42830,
#    'token': '</Td>'},
#   {'end_byte': 42841,
#    'html_token': True,
#    'start_byte': 42836,
#    'token': '</Tr>'},
#   {'end_byte': 42873,
#    'html_token': True,
#    'start_byte': 42842,
#    'token': '<Tr>'},
#   {'end_byte': 42903,
#    'html_token': True,
#    'start_byte': 42874,
#    'token': '<Td>'},
#   {'end_byte': 42972,
#    'html_token': False,
#    'start_byte': 42967,
#    'token': 'colon'},
#   {'end_byte': 42981,
#    'html_token': True,
#    'start_byte': 42976,
#    'token': '</Td>'},
#   {'end_byte': 43086,
#    'html_token': True,
#    'start_byte': 42982,
#    'token': '<Td>'},
#   {'end_byte': 43097, 'html_token': False, 'start_byte': 43096, 'token': ':'},
#   {'end_byte': 43114,
#    'html_token': True,
#    'start_byte': 43109,
#    'token': '</Td>'},
#   {'end_byte': 43120,
#    'html_token': True,
#    'start_byte': 43115,
#    'token': '</Tr>'},
#   {'end_byte': 43152,
#    'html_token': True,
#    'start_byte': 43121,
#    'token': '<Tr>'},
#   {'end_byte': 43182,
#    'html_token': True,
#    'start_byte': 43153,
#    'token': '<Td>'},
#   {'end_byte': 43223,
#    'html_token': False,
#    'start_byte': 43218,
#    'token': 'comma'},
#   {'end_byte': 43232,
#    'html_token': True,
#    'start_byte': 43227,
#    'token': '</Td>'},
#   {'end_byte': 43337,
#    'html_token': True,
#    'start_byte': 43233,
#    'token': '<Td>'},
#   {'end_byte': 43338, 'html_token': False, 'start_byte': 43337, 'token': ','},
#   {'end_byte': 43372, 'html_token': False, 'start_byte': 43370, 'token': '،'},
#   {'end_byte': 43407, 'html_token': False, 'start_byte': 43404, 'token': '、'},
#   {'end_byte': 43412,
#    'html_token': True,
#    'start_byte': 43407,
#    'token': '</Td>'},
#   {'end_byte': 43418,
#    'html_token': True,
#    'start_byte': 43413,
#    'token': '</Tr>'},
#   {'end_byte': 43450,
#    'html_token': True,
#    'start_byte': 43419,
#    'token': '<Tr>'},
#   {'end_byte': 43480,
#    'html_token': True,
#    'start_byte': 43451,
#    'token': '<Td>'},
#   {'end_byte': 43518,
#    'html_token': False,
#    'start_byte': 43514,
#    'token': 'dash'},
#   {'end_byte': 43527,
#    'html_token': True,
#    'start_byte': 43522,
#    'token': '</Td>'},
#   {'end_byte': 43632,
#    'html_token': True,
#    'start_byte': 43528,
#    'token': '<Td>'},
#   {'end_byte': 43635, 'html_token': False, 'start_byte': 43632, 'token': '‒'},
#   {'end_byte': 43641, 'html_token': False, 'start_byte': 43638, 'token': '--'},
#   {'end_byte': 43647, 'html_token': False, 'start_byte': 43644, 'token': '--'},
#   {'end_byte': 43653, 'html_token': False, 'start_byte': 43650, 'token': '―'},
#   {'end_byte': 43658,
#    'html_token': True,
#    'start_byte': 43653,
#    'token': '</Td>'},
#   {'end_byte': 43664,
#    'html_token': True,
#    'start_byte': 43659,
#    'token': '</Tr>'},
#   {'end_byte': 43696,
#    'html_token': True,
#    'start_byte': 43665,
#    'token': '<Tr>'},
#   {'end_byte': 43726,
#    'html_token': True,
#    'start_byte': 43697,
#    'token': '<Td>'},
#   {'end_byte': 43776,
#    'html_token': False,
#    'start_byte': 43768,
#    'token': 'ellipsis'},
#   {'end_byte': 43785,
#    'html_token': True,
#    'start_byte': 43780,
#    'token': '</Td>'},
#   {'end_byte': 43890,
#    'html_token': True,
#    'start_byte': 43786,
#    'token': '<Td>'},
#   {'end_byte': 43893,
#    'html_token': False,
#    'start_byte': 43890,
#    'token': '...'},
#   {'end_byte': 43928,
#    'html_token': False,
#    'start_byte': 43925,
#    'token': '...'},
#   {'end_byte': 43963, 'html_token': False, 'start_byte': 43960, 'token': '⋯'},
#   {'end_byte': 43998, 'html_token': False, 'start_byte': 43995, 'token': '᠁'},
#   {'end_byte': 44033, 'html_token': False, 'start_byte': 44030, 'token': 'ฯ'},
#   {'end_byte': 44038,
#    'html_token': True,
#    'start_byte': 44033,
#    'token': '</Td>'},
#   {'end_byte': 44044,
#    'html_token': True,
#    'start_byte': 44039,
#    'token': '</Tr>'},
#   {'end_byte': 44076,
#    'html_token': True,
#    'start_byte': 44045,
#    'token': '<Tr>'},
#   {'end_byte': 44106,
#    'html_token': True,
#    'start_byte': 44077,
#    'token': '<Td>'},
#   {'end_byte': 44175,
#    'html_token': False,
#    'start_byte': 44164,
#    'token': 'exclamation'},
#   {'end_byte': 44180,
#    'html_token': False,
#    'start_byte': 44176,
#    'token': 'mark'},
#   {'end_byte': 44189,
#    'html_token': True,
#    'start_byte': 44184,
#    'token': '</Td>'},
#   {'end_byte': 44294,
#    'html_token': True,
#    'start_byte': 44190,
#    'token': '<Td>'},
#   {'end_byte': 44297, 'html_token': False, 'start_byte': 44296, 'token': '!'},
#   {'end_byte': 44302,
#    'html_token': True,
#    'start_byte': 44297,
#    'token': '</Td>'},
#   {'end_byte': 44308,
#    'html_token': True,
#    'start_byte': 44303,
#    'token': '</Tr>'},
#   {'end_byte': 44340,
#    'html_token': True,
#    'start_byte': 44309,
#    'token': '<Tr>'},
#   {'end_byte': 44370,
#    'html_token': True,
#    'start_byte': 44341,
#    'token': '<Td>'},
#   {'end_byte': 44418,
#    'html_token': False,
#    'start_byte': 44414,
#    'token': 'full'},
#   {'end_byte': 44423,
#    'html_token': False,
#    'start_byte': 44419,
#    'token': 'stop'},
#   {'end_byte': 44424, 'html_token': False, 'start_byte': 44423, 'token': ','},
#   {'end_byte': 44431,
#    'html_token': False,
#    'start_byte': 44425,
#    'token': 'period'},
#   {'end_byte': 44440,
#    'html_token': True,
#    'start_byte': 44435,
#    'token': '</Td>'},
#   {'end_byte': 44545,
#    'html_token': True,
#    'start_byte': 44441,
#    'token': '<Td>'},
#   {'end_byte': 44549, 'html_token': False, 'start_byte': 44548, 'token': '.'},
#   {'end_byte': 44558,
#    'html_token': True,
#    'start_byte': 44553,
#    'token': '</Td>'},
#   {'end_byte': 44564,
#    'html_token': True,
#    'start_byte': 44559,
#    'token': '</Tr>'},
#   {'end_byte': 44596,
#    'html_token': True,
#    'start_byte': 44565,
#    'token': '<Tr>'},
#   {'end_byte': 44626,
#    'html_token': True,
#    'start_byte': 44597,
#    'token': '<Td>'},
#   {'end_byte': 44680,
#    'html_token': False,
#    'start_byte': 44670,
#    'token': 'guillemets'},
#   {'end_byte': 44689,
#    'html_token': True,
#    'start_byte': 44684,
#    'token': '</Td>'},
#   {'end_byte': 44794,
#    'html_token': True,
#    'start_byte': 44690,
#    'token': '<Td>'},
#   {'end_byte': 44797, 'html_token': False, 'start_byte': 44794, 'token': '``'},
#   {'end_byte': 44802, 'html_token': False, 'start_byte': 44799, 'token': "''"},
#   {'end_byte': 44836, 'html_token': False, 'start_byte': 44834, 'token': '``'},
#   {'end_byte': 44840, 'html_token': False, 'start_byte': 44838, 'token': "''"},
#   {'end_byte': 44845,
#    'html_token': True,
#    'start_byte': 44840,
#    'token': '</Td>'},
#   {'end_byte': 44851,
#    'html_token': True,
#    'start_byte': 44846,
#    'token': '</Tr>'},
#   {'end_byte': 44883,
#    'html_token': True,
#    'start_byte': 44852,
#    'token': '<Tr>'},
#   {'end_byte': 44913,
#    'html_token': True,
#    'start_byte': 44884,
#    'token': '<Td>'},
#   {'end_byte': 44957,
#    'html_token': False,
#    'start_byte': 44951,
#    'token': 'hyphen'},
#   {'end_byte': 44966,
#    'html_token': True,
#    'start_byte': 44961,
#    'token': '</Td>'},
#   {'end_byte': 45071,
#    'html_token': True,
#    'start_byte': 44967,
#    'token': '<Td>'},
#   {'end_byte': 45074, 'html_token': False, 'start_byte': 45071, 'token': '‐'},
#   {'end_byte': 45079,
#    'html_token': True,
#    'start_byte': 45074,
#    'token': '</Td>'},
#   {'end_byte': 45085,
#    'html_token': True,
#    'start_byte': 45080,
#    'token': '</Tr>'},
#   {'end_byte': 45117,
#    'html_token': True,
#    'start_byte': 45086,
#    'token': '<Tr>'},
#   {'end_byte': 45147,
#    'html_token': True,
#    'start_byte': 45118,
#    'token': '<Td>'},
#   {'end_byte': 45203,
#    'html_token': False,
#    'start_byte': 45197,
#    'token': 'hyphen'},
#   {'end_byte': 45204, 'html_token': False, 'start_byte': 45203, 'token': '-'},
#   {'end_byte': 45209,
#    'html_token': False,
#    'start_byte': 45204,
#    'token': 'minus'},
#   {'end_byte': 45218,
#    'html_token': True,
#    'start_byte': 45213,
#    'token': '</Td>'},
#   {'end_byte': 45323,
#    'html_token': True,
#    'start_byte': 45219,
#    'token': '<Td>'},
#   {'end_byte': 45324, 'html_token': False, 'start_byte': 45323, 'token': '-'},
#   {'end_byte': 45329,
#    'html_token': True,
#    'start_byte': 45324,
#    'token': '</Td>'},
#   {'end_byte': 45335,
#    'html_token': True,
#    'start_byte': 45330,
#    'token': '</Tr>'},
#   {'end_byte': 45367,
#    'html_token': True,
#    'start_byte': 45336,
#    'token': '<Tr>'},
#   {'end_byte': 45397,
#    'html_token': True,
#    'start_byte': 45368,
#    'token': '<Td>'},
#   {'end_byte': 45457,
#    'html_token': False,
#    'start_byte': 45449,
#    'token': 'question'},
#   {'end_byte': 45462,
#    'html_token': False,
#    'start_byte': 45458,
#    'token': 'mark'},
#   {'end_byte': 45471,
#    'html_token': True,
#    'start_byte': 45466,
#    'token': '</Td>'},
#   {'end_byte': 45576,
#    'html_token': True,
#    'start_byte': 45472,
#    'token': '<Td>'},
#   {'end_byte': 45579, 'html_token': False, 'start_byte': 45578, 'token': '?'},
#   {'end_byte': 45584,
#    'html_token': True,
#    'start_byte': 45579,
#    'token': '</Td>'},
#   {'end_byte': 45590,
#    'html_token': True,
#    'start_byte': 45585,
#    'token': '</Tr>'},
#   {'end_byte': 45622,
#    'html_token': True,
#    'start_byte': 45591,
#    'token': '<Tr>'},
#   {'end_byte': 45652,
#    'html_token': True,
#    'start_byte': 45623,
#    'token': '<Td>'},
#   {'end_byte': 45715,
#    'html_token': False,
#    'start_byte': 45706,
#    'token': 'quotation'},
#   {'end_byte': 45721,
#    'html_token': False,
#    'start_byte': 45716,
#    'token': 'marks'},
#   {'end_byte': 45730,
#    'html_token': True,
#    'start_byte': 45725,
#    'token': '</Td>'},
#   {'end_byte': 45835,
#    'html_token': True,
#    'start_byte': 45731,
#    'token': '<Td>'},
#   {'end_byte': 45838, 'html_token': False, 'start_byte': 45835, 'token': "'"},
#   {'end_byte': 45843, 'html_token': False, 'start_byte': 45840, 'token': "'"},
#   {'end_byte': 45878, 'html_token': False, 'start_byte': 45875, 'token': '``'},
#   {'end_byte': 45883, 'html_token': False, 'start_byte': 45880, 'token': "''"},
#   {'end_byte': 45920, 'html_token': False, 'start_byte': 45915, 'token': "'"},
#   {'end_byte': 45927, 'html_token': False, 'start_byte': 45922, 'token': "'"},
#   {'end_byte': 45965, 'html_token': False, 'start_byte': 45959, 'token': '``'},
#   {'end_byte': 45973, 'html_token': False, 'start_byte': 45967, 'token': "''"},
#   {'end_byte': 45978,
#    'html_token': True,
#    'start_byte': 45973,
#    'token': '</Td>'},
#   {'end_byte': 45984,
#    'html_token': True,
#    'start_byte': 45979,
#    'token': '</Tr>'},
#   {'end_byte': 46016,
#    'html_token': True,
#    'start_byte': 45985,
#    'token': '<Tr>'},
#   {'end_byte': 46046,
#    'html_token': True,
#    'start_byte': 46017,
#    'token': '<Td>'},
#   {'end_byte': 46099,
#    'html_token': False,
#    'start_byte': 46090,
#    'token': 'semicolon'},
#   {'end_byte': 46108,
#    'html_token': True,
#    'start_byte': 46103,
#    'token': '</Td>'},
#   {'end_byte': 46213,
#    'html_token': True,
#    'start_byte': 46109,
#    'token': '<Td>'},
#   {'end_byte': 46224, 'html_token': False, 'start_byte': 46223, 'token': ';'},
#   {'end_byte': 46241,
#    'html_token': True,
#    'start_byte': 46236,
#    'token': '</Td>'},
#   {'end_byte': 46247,
#    'html_token': True,
#    'start_byte': 46242,
#    'token': '</Tr>'},
#   {'end_byte': 46279,
#    'html_token': True,
#    'start_byte': 46248,
#    'token': '<Tr>'},
#   {'end_byte': 46309,
#    'html_token': True,
#    'start_byte': 46280,
#    'token': '<Td>'},
#   {'end_byte': 46378,
#    'html_token': False,
#    'start_byte': 46373,
#    'token': 'slash'},
#   {'end_byte': 46379, 'html_token': False, 'start_byte': 46378, 'token': ','},
#   {'end_byte': 46386,
#    'html_token': False,
#    'start_byte': 46380,
#    'token': 'stroke'},
#   {'end_byte': 46387, 'html_token': False, 'start_byte': 46386, 'token': ','},
#   {'end_byte': 46395,
#    'html_token': False,
#    'start_byte': 46388,
#    'token': 'solidus'},
#   {'end_byte': 46404,
#    'html_token': True,
#    'start_byte': 46399,
#    'token': '</Td>'},
#   {'end_byte': 46509,
#    'html_token': True,
#    'start_byte': 46405,
#    'token': '<Td>'},
#   {'end_byte': 46510, 'html_token': False, 'start_byte': 46509, 'token': '/'},
#   {'end_byte': 46545, 'html_token': False, 'start_byte': 46542, 'token': '⁄'},
#   {'end_byte': 46550,
#    'html_token': True,
#    'start_byte': 46545,
#    'token': '</Td>'},
#   {'end_byte': 46556,
#    'html_token': True,
#    'start_byte': 46551,
#    'token': '</Tr>'},
#   {'end_byte': 46573,
#    'html_token': True,
#    'start_byte': 46565,
#    'token': '</Table>'},
#   {'end_byte': 46579,
#    'html_token': True,
#    'start_byte': 46574,
#    'token': '</Td>'},
#   {'end_byte': 46585,
#    'html_token': True,
#    'start_byte': 46580,
#    'token': '</Tr>'},
#   {'end_byte': 46606,
#    'html_token': True,
#    'start_byte': 46586,
#    'token': '<Tr>'},
#   {'end_byte': 46649,
#    'html_token': True,
#    'start_byte': 46607,
#    'token': '<Td colspan="2">'},
#   {'end_byte': 46755,
#    'html_token': True,
#    'start_byte': 46650,
#    'token': '<Table>'},
#   {'end_byte': 46767,
#    'html_token': True,
#    'start_byte': 46763,
#    'token': '<Tr>'},
#   {'end_byte': 46846,
#    'html_token': True,
#    'start_byte': 46768,
#    'token': '<Th colspan="2">'},
#   {'end_byte': 46900,
#    'html_token': False,
#    'start_byte': 46896,
#    'token': 'Word'},
#   {'end_byte': 46909,
#    'html_token': False,
#    'start_byte': 46901,
#    'token': 'dividers'},
#   {'end_byte': 46918,
#    'html_token': True,
#    'start_byte': 46913,
#    'token': '</Th>'},
#   {'end_byte': 46924,
#    'html_token': True,
#    'start_byte': 46919,
#    'token': '</Tr>'},
#   {'end_byte': 46956,
#    'html_token': True,
#    'start_byte': 46925,
#    'token': '<Tr>'},
#   {'end_byte': 46986,
#    'html_token': True,
#    'start_byte': 46957,
#    'token': '<Td>'},
#   {'end_byte': 47042,
#    'html_token': False,
#    'start_byte': 47032,
#    'token': 'interpunct'},
#   {'end_byte': 47051,
#    'html_token': True,
#    'start_byte': 47046,
#    'token': '</Td>'},
#   {'end_byte': 47156,
#    'html_token': True,
#    'start_byte': 47052,
#    'token': '<Td>'},
#   {'end_byte': 47170,
#    'html_token': True,
#    'start_byte': 47165,
#    'token': '</Td>'},
#   {'end_byte': 47176,
#    'html_token': True,
#    'start_byte': 47171,
#    'token': '</Tr>'},
#   {'end_byte': 47208,
#    'html_token': True,
#    'start_byte': 47177,
#    'token': '<Tr>'},
#   {'end_byte': 47238,
#    'html_token': True,
#    'start_byte': 47209,
#    'token': '<Td>'},
#   {'end_byte': 47307,
#    'html_token': False,
#    'start_byte': 47302,
#    'token': 'space'},
#   {'end_byte': 47316,
#    'html_token': True,
#    'start_byte': 47311,
#    'token': '</Td>'},
#   {'end_byte': 47421,
#    'html_token': True,
#    'start_byte': 47317,
#    'token': '<Td>'},
#   {'end_byte': 47581,
#    'html_token': True,
#    'start_byte': 47576,
#    'token': '</Td>'},
#   {'end_byte': 47587,
#    'html_token': True,
#    'start_byte': 47582,
#    'token': '</Tr>'},
#   {'end_byte': 47604,
#    'html_token': True,
#    'start_byte': 47596,
#    'token': '</Table>'},
#   {'end_byte': 47610,
#    'html_token': True,
#    'start_byte': 47605,
#    'token': '</Td>'},
#   {'end_byte': 47616,
#    'html_token': True,
#    'start_byte': 47611,
#    'token': '</Tr>'},
#   {'end_byte': 47637,
#    'html_token': True,
#    'start_byte': 47617,
#    'token': '<Tr>'},
#   {'end_byte': 47680,
#    'html_token': True,
#    'start_byte': 47638,
#    'token': '<Td colspan="2">'},
#   {'end_byte': 47786,
#    'html_token': True,
#    'start_byte': 47681,
#    'token': '<Table>'},
#   {'end_byte': 47798,
#    'html_token': True,
#    'start_byte': 47794,
#    'token': '<Tr>'},
#   {'end_byte': 47877,
#    'html_token': True,
#    'start_byte': 47799,
#    'token': '<Th colspan="2">'},
#   {'end_byte': 47884,
#    'html_token': False,
#    'start_byte': 47877,
#    'token': 'General'},
#   {'end_byte': 47941,
#    'html_token': False,
#    'start_byte': 47931,
#    'token': 'typography'},
#   {'end_byte': 47950,
#    'html_token': True,
#    'start_byte': 47945,
#    'token': '</Th>'},
#   {'end_byte': 47956,
#    'html_token': True,
#    'start_byte': 47951,
#    'token': '</Tr>'},
#   {'end_byte': 47988,
#    'html_token': True,
#    'start_byte': 47957,
#    'token': '<Tr>'},
#   {'end_byte': 48018,
#    'html_token': True,
#    'start_byte': 47989,
#    'token': '<Td>'},
#   {'end_byte': 48071,
#    'html_token': False,
#    'start_byte': 48062,
#    'token': 'ampersand'},
#   {'end_byte': 48080,
#    'html_token': True,
#    'start_byte': 48075,
#    'token': '</Td>'},
#   {'end_byte': 48185,
#    'html_token': True,
#    'start_byte': 48081,
#    'token': '<Td>'},
#   {'end_byte': 48190, 'html_token': False, 'start_byte': 48185, 'token': '&'},
#   {'end_byte': 48195,
#    'html_token': True,
#    'start_byte': 48190,
#    'token': '</Td>'},
#   {'end_byte': 48201,
#    'html_token': True,
#    'start_byte': 48196,
#    'token': '</Tr>'},
#   {'end_byte': 48233,
#    'html_token': True,
#    'start_byte': 48202,
#    'token': '<Tr>'},
#   {'end_byte': 48263,
#    'html_token': True,
#    'start_byte': 48234,
#    'token': '<Td>'},
#   {'end_byte': 48313,
#    'html_token': False,
#    'start_byte': 48305,
#    'token': 'asterisk'},
#   {'end_byte': 48322,
#    'html_token': True,
#    'start_byte': 48317,
#    'token': '</Td>'},
#   {'end_byte': 48427,
#    'html_token': True,
#    'start_byte': 48323,
#    'token': '<Td>'},
#   {'end_byte': 48428, 'html_token': False, 'start_byte': 48427, 'token': '*'},
#   {'end_byte': 48433,
#    'html_token': True,
#    'start_byte': 48428,
#    'token': '</Td>'},
#   {'end_byte': 48439,
#    'html_token': True,
#    'start_byte': 48434,
#    'token': '</Tr>'},
#   {'end_byte': 48471,
#    'html_token': True,
#    'start_byte': 48440,
#    'token': '<Tr>'},
#   {'end_byte': 48501,
#    'html_token': True,
#    'start_byte': 48472,
#    'token': '<Td>'},
#   {'end_byte': 48543, 'html_token': False, 'start_byte': 48541, 'token': 'at'},
#   {'end_byte': 48548,
#    'html_token': False,
#    'start_byte': 48544,
#    'token': 'sign'},
#   {'end_byte': 48557,
#    'html_token': True,
#    'start_byte': 48552,
#    'token': '</Td>'},
#   {'end_byte': 48662,
#    'html_token': True,
#    'start_byte': 48558,
#    'token': '<Td>'},
#   {'end_byte': 48663, 'html_token': False, 'start_byte': 48662, 'token': '@'},
#   {'end_byte': 48668,
#    'html_token': True,
#    'start_byte': 48663,
#    'token': '</Td>'},
#   {'end_byte': 48674,
#    'html_token': True,
#    'start_byte': 48669,
#    'token': '</Tr>'},
#   {'end_byte': 48706,
#    'html_token': True,
#    'start_byte': 48675,
#    'token': '<Tr>'},
#   {'end_byte': 48736,
#    'html_token': True,
#    'start_byte': 48707,
#    'token': '<Td>'},
#   {'end_byte': 48789,
#    'html_token': False,
#    'start_byte': 48780,
#    'token': 'backslash'},
#   {'end_byte': 48798,
#    'html_token': True,
#    'start_byte': 48793,
#    'token': '</Td>'},
#   {'end_byte': 48903,
#    'html_token': True,
#    'start_byte': 48799,
#    'token': '<Td>'},
#   {'end_byte': 48904, 'html_token': False, 'start_byte': 48903, 'token': '\\'},
#   {'end_byte': 48909,
#    'html_token': True,
#    'start_byte': 48904,
#    'token': '</Td>'},
#   {'end_byte': 48915,
#    'html_token': True,
#    'start_byte': 48910,
#    'token': '</Tr>'},
#   {'end_byte': 48947,
#    'html_token': True,
#    'start_byte': 48916,
#    'token': '<Tr>'},
#   {'end_byte': 48977,
#    'html_token': True,
#    'start_byte': 48948,
#    'token': '<Td>'},
#   {'end_byte': 49047,
#    'html_token': False,
#    'start_byte': 49041,
#    'token': 'bullet'},
#   {'end_byte': 49056,
#    'html_token': True,
#    'start_byte': 49051,
#    'token': '</Td>'},
#   {'end_byte': 49161,
#    'html_token': True,
#    'start_byte': 49057,
#    'token': '<Td>'},
#   {'end_byte': 49169,
#    'html_token': True,
#    'start_byte': 49164,
#    'token': '</Td>'},
#   {'end_byte': 49175,
#    'html_token': True,
#    'start_byte': 49170,
#    'token': '</Tr>'},
#   {'end_byte': 49207,
#    'html_token': True,
#    'start_byte': 49176,
#    'token': '<Tr>'},
#   {'end_byte': 49237,
#    'html_token': True,
#    'start_byte': 49208,
#    'token': '<Td>'},
#   {'end_byte': 49278,
#    'html_token': False,
#    'start_byte': 49273,
#    'token': 'caret'},
#   {'end_byte': 49287,
#    'html_token': True,
#    'start_byte': 49282,
#    'token': '</Td>'},
#   {'end_byte': 49392,
#    'html_token': True,
#    'start_byte': 49288,
#    'token': '<Td>'},
#   {'end_byte': 49398,
#    'html_token': True,
#    'start_byte': 49393,
#    'token': '</Td>'},
#   {'end_byte': 49404,
#    'html_token': True,
#    'start_byte': 49399,
#    'token': '</Tr>'},
#   {'end_byte': 49436,
#    'html_token': True,
#    'start_byte': 49405,
#    'token': '<Tr>'},
#   {'end_byte': 49466,
#    'html_token': True,
#    'start_byte': 49437,
#    'token': '<Td>'},
#   {'end_byte': 49536,
#    'html_token': False,
#    'start_byte': 49530,
#    'token': 'dagger'},
#   {'end_byte': 49545,
#    'html_token': True,
#    'start_byte': 49540,
#    'token': '</Td>'},
#   {'end_byte': 49650,
#    'html_token': True,
#    'start_byte': 49546,
#    'token': '<Td>'},
#   {'end_byte': 49653, 'html_token': False, 'start_byte': 49650, 'token': '†'},
#   {'end_byte': 49657, 'html_token': False, 'start_byte': 49654, 'token': '‡'},
#   {'end_byte': 49662,
#    'html_token': True,
#    'start_byte': 49657,
#    'token': '</Td>'},
#   {'end_byte': 49668,
#    'html_token': True,
#    'start_byte': 49663,
#    'token': '</Tr>'},
#   {'end_byte': 49700,
#    'html_token': True,
#    'start_byte': 49669,
#    'token': '<Tr>'},
#   {'end_byte': 49730,
#    'html_token': True,
#    'start_byte': 49701,
#    'token': '<Td>'},
#   {'end_byte': 49788,
#    'html_token': False,
#    'start_byte': 49782,
#    'token': 'degree'},
#   {'end_byte': 49797,
#    'html_token': True,
#    'start_byte': 49792,
#    'token': '</Td>'},
#   {'end_byte': 49902,
#    'html_token': True,
#    'start_byte': 49798,
#    'token': '<Td>'},
#   {'end_byte': 49904, 'html_token': False, 'start_byte': 49902, 'token': '°'},
#   {'end_byte': 49909,
#    'html_token': True,
#    'start_byte': 49904,
#    'token': '</Td>'},
#   {'end_byte': 49915,
#    'html_token': True,
#    'start_byte': 49910,
#    'token': '</Tr>'},
#   {'end_byte': 49947,
#    'html_token': True,
#    'start_byte': 49916,
#    'token': '<Tr>'},
#   {'end_byte': 49977,
#    'html_token': True,
#    'start_byte': 49948,
#    'token': '<Td>'},
#   {'end_byte': 50028,
#    'html_token': False,
#    'start_byte': 50023,
#    'token': 'ditto'},
#   {'end_byte': 50033,
#    'html_token': False,
#    'start_byte': 50029,
#    'token': 'mark'},
#   {'end_byte': 50042,
#    'html_token': True,
#    'start_byte': 50037,
#    'token': '</Td>'},
#   {'end_byte': 50147,
#    'html_token': True,
#    'start_byte': 50043,
#    'token': '<Td>'},
#   {'end_byte': 50150, 'html_token': False, 'start_byte': 50147, 'token': "''"},
#   {'end_byte': 50155,
#    'html_token': True,
#    'start_byte': 50150,
#    'token': '</Td>'},
#   {'end_byte': 50161,
#    'html_token': True,
#    'start_byte': 50156,
#    'token': '</Tr>'},
#   {'end_byte': 50193,
#    'html_token': True,
#    'start_byte': 50162,
#    'token': '<Tr>'},
#   {'end_byte': 50223,
#    'html_token': True,
#    'start_byte': 50194,
#    'token': '<Td>'},
#   {'end_byte': 50335,
#    'html_token': False,
#    'start_byte': 50327,
#    'token': 'inverted'},
#   {'end_byte': 50347,
#    'html_token': False,
#    'start_byte': 50336,
#    'token': 'exclamation'},
#   {'end_byte': 50352,
#    'html_token': False,
#    'start_byte': 50348,
#    'token': 'mark'},
#   {'end_byte': 50361,
#    'html_token': True,
#    'start_byte': 50356,
#    'token': '</Td>'},
#   {'end_byte': 50466,
#    'html_token': True,
#    'start_byte': 50362,
#    'token': '<Td>'},
#   {'end_byte': 50468, 'html_token': False, 'start_byte': 50466, 'token': '¡'},
#   {'end_byte': 50473,
#    'html_token': True,
#    'start_byte': 50468,
#    'token': '</Td>'},
#   {'end_byte': 50479,
#    'html_token': True,
#    'start_byte': 50474,
#    'token': '</Tr>'},
#   {'end_byte': 50511,
#    'html_token': True,
#    'start_byte': 50480,
#    'token': '<Tr>'},
#   {'end_byte': 50541,
#    'html_token': True,
#    'start_byte': 50512,
#    'token': '<Td>'},
#   {'end_byte': 50653,
#    'html_token': False,
#    'start_byte': 50645,
#    'token': 'inverted'},
#   {'end_byte': 50662,
#    'html_token': False,
#    'start_byte': 50654,
#    'token': 'question'},
#   {'end_byte': 50667,
#    'html_token': False,
#    'start_byte': 50663,
#    'token': 'mark'},
#   {'end_byte': 50676,
#    'html_token': True,
#    'start_byte': 50671,
#    'token': '</Td>'},
#   {'end_byte': 50781,
#    'html_token': True,
#    'start_byte': 50677,
#    'token': '<Td>'},
#   {'end_byte': 50783, 'html_token': False, 'start_byte': 50781, 'token': '¿'},
#   {'end_byte': 50788,
#    'html_token': True,
#    'start_byte': 50783,
#    'token': '</Td>'},
#   {'end_byte': 50794,
#    'html_token': True,
#    'start_byte': 50789,
#    'token': '</Tr>'},
#   {'end_byte': 50826,
#    'html_token': True,
#    'start_byte': 50795,
#    'token': '<Tr>'},
#   {'end_byte': 50856,
#    'html_token': True,
#    'start_byte': 50827,
#    'token': '<Td>'},
#   {'end_byte': 50915,
#    'html_token': False,
#    'start_byte': 50904,
#    'token': 'komejirushi'},
#   {'end_byte': 50916, 'html_token': False, 'start_byte': 50915, 'token': ','},
#   {'end_byte': 50921,
#    'html_token': False,
#    'start_byte': 50917,
#    'token': 'kome'},
#   {'end_byte': 50922, 'html_token': False, 'start_byte': 50921, 'token': ','},
#   {'end_byte': 50932,
#    'html_token': False,
#    'start_byte': 50923,
#    'token': 'reference'},
#   {'end_byte': 50937,
#    'html_token': False,
#    'start_byte': 50933,
#    'token': 'mark'},
#   {'end_byte': 50946,
#    'html_token': True,
#    'start_byte': 50941,
#    'token': '</Td>'},
#   {'end_byte': 51051,
#    'html_token': True,
#    'start_byte': 50947,
#    'token': '<Td>'},
#   {'end_byte': 51054, 'html_token': False, 'start_byte': 51051, 'token': '※'},
#   {'end_byte': 51059,
#    'html_token': True,
#    'start_byte': 51054,
#    'token': '</Td>'},
#   {'end_byte': 51065,
#    'html_token': True,
#    'start_byte': 51060,
#    'token': '</Tr>'},
#   {'end_byte': 51097,
#    'html_token': True,
#    'start_byte': 51066,
#    'token': '<Tr>'},
#   {'end_byte': 51127,
#    'html_token': True,
#    'start_byte': 51098,
#    'token': '<Td>'},
#   {'end_byte': 51181,
#    'html_token': False,
#    'start_byte': 51175,
#    'token': 'number'},
#   {'end_byte': 51187,
#    'html_token': False,
#    'start_byte': 51183,
#    'token': 'sign'},
#   {'end_byte': 51188, 'html_token': False, 'start_byte': 51187, 'token': ','},
#   {'end_byte': 51194,
#    'html_token': False,
#    'start_byte': 51189,
#    'token': 'pound'},
#   {'end_byte': 51195, 'html_token': False, 'start_byte': 51194, 'token': ','},
#   {'end_byte': 51200,
#    'html_token': False,
#    'start_byte': 51196,
#    'token': 'hash'},
#   {'end_byte': 51209,
#    'html_token': True,
#    'start_byte': 51204,
#    'token': '</Td>'},
#   {'end_byte': 51314,
#    'html_token': True,
#    'start_byte': 51210,
#    'token': '<Td>'},
#   {'end_byte': 51315, 'html_token': False, 'start_byte': 51314, 'token': '#'},
#   {'end_byte': 51320,
#    'html_token': True,
#    'start_byte': 51315,
#    'token': '</Td>'},
#   {'end_byte': 51326,
#    'html_token': True,
#    'start_byte': 51321,
#    'token': '</Tr>'},
#   {'end_byte': 51358,
#    'html_token': True,
#    'start_byte': 51327,
#    'token': '<Tr>'},
#   {'end_byte': 51388,
#    'html_token': True,
#    'start_byte': 51359,
#    'token': '<Td>'},
#   {'end_byte': 51442,
#    'html_token': False,
#    'start_byte': 51436,
#    'token': 'numero'},
#   {'end_byte': 51447,
#    'html_token': False,
#    'start_byte': 51443,
#    'token': 'sign'},
#   {'end_byte': 51456,
#    'html_token': True,
#    'start_byte': 51451,
#    'token': '</Td>'},
#   {'end_byte': 51561,
#    'html_token': True,
#    'start_byte': 51457,
#    'token': '<Td>'},
#   {'end_byte': 51564, 'html_token': False, 'start_byte': 51561, 'token': 'No'},
#   {'end_byte': 51569,
#    'html_token': True,
#    'start_byte': 51564,
#    'token': '</Td>'},
#   {'end_byte': 51575,
#    'html_token': True,
#    'start_byte': 51570,
#    'token': '</Tr>'},
#   {'end_byte': 51607,
#    'html_token': True,
#    'start_byte': 51576,
#    'token': '<Tr>'},
#   {'end_byte': 51637,
#    'html_token': True,
#    'start_byte': 51608,
#    'token': '<Td>'},
#   {'end_byte': 51681,
#    'html_token': False,
#    'start_byte': 51675,
#    'token': 'obelus'},
#   {'end_byte': 51690,
#    'html_token': True,
#    'start_byte': 51685,
#    'token': '</Td>'},
#   {'end_byte': 51795,
#    'html_token': True,
#    'start_byte': 51691,
#    'token': '<Td>'},
#   {'end_byte': 51797, 'html_token': False, 'start_byte': 51795, 'token': '÷'},
#   {'end_byte': 51802,
#    'html_token': True,
#    'start_byte': 51797,
#    'token': '</Td>'},
#   {'end_byte': 51808,
#    'html_token': True,
#    'start_byte': 51803,
#    'token': '</Tr>'},
#   {'end_byte': 51840,
#    'html_token': True,
#    'start_byte': 51809,
#    'token': '<Tr>'},
#   {'end_byte': 51870,
#    'html_token': True,
#    'start_byte': 51841,
#    'token': '<Td>'},
#   {'end_byte': 51948,
#    'html_token': False,
#    'start_byte': 51934,
#    'token': 'multiplication'},
#   {'end_byte': 51953,
#    'html_token': False,
#    'start_byte': 51949,
#    'token': 'sign'},
#   {'end_byte': 51962,
#    'html_token': True,
#    'start_byte': 51957,
#    'token': '</Td>'},
#   {'end_byte': 52067,
#    'html_token': True,
#    'start_byte': 51963,
#    'token': '<Td>'},
#   {'end_byte': 52069, 'html_token': False, 'start_byte': 52067, 'token': '×'},
#   {'end_byte': 52074,
#    'html_token': True,
#    'start_byte': 52069,
#    'token': '</Td>'},
#   {'end_byte': 52080,
#    'html_token': True,
#    'start_byte': 52075,
#    'token': '</Tr>'},
#   {'end_byte': 52112,
#    'html_token': True,
#    'start_byte': 52081,
#    'token': '<Tr>'},
#   {'end_byte': 52142,
#    'html_token': True,
#    'start_byte': 52113,
#    'token': '<Td>'},
#   {'end_byte': 52209,
#    'html_token': False,
#    'start_byte': 52202,
#    'token': 'ordinal'},
#   {'end_byte': 52219,
#    'html_token': False,
#    'start_byte': 52210,
#    'token': 'indicator'},
#   {'end_byte': 52228,
#    'html_token': True,
#    'start_byte': 52223,
#    'token': '</Td>'},
#   {'end_byte': 52333,
#    'html_token': True,
#    'start_byte': 52229,
#    'token': '<Td>'},
#   {'end_byte': 52335, 'html_token': False, 'start_byte': 52333, 'token': 'o'},
#   {'end_byte': 52338, 'html_token': False, 'start_byte': 52336, 'token': 'a'},
#   {'end_byte': 52343,
#    'html_token': True,
#    'start_byte': 52338,
#    'token': '</Td>'},
#   {'end_byte': 52349,
#    'html_token': True,
#    'start_byte': 52344,
#    'token': '</Tr>'},
#   {'end_byte': 52381,
#    'html_token': True,
#    'start_byte': 52350,
#    'token': '<Tr>'},
#   {'end_byte': 52411,
#    'html_token': True,
#    'start_byte': 52382,
#    'token': '<Td>'},
#   {'end_byte': 52468,
#    'html_token': False,
#    'start_byte': 52461,
#    'token': 'percent'},
#   {'end_byte': 52473, 'html_token': False, 'start_byte': 52472, 'token': ','},
#   {'end_byte': 52521,
#    'html_token': False,
#    'start_byte': 52518,
#    'token': 'per'},
#   {'end_byte': 52525,
#    'html_token': False,
#    'start_byte': 52522,
#    'token': 'mil'},
#   {'end_byte': 52534,
#    'html_token': True,
#    'start_byte': 52529,
#    'token': '</Td>'},
#   {'end_byte': 52639,
#    'html_token': True,
#    'start_byte': 52535,
#    'token': '<Td>'},
#   {'end_byte': 52642, 'html_token': False, 'start_byte': 52641, 'token': '%'},
#   {'end_byte': 52646, 'html_token': False, 'start_byte': 52643, 'token': '‰'},
#   {'end_byte': 52651,
#    'html_token': True,
#    'start_byte': 52646,
#    'token': '</Td>'},
#   {'end_byte': 52657,
#    'html_token': True,
#    'start_byte': 52652,
#    'token': '</Tr>'},
#   {'end_byte': 52689,
#    'html_token': True,
#    'start_byte': 52658,
#    'token': '<Tr>'},
#   {'end_byte': 52719,
#    'html_token': True,
#    'start_byte': 52690,
#    'token': '<Td>'},
#   {'end_byte': 52789,
#    'html_token': False,
#    'start_byte': 52785,
#    'token': 'plus'},
#   {'end_byte': 52793,
#    'html_token': False,
#    'start_byte': 52790,
#    'token': 'and'},
#   {'end_byte': 52799,
#    'html_token': False,
#    'start_byte': 52794,
#    'token': 'minus'},
#   {'end_byte': 52808,
#    'html_token': True,
#    'start_byte': 52803,
#    'token': '</Td>'},
#   {'end_byte': 52913,
#    'html_token': True,
#    'start_byte': 52809,
#    'token': '<Td>'},
#   {'end_byte': 52914, 'html_token': False, 'start_byte': 52913, 'token': '+'},
#   {'end_byte': 52918, 'html_token': False, 'start_byte': 52915, 'token': '−'},
#   {'end_byte': 52923,
#    'html_token': True,
#    'start_byte': 52918,
#    'token': '</Td>'},
#   {'end_byte': 52929,
#    'html_token': True,
#    'start_byte': 52924,
#    'token': '</Tr>'},
#   {'end_byte': 52961,
#    'html_token': True,
#    'start_byte': 52930,
#    'token': '<Tr>'},
#   {'end_byte': 52991,
#    'html_token': True,
#    'start_byte': 52962,
#    'token': '<Td>'},
#   {'end_byte': 53045,
#    'html_token': False,
#    'start_byte': 53039,
#    'token': 'equals'},
#   {'end_byte': 53050,
#    'html_token': False,
#    'start_byte': 53046,
#    'token': 'sign'},
#   {'end_byte': 53059,
#    'html_token': True,
#    'start_byte': 53054,
#    'token': '</Td>'},
#   {'end_byte': 53164,
#    'html_token': True,
#    'start_byte': 53060,
#    'token': '<Td>'},
#   {'end_byte': 53165, 'html_token': False, 'start_byte': 53164, 'token': '='},
#   {'end_byte': 53170,
#    'html_token': True,
#    'start_byte': 53165,
#    'token': '</Td>'},
#   {'end_byte': 53176,
#    'html_token': True,
#    'start_byte': 53171,
#    'token': '</Tr>'},
#   {'end_byte': 53208,
#    'html_token': True,
#    'start_byte': 53177,
#    'token': '<Tr>'},
#   {'end_byte': 53238,
#    'html_token': True,
#    'start_byte': 53209,
#    'token': '<Td>'},
#   {'end_byte': 53291,
#    'html_token': False,
#    'start_byte': 53286,
#    'token': 'basis'},
#   {'end_byte': 53297,
#    'html_token': False,
#    'start_byte': 53292,
#    'token': 'point'},
#   {'end_byte': 53306,
#    'html_token': True,
#    'start_byte': 53301,
#    'token': '</Td>'},
#   {'end_byte': 53411,
#    'html_token': True,
#    'start_byte': 53307,
#    'token': '<Td>'},
#   {'end_byte': 53414, 'html_token': False, 'start_byte': 53411, 'token': '‱'},
#   {'end_byte': 53419,
#    'html_token': True,
#    'start_byte': 53414,
#    'token': '</Td>'},
#   {'end_byte': 53425,
#    'html_token': True,
#    'start_byte': 53420,
#    'token': '</Tr>'},
#   {'end_byte': 53457,
#    'html_token': True,
#    'start_byte': 53426,
#    'token': '<Tr>'},
#   {'end_byte': 53487,
#    'html_token': True,
#    'start_byte': 53458,
#    'token': '<Td>'},
#   {'end_byte': 53534,
#    'html_token': False,
#    'start_byte': 53527,
#    'token': 'pilcrow'},
#   {'end_byte': 53543,
#    'html_token': True,
#    'start_byte': 53538,
#    'token': '</Td>'},
#   {'end_byte': 53648,
#    'html_token': True,
#    'start_byte': 53544,
#    'token': '<Td>'},
#   {'end_byte': 53650, 'html_token': False, 'start_byte': 53648, 'token': '¶'},
#   {'end_byte': 53655,
#    'html_token': True,
#    'start_byte': 53650,
#    'token': '</Td>'},
#   {'end_byte': 53661,
#    'html_token': True,
#    'start_byte': 53656,
#    'token': '</Tr>'},
#   {'end_byte': 53693,
#    'html_token': True,
#    'start_byte': 53662,
#    'token': '<Tr>'},
#   {'end_byte': 53723,
#    'html_token': True,
#    'start_byte': 53694,
#    'token': '<Td>'},
#   {'end_byte': 53782,
#    'html_token': False,
#    'start_byte': 53777,
#    'token': 'prime'},
#   {'end_byte': 53791,
#    'html_token': True,
#    'start_byte': 53786,
#    'token': '</Td>'},
#   {'end_byte': 53896,
#    'html_token': True,
#    'start_byte': 53792,
#    'token': '<Td>'},
#   {'end_byte': 53899, 'html_token': False, 'start_byte': 53896, 'token': '′'},
#   {'end_byte': 53934, 'html_token': False, 'start_byte': 53931, 'token': "''"},
#   {'end_byte': 53969,
#    'html_token': False,
#    'start_byte': 53966,
#    'token': '′′′'},
#   {'end_byte': 53974,
#    'html_token': True,
#    'start_byte': 53969,
#    'token': '</Td>'},
#   {'end_byte': 53980,
#    'html_token': True,
#    'start_byte': 53975,
#    'token': '</Tr>'},
#   {'end_byte': 54012,
#    'html_token': True,
#    'start_byte': 53981,
#    'token': '<Tr>'},
#   {'end_byte': 54042,
#    'html_token': True,
#    'start_byte': 54013,
#    'token': '<Td>'},
#   {'end_byte': 54099,
#    'html_token': False,
#    'start_byte': 54092,
#    'token': 'section'},
#   {'end_byte': 54104,
#    'html_token': False,
#    'start_byte': 54100,
#    'token': 'sign'},
#   {'end_byte': 54113,
#    'html_token': True,
#    'start_byte': 54108,
#    'token': '</Td>'},
#   {'end_byte': 54218,
#    'html_token': True,
#    'start_byte': 54114,
#    'token': '<Td>'},
#   {'end_byte': 54220, 'html_token': False, 'start_byte': 54218, 'token': '§'},
#   {'end_byte': 54225,
#    'html_token': True,
#    'start_byte': 54220,
#    'token': '</Td>'},
#   {'end_byte': 54231,
#    'html_token': True,
#    'start_byte': 54226,
#    'token': '</Tr>'},
#   {'end_byte': 54263,
#    'html_token': True,
#    'start_byte': 54232,
#    'token': '<Tr>'},
#   {'end_byte': 54293,
#    'html_token': True,
#    'start_byte': 54264,
#    'token': '<Td>'},
#   {'end_byte': 54334,
#    'html_token': False,
#    'start_byte': 54329,
#    'token': 'tilde'},
#   {'end_byte': 54343,
#    'html_token': True,
#    'start_byte': 54338,
#    'token': '</Td>'},
#   {'end_byte': 54448,
#    'html_token': True,
#    'start_byte': 54344,
#    'token': '<Td>'},
#   {'end_byte': 54449, 'html_token': False, 'start_byte': 54448, 'token': '~'},
#   {'end_byte': 54454,
#    'html_token': True,
#    'start_byte': 54449,
#    'token': '</Td>'},
#   {'end_byte': 54460,
#    'html_token': True,
#    'start_byte': 54455,
#    'token': '</Tr>'},
#   {'end_byte': 54492,
#    'html_token': True,
#    'start_byte': 54461,
#    'token': '<Tr>'},
#   {'end_byte': 54522,
#    'html_token': True,
#    'start_byte': 54493,
#    'token': '<Td>'},
#   {'end_byte': 54578,
#    'html_token': False,
#    'start_byte': 54568,
#    'token': 'underscore'},
#   {'end_byte': 54579, 'html_token': False, 'start_byte': 54578, 'token': ','},
#   {'end_byte': 54591,
#    'html_token': False,
#    'start_byte': 54580,
#    'token': 'understrike'},
#   {'end_byte': 54600,
#    'html_token': True,
#    'start_byte': 54595,
#    'token': '</Td>'},
#   {'end_byte': 54705,
#    'html_token': True,
#    'start_byte': 54601,
#    'token': '<Td>'},
#   {'end_byte': 54754, 'html_token': False, 'start_byte': 54753, 'token': '_'},
#   {'end_byte': 54766,
#    'html_token': True,
#    'start_byte': 54761,
#    'token': '</Td>'},
#   {'end_byte': 54772,
#    'html_token': True,
#    'start_byte': 54767,
#    'token': '</Tr>'},
#   {'end_byte': 54804,
#    'html_token': True,
#    'start_byte': 54773,
#    'token': '<Tr>'},
#   {'end_byte': 54834,
#    'html_token': True,
#    'start_byte': 54805,
#    'token': '<Td>'},
#   {'end_byte': 54892,
#    'html_token': False,
#    'start_byte': 54884,
#    'token': 'vertical'},
#   {'end_byte': 54896,
#    'html_token': False,
#    'start_byte': 54893,
#    'token': 'bar'},
#   {'end_byte': 54897, 'html_token': False, 'start_byte': 54896, 'token': ','},
#   {'end_byte': 54902,
#    'html_token': False,
#    'start_byte': 54898,
#    'token': 'pipe'},
#   {'end_byte': 54903, 'html_token': False, 'start_byte': 54902, 'token': ','},
#   {'end_byte': 54910,
#    'html_token': False,
# ...
#   {'end_byte': 67382, 'html_token': False, 'start_byte': 67380, 'token': 'it'},
#   {'end_byte': 67385, 'html_token': False, 'start_byte': 67383, 'token': 'is'},
#   {'end_byte': 67390,
#    'html_token': False,
#    'start_byte': 67386,
#    'token': 'used'},
#   {'end_byte': 67393, 'html_token': False, 'start_byte': 67391, 'token': 'in'},
#   {'end_byte': 67453,
#    'html_token': False,
#    'start_byte': 67442,
#    'token': 'mathematics'},
#   {'end_byte': 67461,
#    'html_token': False,
#    'start_byte': 67458,
#    'token': 'and'},
#   {'end_byte': 67515,
#    'html_token': False,
#    'start_byte': 67506,
#    'token': 'shorthand'},
#   {'end_byte': 67520, 'html_token': False, 'start_byte': 67519, 'token': '.'},
#   {'end_byte': 67523, 'html_token': False, 'start_byte': 67521, 'token': 'It'},
#   {'end_byte': 67526, 'html_token': False, 'start_byte': 67524, 'token': 'is'},
#   {'end_byte': 67540,
#    'html_token': False,
#    'start_byte': 67527,
#    'token': 'complementary'},
#   {'end_byte': 67543, 'html_token': False, 'start_byte': 67541, 'token': 'to'},
#   {'end_byte': 67634, 'html_token': False, 'start_byte': 67633, 'token': 'U'},
#   {'end_byte': 67635, 'html_token': False, 'start_byte': 67634, 'token': '+'},
#   {'end_byte': 67639,
#    'html_token': False,
#    'start_byte': 67635,
#    'token': '2235'},
#   {'end_byte': 67686, 'html_token': False, 'start_byte': 67683, 'token': '∵'},
#   {'end_byte': 67779,
#    'html_token': False,
#    'start_byte': 67772,
#    'token': 'because'},
#   {'end_byte': 67788, 'html_token': False, 'start_byte': 67787, 'token': '('},
#   {'end_byte': 67792,
#    'html_token': False,
#    'start_byte': 67788,
#    'token': 'HTML'},
#   {'end_byte': 67805, 'html_token': False, 'start_byte': 67800, 'token': '&'},
#   {'end_byte': 67806, 'html_token': False, 'start_byte': 67805, 'token': '#'},
#   {'end_byte': 67810,
#    'html_token': False,
#    'start_byte': 67806,
#    'token': '8757'},
#   {'end_byte': 67811, 'html_token': False, 'start_byte': 67810, 'token': ';'},
#   {'end_byte': 67819, 'html_token': False, 'start_byte': 67818, 'token': ')'},
#   {'end_byte': 67820, 'html_token': False, 'start_byte': 67819, 'token': '.'},
#   {'end_byte': 67824,
#    'html_token': True,
#    'start_byte': 67820,
#    'token': '</P>'},
#   {'end_byte': 67828, 'html_token': True, 'start_byte': 67825, 'token': '<P>'},
#   {'end_byte': 67832,
#    'html_token': True,
#    'start_byte': 67828,
#    'token': '</P>'},
#   {'end_byte': 67921,
#    'html_token': True,
#    'start_byte': 67917,
#    'token': '<H2>'},
#   {'end_byte': 67929,
#    'html_token': False,
#    'start_byte': 67921,
#    'token': 'Contents'},
#   {'end_byte': 67934,
#    'html_token': True,
#    'start_byte': 67929,
#    'token': '</H2>'},
#   {'end_byte': 67962, 'html_token': False, 'start_byte': 67961, 'token': '('},
#   {'end_byte': 68015,
#    'html_token': False,
#    'start_byte': 68011,
#    'token': 'hide'},
#   {'end_byte': 68020, 'html_token': False, 'start_byte': 68019, 'token': ')'},
#   {'end_byte': 68040,
#    'html_token': True,
#    'start_byte': 68036,
#    'token': '<Ul>'},
#   {'end_byte': 68077,
#    'html_token': True,
#    'start_byte': 68041,
#    'token': '<Li>'},
#   {'end_byte': 68121, 'html_token': False, 'start_byte': 68120, 'token': '1'},
#   {'end_byte': 68158,
#    'html_token': False,
#    'start_byte': 68151,
#    'token': 'History'},
#   {'end_byte': 68174,
#    'html_token': True,
#    'start_byte': 68169,
#    'token': '</Li>'},
#   {'end_byte': 68211,
#    'html_token': True,
#    'start_byte': 68175,
#    'token': '<Li>'},
#   {'end_byte': 68262, 'html_token': False, 'start_byte': 68261, 'token': '2'},
#   {'end_byte': 68299,
#    'html_token': False,
#    'start_byte': 68292,
#    'token': 'Example'},
#   {'end_byte': 68302, 'html_token': False, 'start_byte': 68300, 'token': 'of'},
#   {'end_byte': 68306,
#    'html_token': False,
#    'start_byte': 68303,
#    'token': 'use'},
#   {'end_byte': 68322,
#    'html_token': True,
#    'start_byte': 68317,
#    'token': '</Li>'},
#   {'end_byte': 68359,
#    'html_token': True,
#    'start_byte': 68323,
#    'token': '<Li>'},
#   {'end_byte': 68409, 'html_token': False, 'start_byte': 68408, 'token': '3'},
#   {'end_byte': 68446,
#    'html_token': False,
#    'start_byte': 68439,
#    'token': 'Related'},
#   {'end_byte': 68452,
#    'html_token': False,
#    'start_byte': 68447,
#    'token': 'signs'},
#   {'end_byte': 68468,
#    'html_token': True,
#    'start_byte': 68463,
#    'token': '</Li>'},
#   {'end_byte': 68505,
#    'html_token': True,
#    'start_byte': 68469,
#    'token': '<Li>'},
#   {'end_byte': 68550, 'html_token': False, 'start_byte': 68549, 'token': '4'},
#   {'end_byte': 68583,
#    'html_token': False,
#    'start_byte': 68580,
#    'token': 'See'},
#   {'end_byte': 68588,
#    'html_token': False,
#    'start_byte': 68584,
#    'token': 'also'},
#   {'end_byte': 68604,
#    'html_token': True,
#    'start_byte': 68599,
#    'token': '</Li>'},
#   {'end_byte': 68641,
#    'html_token': True,
#    'start_byte': 68605,
#    'token': '<Li>'},
#   {'end_byte': 68688, 'html_token': False, 'start_byte': 68687, 'token': '5'},
#   {'end_byte': 68728,
#    'html_token': False,
#    'start_byte': 68718,
#    'token': 'References'},
#   {'end_byte': 68744,
#    'html_token': True,
#    'start_byte': 68739,
#    'token': '</Li>'},
#   {'end_byte': 68750,
#    'html_token': True,
#    'start_byte': 68745,
#    'token': '</Ul>'},
#   {'end_byte': 68761, 'html_token': True, 'start_byte': 68758, 'token': '<P>'},
#   {'end_byte': 68765,
#    'html_token': True,
#    'start_byte': 68761,
#    'token': '</P>'},
#   {'end_byte': 68770,
#    'html_token': True,
#    'start_byte': 68766,
#    'token': '<H2>'},
#   {'end_byte': 68816,
#    'html_token': False,
#    'start_byte': 68809,
#    'token': 'History'},
#   {'end_byte': 68890, 'html_token': False, 'start_byte': 68889, 'token': '('},
#   {'end_byte': 69005,
#    'html_token': False,
#    'start_byte': 69001,
#    'token': 'edit'},
#   {'end_byte': 69047, 'html_token': False, 'start_byte': 69046, 'token': ')'},
#   {'end_byte': 69066,
#    'html_token': True,
#    'start_byte': 69061,
#    'token': '</H2>'},
#   {'end_byte': 69070, 'html_token': True, 'start_byte': 69067, 'token': '<P>'},
#   {'end_byte': 69079,
#    'html_token': False,
#    'start_byte': 69070,
#    'token': 'According'},
#   {'end_byte': 69082, 'html_token': False, 'start_byte': 69080, 'token': 'to'},
#   {'end_byte': 69143,
#    'html_token': False,
#    'start_byte': 69137,
#    'token': 'Cajori'},
#   {'end_byte': 69148, 'html_token': False, 'start_byte': 69147, 'token': ','},
#   {'end_byte': 69153, 'html_token': False, 'start_byte': 69152, 'token': 'A'},
#   {'end_byte': 69161,
#    'html_token': False,
#    'start_byte': 69154,
#    'token': 'History'},
#   {'end_byte': 69164, 'html_token': False, 'start_byte': 69162, 'token': 'of'},
#   {'end_byte': 69177,
#    'html_token': False,
#    'start_byte': 69165,
#    'token': 'Mathematical'},
#   {'end_byte': 69187,
#    'html_token': False,
#    'start_byte': 69178,
#    'token': 'Notations'},
#   {'end_byte': 69188, 'html_token': False, 'start_byte': 69187, 'token': ','},
#   {'end_byte': 69247,
#    'html_token': False,
#    'start_byte': 69241,
#    'token': 'Johann'},
#   {'end_byte': 69252,
#    'html_token': False,
#    'start_byte': 69248,
#    'token': 'Rahn'},
#   {'end_byte': 69261,
#    'html_token': False,
#    'start_byte': 69257,
#    'token': 'used'},
#   {'end_byte': 69266,
#    'html_token': False,
#    'start_byte': 69262,
#    'token': 'both'},
#   {'end_byte': 69270,
#    'html_token': False,
#    'start_byte': 69267,
#    'token': 'the'},
#   {'end_byte': 69283,
#    'html_token': False,
#    'start_byte': 69274,
#    'token': 'therefore'},
#   {'end_byte': 69291,
#    'html_token': False,
#    'start_byte': 69288,
#    'token': 'and'},
#   {'end_byte': 69302,
#    'html_token': False,
#    'start_byte': 69295,
#    'token': 'because'},
#   {'end_byte': 69312,
#    'html_token': False,
#    'start_byte': 69307,
#    'token': 'signs'},
#   {'end_byte': 69315, 'html_token': False, 'start_byte': 69313, 'token': 'to'},
#   {'end_byte': 69320,
#    'html_token': False,
#    'start_byte': 69316,
#    'token': 'mean'},
#   {'end_byte': 69327, 'html_token': False, 'start_byte': 69321, 'token': '``'},
#   {'end_byte': 69336,
#    'html_token': False,
#    'start_byte': 69327,
#    'token': 'therefore'},
#   {'end_byte': 69342, 'html_token': False, 'start_byte': 69336, 'token': "''"},
#   {'end_byte': 69343, 'html_token': False, 'start_byte': 69342, 'token': ';'},
#   {'end_byte': 69346, 'html_token': False, 'start_byte': 69344, 'token': 'in'},
#   {'end_byte': 69350,
#    'html_token': False,
#    'start_byte': 69347,
#    'token': 'the'},
#   {'end_byte': 69357,
#    'html_token': False,
#    'start_byte': 69351,
#    'token': 'German'},
#   {'end_byte': 69365,
#    'html_token': False,
#    'start_byte': 69358,
#    'token': 'edition'},
#   {'end_byte': 69368, 'html_token': False, 'start_byte': 69366, 'token': 'of'},
#   {'end_byte': 69380,
#    'html_token': False,
#    'start_byte': 69372,
#    'token': 'Teutsche'},
#   {'end_byte': 69388,
#    'html_token': False,
#    'start_byte': 69381,
#    'token': 'Algebra'},
#   ...],
#  'document_url': 'https://en.wikipedia.org//w/index.php?title=Therefore_sign&amp;oldid=815234923',
#  'example_id': 6915606477668963399,
#  'long_answer_candidates': [{'end_token': 808,
#    'start_token': 14,
#    'top_level': True},
#   {'end_token': 20, 'start_token': 15, 'top_level': False},
#   {'end_token': 26, 'start_token': 20, 'top_level': False},
#   {'end_token': 197, 'start_token': 26, 'top_level': False},
#   {'end_token': 195, 'start_token': 28, 'top_level': False},
#   {'end_token': 34, 'start_token': 29, 'top_level': False},
#   {'end_token': 43, 'start_token': 34, 'top_level': False},
#   {'end_token': 58, 'start_token': 43, 'top_level': False},
#   {'end_token': 66, 'start_token': 58, 'top_level': False},
#   {'end_token': 76, 'start_token': 66, 'top_level': False},
#   {'end_token': 87, 'start_token': 76, 'top_level': False},
#   {'end_token': 99, 'start_token': 87, 'top_level': False},
#   {'end_token': 108, 'start_token': 99, 'top_level': False},
#   {'end_token': 119, 'start_token': 108, 'top_level': False},
#   {'end_token': 130, 'start_token': 119, 'top_level': False},
#   {'end_token': 138, 'start_token': 130, 'top_level': False},
#   {'end_token': 148, 'start_token': 138, 'top_level': False},
#   {'end_token': 157, 'start_token': 148, 'top_level': False},
#   {'end_token': 173, 'start_token': 157, 'top_level': False},
#   {'end_token': 181, 'start_token': 173, 'top_level': False},
#   {'end_token': 194, 'start_token': 181, 'top_level': False},
#   {'end_token': 223, 'start_token': 197, 'top_level': False},
#   {'end_token': 221, 'start_token': 199, 'top_level': False},
#   {'end_token': 206, 'start_token': 200, 'top_level': False},
#   {'end_token': 213, 'start_token': 206, 'top_level': False},
#   {'end_token': 220, 'start_token': 213, 'top_level': False},
#   {'end_token': 491, 'start_token': 223, 'top_level': False},
#   {'end_token': 489, 'start_token': 225, 'top_level': False},
#   {'end_token': 232, 'start_token': 226, 'top_level': False},
#   {'end_token': 240, 'start_token': 232, 'top_level': False},
#   {'end_token': 248, 'start_token': 240, 'top_level': False},
#   {'end_token': 257, 'start_token': 248, 'top_level': False},
#   {'end_token': 265, 'start_token': 257, 'top_level': False},
#   {'end_token': 272, 'start_token': 265, 'top_level': False},
#   {'end_token': 279, 'start_token': 272, 'top_level': False},
#   {'end_token': 288, 'start_token': 279, 'top_level': False},
#   {'end_token': 296, 'start_token': 288, 'top_level': False},
#   {'end_token': 305, 'start_token': 296, 'top_level': False},
#   {'end_token': 315, 'start_token': 305, 'top_level': False},
#   {'end_token': 325, 'start_token': 315, 'top_level': False},
#   {'end_token': 338, 'start_token': 325, 'top_level': False},
#   {'end_token': 351, 'start_token': 338, 'top_level': False},
#   {'end_token': 360, 'start_token': 351, 'top_level': False},
#   {'end_token': 368, 'start_token': 360, 'top_level': False},
#   {'end_token': 377, 'start_token': 368, 'top_level': False},
#   {'end_token': 387, 'start_token': 377, 'top_level': False},
#   {'end_token': 399, 'start_token': 387, 'top_level': False},
#   {'end_token': 410, 'start_token': 399, 'top_level': False},
#   {'end_token': 419, 'start_token': 410, 'top_level': False},
#   {'end_token': 428, 'start_token': 419, 'top_level': False},
#   {'end_token': 436, 'start_token': 428, 'top_level': False},
#   {'end_token': 446, 'start_token': 436, 'top_level': False},
#   {'end_token': 455, 'start_token': 446, 'top_level': False},
#   {'end_token': 463, 'start_token': 455, 'top_level': False},
#   {'end_token': 473, 'start_token': 463, 'top_level': False},
#   {'end_token': 488, 'start_token': 473, 'top_level': False},
#   {'end_token': 548, 'start_token': 491, 'top_level': False},
#   {'end_token': 546, 'start_token': 493, 'top_level': False},
#   {'end_token': 500, 'start_token': 494, 'top_level': False},
#   {'end_token': 508, 'start_token': 500, 'top_level': False},
#   {'end_token': 519, 'start_token': 508, 'top_level': False},
#   {'end_token': 528, 'start_token': 519, 'top_level': False},
#   {'end_token': 537, 'start_token': 528, 'top_level': False},
#   {'end_token': 545, 'start_token': 537, 'top_level': False},
#   {'end_token': 655, 'start_token': 548, 'top_level': False},
#   {'end_token': 566, 'start_token': 550, 'top_level': False},
#   {'end_token': 556, 'start_token': 551, 'top_level': False},
#   {'end_token': 565, 'start_token': 556, 'top_level': False},
#   {'end_token': 653, 'start_token': 568, 'top_level': False},
#   {'end_token': 728, 'start_token': 655, 'top_level': False},
#   {'end_token': 726, 'start_token': 657, 'top_level': False},
#   {'end_token': 664, 'start_token': 658, 'top_level': False},
#   {'end_token': 672, 'start_token': 664, 'top_level': False},
#   {'end_token': 682, 'start_token': 672, 'top_level': False},
#   {'end_token': 692, 'start_token': 682, 'top_level': False},
#   {'end_token': 700, 'start_token': 692, 'top_level': False},
#   {'end_token': 709, 'start_token': 700, 'top_level': False},
#   {'end_token': 717, 'start_token': 709, 'top_level': False},
#   {'end_token': 725, 'start_token': 717, 'top_level': False},
#   {'end_token': 733, 'start_token': 728, 'top_level': False},
#   {'end_token': 754, 'start_token': 733, 'top_level': False},
#   {'end_token': 752, 'start_token': 735, 'top_level': False},
#   {'end_token': 747, 'start_token': 736, 'top_level': False},
#   {'end_token': 746, 'start_token': 737, 'top_level': False},
#   {'end_token': 761, 'start_token': 754, 'top_level': False},
#   {'end_token': 779, 'start_token': 761, 'top_level': False},
#   {'end_token': 777, 'start_token': 763, 'top_level': False},
#   {'end_token': 795, 'start_token': 779, 'top_level': False},
#   {'end_token': 788, 'start_token': 781, 'top_level': False},
#   {'end_token': 793, 'start_token': 788, 'top_level': False},
#   {'end_token': 807, 'start_token': 795, 'top_level': False},
#   {'end_token': 805, 'start_token': 797, 'top_level': False},
#   {'end_token': 925, 'start_token': 808, 'top_level': True},
#   {'end_token': 1116, 'start_token': 967, 'top_level': True},
#   {'end_token': 1131, 'start_token': 1124, 'top_level': True},
#   {'end_token': 1154, 'start_token': 1131, 'top_level': True},
#   {'end_token': 1139, 'start_token': 1132, 'top_level': False},
#   {'end_token': 1146, 'start_token': 1139, 'top_level': False},
#   {'end_token': 1153, 'start_token': 1146, 'top_level': False},
#   {'end_token': 1169, 'start_token': 1154, 'top_level': True},
#   {'end_token': 1162, 'start_token': 1155, 'top_level': False},
#   {'end_token': 1168, 'start_token': 1162, 'top_level': False},
#   {'end_token': 1230, 'start_token': 1197, 'top_level': True},
#   {'end_token': 1246, 'start_token': 1230, 'top_level': True},
#   {'end_token': 1271, 'start_token': 1246, 'top_level': True},
#   {'end_token': 1340, 'start_token': 1271, 'top_level': True},
#   {'end_token': 1394, 'start_token': 1340, 'top_level': True},
#   {'end_token': 1415, 'start_token': 1394, 'top_level': True},
#   {'end_token': 1481, 'start_token': 1415, 'top_level': True},
#   {'end_token': 1540, 'start_token': 1481, 'top_level': True}],
#  'question_text': 'what do the 3 dots mean in math',
#  'question_tokens': ['what', 'do', 'the', '3', 'dots', 'mean', 'in', 'math']}

# %%
def simplify_data(full_data):
    '''
    This function applies 
    
    '''

# %% [markdown]
# ## Filter For Retriever Evaluation
#
# For our evaluation purposes, we will only be utilizing questions that contain short answer or null answer types. Thus, we are excluding any questions that only have long or yes/no answers only.
#
# **Identifying Exclusions**
# The following field/value logic is used to identify short answer and no answer types.
# - len(short_answers) > 0  ## QUESTION: can there be more than one short answer??
# - yes_no_answer != 'NONE'
# - long_answer:

# %%
if (len(short_answers) == 0) & (yes_no_answer == 'NONE'): 'no_answer'
if (len(short_answers) > 0) & (yes_no_answer == 'NONE'): 'short_answer'

# %%
# !wget https://storage.cloud.google.com/natural_questions/v1.0-simplified/simplified-nq-train.jsonl.gz

# %%
import urllib

# %%
url = 'https://storage.cloud.google.com/natural_questions/v1.0-simplified/simplified-nq-train.jsonl.gz'
url = 'https://00e9e64bac5fa14003581c8a55581c7f65d2b932543c109661-apidata.googleusercontent.com/download/storage/v1/b/natural_questions/o/v1.0-simplified%2Fsimplified-nq-train.jsonl.gz?qk=AD5uMEuhixdPI4RVW-Vp92Ctehkh0xgrPCBAuMKIT0EF0xHiLeqaOuQaFYTvLatFxlhRkylGfZEb0PpZwgda203f1EeK6IxrdoFKK3xDVZMsUqpF852yTnjj_aQmlM0NvLDMjoDBfza2N6oAnx3wdznwXZ-WJW0WfudIQT8tkBzo-Tt3mVvD5To5LjmdUI7a35GILzS4fmSix9tOGbaEVw4sSo3wSikMYNPfoBJU6Nfprr2VJjg_fuqBPfxqTciahIHBCyRKTuJVAxy40AxZGOHHBYbfmUcqfhTyS0IfbYy0pylvprptUZpivxRKkSn1dFxMXtIpV3sBh3D1Q04Q8I9Ygt2TX4kEIO6-DEtM3--odSgWKoc3sWRB7Vwv1nM5JxXdM049pI4tb3VFB7zch4_VfV0DggLtTYHnf5xsKOewtCxu8yvmhN0oshKo21ijgl8u6DvWi6HeEYT6ixvFbQRyB52hZmlxeegZh5dWvyeoGyQmxpGQLFWAGI7Lsst3232mTUBmE_H0Tj62YYGyc5kUQyqjkLMwiYqOK-dFdfAyW8yCKN2dg-XkjqoMZTg_7WaP0tnJ9cBrMD27n5Y3zSyPVjhkFk9gnSZOiJN14KUHpfNBVoprgkaXygyQWahv-69oa6qB2cjHEYmFgoPa24r_OPLPX9MtD1JHT5U8R4MsKveg5-RCPkd4h_Ot06YzoXsKsbJk_xNGwGX5ynjcrudEfrHpyACEfqN0aTGd1yZfhuBNS5ng0IEdjfvtQDzJyzwoKRjoqg9QQcUUAvHwMF11cWxUisQgIP6E0_lgHmsWITygeUeXi8pxR-XVzPFVOEO9NPCl4bZEPkTh9NZA1dBhjppmFv-LfQ&isca=1'

urllib.request.urlretrieve(url, 'temp/TESTING.jsonl.gz')
# Out:
# -------------------------------------------------------------------------
# KeyboardInterrupt                       Traceback (most recent call last)
# <ipython-input-6-7f96d72ef02f> in <module>
#       2 url = 'https://00e9e64bac5fa14003581c8a55581c7f65d2b932543c109661-apidata.googleusercontent.com/download/storage/v1/b/natural_questions/o/v1.0-simplified%2Fsimplified-nq-train.jsonl.gz?qk=AD5uMEuhixdPI4RVW-Vp92Ctehkh0xgrPCBAuMKIT0EF0xHiLeqaOuQaFYTvLatFxlhRkylGfZEb0PpZwgda203f1EeK6IxrdoFKK3xDVZMsUqpF852yTnjj_aQmlM0NvLDMjoDBfza2N6oAnx3wdznwXZ-WJW0WfudIQT8tkBzo-Tt3mVvD5To5LjmdUI7a35GILzS4fmSix9tOGbaEVw4sSo3wSikMYNPfoBJU6Nfprr2VJjg_fuqBPfxqTciahIHBCyRKTuJVAxy40AxZGOHHBYbfmUcqfhTyS0IfbYy0pylvprptUZpivxRKkSn1dFxMXtIpV3sBh3D1Q04Q8I9Ygt2TX4kEIO6-DEtM3--odSgWKoc3sWRB7Vwv1nM5JxXdM049pI4tb3VFB7zch4_VfV0DggLtTYHnf5xsKOewtCxu8yvmhN0oshKo21ijgl8u6DvWi6HeEYT6ixvFbQRyB52hZmlxeegZh5dWvyeoGyQmxpGQLFWAGI7Lsst3232mTUBmE_H0Tj62YYGyc5kUQyqjkLMwiYqOK-dFdfAyW8yCKN2dg-XkjqoMZTg_7WaP0tnJ9cBrMD27n5Y3zSyPVjhkFk9gnSZOiJN14KUHpfNBVoprgkaXygyQWahv-69oa6qB2cjHEYmFgoPa24r_OPLPX9MtD1JHT5U8R4MsKveg5-RCPkd4h_Ot06YzoXsKsbJk_xNGwGX5ynjcrudEfrHpyACEfqN0aTGd1yZfhuBNS5ng0IEdjfvtQDzJyzwoKRjoqg9QQcUUAvHwMF11cWxUisQgIP6E0_lgHmsWITygeUeXi8pxR-XVzPFVOEO9NPCl4bZEPkTh9NZA1dBhjppmFv-LfQ&isca=1'
#       3
# ----> 4 urllib.request.urlretrieve(url, 'temp/TESTING.jsonl.gz')
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/http/client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/http/client.py in readinto(self, b)
#     496         # connection, and the user is reading more bytes than will be provided
#     497         # (for example, reading in 1k chunks)
# --> 498         n = self.fp.readinto(b)
#     499         if not n and b:
#     500             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !pwd
# Out:
# /Users/areed/Documents/FFL Research/FF14/qa_retriever_evaluation/notebooks

# %%
'hello.py.gz'[:-3]
# Out:
# 'hello.py'

# %%
import os

# %%
os.g
