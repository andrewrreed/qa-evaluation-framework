# %% [markdown]
# # Natural Questions - Elastic Search Setup for Retriever Evaluation

# %%
import re
import json
import pickle
import logging
import pandas as pd
from tqdm.notebook import tqdm
from elasticsearch import Elasticsearch

# %% [markdown]
# **Resources:**
# - https://towardsdatascience.com/getting-started-with-elasticsearch-in-python-c3598e718380

# %% [markdown]
# ## Connect to ElasticSearch

# %%
local_config = [{'host': 'localhost', 'port': 9200}]
es = Elasticsearch(local_config)

es.ping()
# Out:
# True

# %%
es.indices.get_alias('*')
# Out:
# {'nq_wiki_data': {'aliases': {}}, 'cases': {'aliases': {}}}

# %%
# Delete an index
#es.indices.delete(index='nq_wiki_data')
# Out:
# {'acknowledged': True}

# %% [markdown]
# ## Create and Load and Index

# %%
es_settings = {
    "mappings": {
        "dynamic": "strict",        
        "properties": {
            "document_title": {"type": "text"},
            "document_url": {"type": "text"},
            "document_text_clean": {"type": "text"}
            }
        }
    }

index_name = 'nq_wiki_data_test'

es.indices.create(index=index_name, body=es_settings, ignore=400)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'nq_wiki_data_test'}

# %%
file_path = '../data/eval_data/'
file_name = 'evidence_corpus.pkl'

with open(file_path+file_name, 'rb') as f:
    
    evidence_corpus = pickle.load(f)

# %%
evidence_corpus[0]
# Out:
# {'document_title': 'The_Mother_(How_I_Met_Your_Mother)',
#  'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Mother_(How_I_Met_Your_Mother)&amp;oldid=802354471',
#  'document_text_clean': "The Mother ( How I Met Your Mother ) - wikipedia  The Mother ( How I Met Your Mother )  Jump to : navigation , search    Tracy McConnell     How I Met Your Mother character     The Mother appearing in `` The Locket ''     First appearance   `` Lucky Penny ( unseen ) '' `` Something New '' ( seen )     Last appearance   `` Last Forever ''     Created by   Carter Bays Craig Thomas     Portrayed by   Cristin Milioti     Information     Aliases   The Mother     Gender   Female     Spouse ( s )   Ted Mosby     Significant other ( s )   Max ( deceased former boyfriend ) Louis ( ex-boyfriend )     Children   Penny Mosby ( daughter , born in 2015 , played by Lyndsy Fonseca ) Luke Mosby ( son , born in 2017 , played by David Henrie )     Nationality   American     Tracy McConnell , better known as `` The Mother '' , is the title character from the CBS television sitcom How I Met Your Mother . The show , narrated by Future Ted , tells the story of how Ted Mosby met The Mother . Tracy McConnell appears in 8 episodes from `` Lucky Penny '' to `` The Time Travelers '' as an unseen character ; she was first seen fully in `` Something New '' and was promoted to a main character in season 9 . The Mother is played by Cristin Milioti .   The story of how Ted met The Mother is the framing device behind the series ; many facts about her are revealed throughout the series , including the fact that Ted once unwittingly owned her umbrella before accidentally leaving it behind in her apartment . Ted and The Mother meet at the Farhampton train station following Barney Stinson and Robin Scherbatsky 's wedding ; this scene is shown in `` Last Forever '' , the series finale . The Mother 's death from an unspecified terminal illness in 2024 , also revealed in the series finale , received a mixed reaction from fans .   An alternate ending was released in the ninth season DVD . In the alternate ending , Tracy Mosby is still living when Ted is telling the story in 2030 . In the video , future Ted is heard saying , `` ... When I think how lucky I am to wake up next to your mom every morning , I ca n't help but be amazed how easy it all really was ... '' , indirectly stating that The Mother is alive . The video ends right after the train passes at Farhampton station and credits start rolling , implying that Ted never went back to Robin as he lived a successful married life with Tracy Mosby .     Contents  ( hide )   1 Casting   2 Character history   2.1 Name     3 Death   4 Notes   5 References      Casting ( edit )   During its first eight seasons , the successful sitcom How I Met Your Mother often hinted at the unseen character of The Mother . Well - known actresses often made guest appearances on the show . Many fans expected that another would play one of the most - wanted roles in Hollywood , but creators Carter Bays and Craig Thomas wanted an unknown . Using Anne Hathaway and Amy Adams as examples , Thomas said that `` We did n't want it to be a big famous star because we did n't want the wider audience to have associations with whatever actress this would be ... The whole idea is that Ted 's never seen this woman before , so it better feel that way to the audience '' , similar to how Cobie Smulders being cast as Robin Scherbatsky had `` kept the show alive '' when it began . Bays and Thomas also did not want a large casting call .   They chose Cristin Milioti after seeing her on 30 Rock and Once ; her musical ability was also helpful , as The Mother had been described as a band member . After competing for the role against at least two others , Milioti filmed her first scene -- for the last episode of season 8 -- having never watched How I Met Your Mother ; she recalled , `` I had ignorance on my side . So I did n't know what it meant . '' Milioti learned of the character 's importance only after binge watching the show during the summer .   Character history ( edit )   The Mother was born on September 19 , 1984 .   The Mother , ...

# %%
# load into test index

for i, rec in enumerate(tqdm(evidence_corpus)):
    
    try:
        index_status = es.index(index='nq_wiki_data_test', id=i, body=rec)

    except Exception as ex:
        print(str(ex))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=40971.0), HTML(value='')))
# --------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-13-229322de67a5> in <module>
#       4
#       5     try:
# ----> 6         index_status = es.index(index='nq_wiki_data_test', id=i, body=rec)
#       7
#       8     except Exception as ex:
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      90                 if p in kwargs:
#      91                     params[p] = kwargs.pop(p)
# ---> 92             return func(*args, params=params, headers=headers, **kwargs)
#      93
#      94         return _wrapped
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/elasticsearch/client/__init__.py in index(self, index, body, doc_type, id, params, headers)
#     402             doc_type = "_doc"
#     403
# --> 404         return self.transport.perform_request(
#     405             "POST" if id in SKIP_IN_PATH else "PUT",
#     406             _make_path(index, doc_type, id),
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     353
#     354             try:
# --> 355                 status, headers_response, data = connection.perform_request(
#     356                     method,
#     357                     url,
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     226                 request_headers["content-encoding"] = "gzip"
#     227
# --> 228             response = self.pool.urlopen(
#     229                 method, url, body, retries=Retry(False), headers=request_headers, **kw
#     230             )
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     618         # Ensure that the URL we're connecting to is properly encoded
#     619         if url.startswith("/"):
# --> 620             url = six.ensure_str(_encode_target(url))
#     621         else:
#     622             url = six.ensure_str(parse_url(url).url)
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/urllib3/util/url.py in _encode_target(target)
#     321     """Percent-encodes a request target so that there are no invalid characters"""
#     322     path, query = TARGET_RE.match(target).groups()
# --> 323     target = _encode_invalid_chars(path, PATH_CHARS)
#     324     query = _encode_invalid_chars(query, QUERY_CHARS)
#     325     if query is not None:
#
# ~/opt/anaconda3/envs/qa-retriever-eval/lib/python3.8/site-packages/urllib3/util/url.py in _encode_invalid_chars(component, allowed_chars, encoding)
#     230     for i in range(0, len(uri_bytes)):
#     231         # Will return a single character bytestring on both Python 2 & 3
# --> 232         byte = uri_bytes[i : i + 1]
#     233         byte_ord = ord(byte)
#     234         if (is_percent_encoded and byte == b"%") or (
#
# KeyboardInterrupt:

# %%
es.count(index='nq_wiki_data_test')['count']
# Out:
# 3763

# %%
file_path = '../data/eval_data/'
file_name = 'ES_wiki_docs_full.jsonl'


with open(file_path+file_name, 'rb') as f:
    for i, line in enumerate(tqdm(f)):
        
        doc = json.loads(str(line, 'utf8'))
        
        try:
            index_status = es.index(index=index_name, id=i, body=doc)

        except Exception as ex:
            print(str(ex))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ConnectionTimeout caused by - ReadTimeoutError(HTTPConnectionPool(host='localhost', port=9200): Read timed out. (read timeout=10))
# ConnectionTimeout caused by - ReadTimeoutError(HTTPConnectionPool(host='localhost', port=9200): Read timed out. (read timeout=10))
# ConnectionTimeout caused by - ReadTimeoutError(HTTPConnectionPool(host='localhost', port=9200): Read timed out. (read timeout=10))

# %%
pickle.dump()

# %%
assert es.count(index=index_name)['count'] == 87108

# %%
query = {
    'query': {
        'query_string': {
            'query': 'why did argentina attack the falklands malvinas islands',
            'default_field': 'document_text_clean'
            }
        }
    }

# %%
re.sub('[^A-Za-z0-9]+', ' ', 'why did argentina attack the falklands/malvinas islands')
# Out:
# 'why did argentina attack the falklands malvinas islands'

# %%
index_name = 'nq_wiki_data'
res = es.search(index=index_name, body=query, size=5)

# %%
res
# Out:
# {'took': 1129,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 38.610443,
#   'hits': [{'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '23',
#     '_score': 38.610443,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Falklands_War&amp;oldid=865589436',
#      'document_title': 'Falklands_War',
#      'document_text_clean': "Falklands War - wikipedia  Falklands War  This article is about the 1982 war . For the 1770 diplomatic crisis , see Falklands Crisis ( 1770 ) .    Falklands War     Map outlining the British recapture of the islands        Date   2 April -- 14 June 1982 ( 2 months , 1 week and 5 days )     Location   Falkland Islands , South Georgia and the South Sandwich Islands and surrounding sea and airspace     Result   British victory     Territorial changes     Status quo ante bellum in South Georgia and the Falklands   Argentine occupation of Southern Thule ended          Belligerents     United Kingdom   Argentina     Commanders and leaders       Margaret Thatcher   Sir Terence Lewin   Sir John Fieldhouse   Sandy Woodward   Jeremy Moore   Julian Thompson   Tony Wilson       Leopoldo Galtieri   Jorge Anaya   Basilio Lami Dozo   Juan Lombardo   Ernesto Crespo   Mario Menéndez       Casualties and losses       255 killed   775 wounded   115 POWs   2 destroyers   2 frigates   1 LSL   1 LCU   1 container ship   24 helicopters   10 fighters   1 bomber ( interned in Brazil )       649 killed   1,657 wounded   11,313 POWs   1 cruiser   1 submarine   4 cargo vessels   2 patrol boats   1 spy trawler   25 helicopters   35 fighters   2 bombers   4 cargo aircraft   25 COIN aircraft   9 armed trainers       3 civilians killed by British shelling               Falklands War       Argentine invasion   South Georgia   Occupation     Paraquet   Black Buck   Belgrano   Sobral   Sheffield   Pebble Island   Mikado   Sutton   San Carlos   Ardent   Seal Cove   Antelope   Atlantic Conveyor   Coventry   Goose Green   Mount Kent   Top Malo House   Bluff Cove   Many Branch Point   Mount Harriet   Two Sisters   Glamorgan   Mount Longdon   Wireless Ridge   Mount Tumbledown   Port Stanley   Thule Island       The Falklands War ( Spanish : Guerra de las Malvinas ) , also known as the Falklands Conflict , Falklands Crisis , Malvinas War , South Atlantic Conflict , and the Guerra del Atlántico Sur ( Spanish for `` South Atlantic War '' ) , was a ten - week war between Argentina and the United Kingdom over two British dependent territories in the South Atlantic : the Falkland Islands , and its territorial dependency , the South Georgia and the South Sandwich Islands . It began on Friday , 2 April 1982 , when Argentina invaded and occupied the Falkland Islands ( and , the following day , South Georgia and the South Sandwich Islands ) in an attempt to establish the sovereignty it had claimed over them . On 5 April , the British government dispatched a naval task force to engage the Argentine Navy and Air Force before making an amphibious assault on the islands . The conflict lasted 74 days and ended with the Argentine surrender on 14 June 1982 , returning the islands to British control . In total , 649 Argentine military personnel , 255 British military personnel , and three Falkland Islanders died during the hostilities .   The conflict was a major episode in the protracted confrontation over the territories ' sovereignty . Argentina asserted ( and maintains ) that the islands are Argentine territory , and the Argentine government thus characterised its military action as the reclamation of its own territory . The British government regarded the action as an invasion of a territory that had been a Crown colony since 1841 . Falkland Islanders , who have inhabited the islands since the early 19th century , are predominantly descendants of British settlers , and strongly favour British sovereignty . Neither state officially declared war , although both governments declared the Islands a war zone . Hostilities were almost exclusively limited to the territories under dispute and the area of the South Atlantic where they lie .   The conflict has had a strong effect in both countries and has been the subject of various books , articles , films , and songs . Patriotic sentiment ran high in Argentina , but the outcome prompted large protests against ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '40295',
#     '_score': 34.177273,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Falkland_Islands&amp;oldid=817794632',
#      'document_title': 'Falkland_Islands',
#      'document_text_clean': "Falkland Islands - wikipedia  Falkland Islands  Jump to : navigation , search `` Falklands '' and `` Malvinas '' redirect here . For other uses , see Falklands ( disambiguation ) and Malvinas ( disambiguation ) .    Falkland Islands     Flag Coat of arms     Motto : `` Desire the Right ''     Anthem : `` God Save the Queen '' ( official ) `` Song of the Falklands ''     Location of the Falkland Islands     Status   British Overseas Territory     Capital and largest settlement   Stanley 51 ° 42 ′ S 57 ° 51 ′ W \ufeff / \ufeff 51.700 ° S 57.850 ° W \ufeff / - 51.700 ; - 57.850     Official languages   English     Demonym   Falkland Islander     Government   Parliamentary dependency under a constitutional monarchy     Monarch   Elizabeth II     Governor   Nigel Phillips     Chief Executive   Barry Rowland     Responsible Minister ( UK )   Alan Duncan MP     Legislature   Legislative Assembly     Establishment     British rule reasserted   1833     Crown colony   1841     British Dependent Territory   1981     British Overseas Territory   2002     Current constitution   2009     Area     Total   12,200 km ( 4,700 sq mi )     Water ( % )   0     Population     2016 census   3,398     Density   0.28 / km ( 0.7 / sq mi ) ( 241st )     GDP ( PPP )   2013 estimate     Total   $228.5 million     Per capita   $77,962 ( 9th )     Gini ( 2010 )   34.17 medium 64th     HDI ( 2010 )   0.874 very high 20th     Currency   Falklands pound ( FKP )     Time zone   FKST ( UTC − 3 )     Drives on the   left     Calling code   + 500     ISO 3166 code   FK     Internet TLD   . fk       ^ `` Song of the Falklands '' is used as the islands ' anthem at sporting events .   ^ Fixed to the pound sterling ( GBP ) .   ^ The Falklands has been on FKST year - round since September 2010 .       The Falkland Islands ( / ˈfɔːlklənd / ; Spanish : Islas Malvinas , pronounced ( ˈislas malˈβinas ) ) is an archipelago in the South Atlantic Ocean on the Patagonian Shelf . The principal islands are about 300 miles ( 483 kilometres ) east of South America 's southern Patagonian coast , at a latitude of about 52 ° S . The archipelago , with an area of 4,700 square miles ( 12,000 square kilometres ) , comprises East Falkland , West Falkland and 776 smaller islands . As a British overseas territory , the ' Falklands ' has internal self - governance , and the United Kingdom takes responsibility for its defence and foreign affairs . The Falkland Islands ' capital is Stanley on East Falkland .   Controversy exists over the Falklands ' discovery and subsequent colonisation by Europeans . At various times , the islands have had French , British , Spanish , and Argentine settlements . Britain reasserted its rule in 1833 , although Argentina maintains its claim to the islands . In April 1982 , Argentine forces temporarily occupied the islands . British administration was restored two months later at the end of the Falklands War . Most Falklanders favour the archipelago remaining a UK overseas territory , but its sovereignty status is part of an ongoing dispute between Argentina and the United Kingdom .   The population ( 2,932 inhabitants in 2012 ) primarily consists of native - born Falkland Islanders , the majority of British descent . Other ethnicities include French , Gibraltarian and Scandinavian . Immigration from the United Kingdom , the South Atlantic island of Saint Helena , and Chile has reversed a population decline . The predominant ( and official ) language is English . Under the British Nationality ( Falkland Islands ) Act 1983 , Falkland Islanders are British citizens .   The islands lie on the boundary of the subantarctic oceanic and tundra climate zones , and both major islands have mountain ranges reaching 2,300 feet ( 700 m ) . They are home to large bird populations , although many no longer breed on the main islands because of competition from introduced species . Major economic activities include fishing , tourism and sheep farmin ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '28769',
#     '_score': 34.177155,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Falkland_Islands&amp;oldid=806819826',
#      'document_title': 'Falkland_Islands',
#      'document_text_clean': "Falkland Islands - wikipedia  Falkland Islands  Jump to : navigation , search `` Falklands '' and `` Malvinas '' redirect here . For other uses , see Falklands ( disambiguation ) and Malvinas ( disambiguation ) .    Falkland Islands     Flag Coat of arms     Motto : `` Desire the Right ''     Anthem : `` God Save the Queen '' ( official ) `` Song of the Falklands ''     Location of the Falkland Islands     Status   British Overseas Territory     Capital and largest settlement   Stanley 51 ° 42 ′ S 57 ° 51 ′ W \ufeff / \ufeff 51.700 ° S 57.850 ° W \ufeff / - 51.700 ; - 57.850     Official languages   English     Demonym   Falkland Islander     Government   Parliamentary dependency under a constitutional monarchy     Monarch   Elizabeth II     Governor   Nigel Phillips     Chief Executive   Barry Rowland     Responsible Minister ( UK )   Alan Duncan MP     Legislature   Legislative Assembly     Establishment     British rule reasserted   1833     Crown colony   1841     British Dependent Territory   1981     British Overseas Territory   2002     Current constitution   2009     Area     Total   12,200 km ( 4,700 sq mi )     Water ( % )   0     Population     2016 census   3,398     Density   0.28 / km ( 0.7 / sq mi ) ( 241st )     GDP ( PPP )   2013 estimate     Total   $228.5 million     Per capita   $77,962 ( 9th )     Gini ( 2010 )   34.17 medium 64th     HDI ( 2010 )   0.874 very high 20th     Currency   Falklands pound ( FKP )     Time zone   FKST ( UTC − 3 )     Drives on the   left     Calling code   + 500     ISO 3166 code   FK     Internet TLD   . fk       ^ `` Song of the Falklands '' is used as the islands ' anthem at sporting events .   ^ Fixed to the pound sterling ( GBP ) .   ^ The Falklands has been on FKST year - round since September 2010 .       The Falkland Islands ( / ˈfɔːlklənd / ; Spanish : Islas Malvinas , pronounced ( ˈizlaz malˈβinas ) ) are an archipelago in the South Atlantic Ocean on the Patagonian Shelf . The principal islands are about 300 miles ( 483 kilometres ) east of South America 's southern Patagonian coast , at a latitude of about 52 ° S . The archipelago , with an area of 4,700 square miles ( 12,000 square kilometres ) , comprises East Falkland , West Falkland and 776 smaller islands . As a British overseas territory , the Falklands have internal self - governance , and the United Kingdom takes responsibility for their defence and foreign affairs . The islands ' capital is Stanley on East Falkland .   Controversy exists over the Falklands ' discovery and subsequent colonisation by Europeans . At various times , the islands have had French , British , Spanish , and Argentine settlements . Britain reasserted its rule in 1833 , although Argentina maintains its claim to the islands . In April 1982 , Argentine forces temporarily occupied the islands . British administration was restored two months later at the end of the Falklands War . Most Falklanders favour the archipelago remaining a UK overseas territory , but its sovereignty status is part of an ongoing dispute between Argentina and the United Kingdom .   The population ( 2,932 inhabitants in 2012 ) primarily consists of native - born Falkland Islanders , the majority of British descent . Other ethnicities include French , Gibraltarian and Scandinavian . Immigration from the United Kingdom , the South Atlantic island of Saint Helena , and Chile has reversed a population decline . The predominant ( and official ) language is English . Under the British Nationality ( Falkland Islands ) Act 1983 , Falkland Islanders are British citizens .   The islands lie on the boundary of the subantarctic oceanic and tundra climate zones , and both major islands have mountain ranges reaching 2,300 feet ( 700 m ) . They are home to large bird populations , although many no longer breed on the main islands because of competition from introduced species . Major economic activities include fishing , tourism and sheep farming , with  ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '78787',
#     '_score': 34.173367,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Falkland_Islands&amp;oldid=833213275',
#      'document_title': 'Falkland_Islands',
#      'document_text_clean': "Falkland Islands - wikipedia  Falkland Islands  Jump to : navigation , search `` Falklands '' and `` Malvinas '' redirect here . For other uses , see Falklands ( disambiguation ) and Malvinas ( disambiguation ) .    Falkland Islands     Flag Coat of arms     Motto : `` Desire the Right ''     Anthem : `` God Save the Queen '' ( official ) `` Song of the Falklands ''     Location of the Falkland Islands     Status   British Overseas Territory     Capital and largest settlement   Stanley 51 ° 42 ′ S 57 ° 51 ′ W \ufeff / \ufeff 51.700 ° S 57.850 ° W \ufeff / - 51.700 ; - 57.850     Official languages   English     Demonym   Falkland Islander     Government   Parliamentary dependency under a constitutional monarchy     Monarch   Elizabeth II     Governor   Nigel Phillips     Chief Executive   Barry Rowland     Responsible Minister ( UK )   Alan Duncan MP     Legislature   Legislative Assembly     Establishment     British rule reasserted   1833     Crown colony   1841     British Dependent Territory   1981     British Overseas Territory   2002     Current constitution   2009     Area     Total   12,200 km ( 4,700 sq mi )     Water ( % )   0     Population     2016 census   3,398     Density   0.28 / km ( 0.7 / sq mi ) ( 241st )     GDP ( PPP )   2013 estimate     Total   $228.5 million     Per capita   $96,962 ( 4th )     Gini ( 2010 )   34.17 medium 64th     HDI ( 2010 )   0.874 very high 20th     Currency   Falklands pound ( FKP )     Time zone   FKST ( UTC − 3 )     Drives on the   left     Calling code   + 500     ISO 3166 code   FK     Internet TLD   . fk       ^ `` Song of the Falklands '' is used as the islands ' anthem at sporting events .   ^ Fixed to the pound sterling ( GBP ) .   ^ The Falklands has been on FKST year - round since September 2010 .       The Falkland Islands ( / ˈfɔːlklənd / ; Spanish : Islas Malvinas , pronounced ( ˈislas malˈβinas ) ) is an archipelago in the South Atlantic Ocean on the Patagonian Shelf . The principal islands are about 300 miles ( 483 kilometres ) east of South America 's southern Patagonian coast , at a latitude of about 52 ° S . The archipelago , with an area of 4,700 square miles ( 12,000 square kilometres ) , comprises East Falkland , West Falkland and 776 smaller islands . As a British overseas territory , the Falklands have internal self - governance , and the United Kingdom takes responsibility for their defence and foreign affairs . The Falkland Islands ' capital is Stanley on East Falkland .   Controversy exists over the Falklands ' discovery and subsequent colonisation by Europeans . At various times , the islands have had French , British , Spanish , and Argentine settlements . Britain reasserted its rule in 1833 , although Argentina maintains its claim to the islands . In April 1982 , Argentine forces temporarily occupied the islands . British administration was restored two months later at the end of the Falklands War . Most Falklanders favour the archipelago remaining a UK overseas territory , but its sovereignty status is part of an ongoing dispute between Argentina and the United Kingdom .   The population ( 2,932 inhabitants in 2012 ) primarily consists of native - born Falkland Islanders , the majority of British descent . Other ethnicities include French , Gibraltarian and Scandinavian . Immigration from the United Kingdom , the South Atlantic island of Saint Helena , and Chile has reversed a population decline . The predominant ( and official ) language is English . Under the British Nationality ( Falkland Islands ) Act 1983 , Falkland Islanders are British citizens .   The islands lie on the boundary of the subantarctic oceanic and tundra climate zones , and both major islands have mountain ranges reaching 2,300 feet ( 700 m ) . They are home to large bird populations , although many no longer breed on the main islands because of competition from introduced species . Major economic activities include fishing , tourism and sheep farming ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '77621',
#     '_score': 33.698788,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Leopoldo_Galtieri&amp;oldid=843227202',
#      'document_title': 'Leopoldo_Galtieri',
#      'document_text_clean': "Leopoldo Galtieri - wikipedia  Leopoldo Galtieri  Jump to : navigation , search This name uses Spanish naming customs : the first or paternal family name is Galtieri and the second or maternal family name is Castelli .    Leopoldo Galtieri             President of Argentina De facto     In office 22 December 1981 -- 18 June 1982     Preceded by   Carlos Lacoste ( interim )     Succeeded by   Alfredo Oscar Saint Jean ( acting )         Personal details       ( 1926 - 07 - 15 ) 15 July 1926 Caseros , Argentina       12 January 2003 ( 2003 - 01 - 12 ) ( aged 76 ) Buenos Aires , Argentina     Nationality   Argentine     Political party   None     Spouse ( s )   Lucía Noemí Gentili     Children       Alma mater   Colegio Militar de la Nación     Profession   Military     Signature       Military service     Allegiance   Argentina     Service / branch   Argentine Army     Years of service   1944 -- 1982     Rank   Lieutenant General     Battles / wars   Falklands War     Leopoldo Fortunato Galtieri Castelli ( Spanish pronunciation : ( leoˈpoldo foɾtuˈnato ɣalˈtjeɾi kasˈteʎi ) ; 15 July 1926 -- 12 January 2003 ) was an Argentine general and President of Argentina from 22 December 1981 to 18 June 1982 , during the last military dictatorship ( known officially as the National Reorganization Process ) . The death squad , 601 Intelligence Battalion , directly reported to him . He was removed from power soon after the British re-took the Falkland Islands , whose invasion and occupation he had ordered .     Contents  ( hide )   1 Early life   2 Rise to power   3 Falklands War   4 Defeat , fall from power , trial and prison   5 Later life , further accusations   6 Death   7 References   8 External links      Early life ( edit )   Galtieri was an Italian Argentine born to working class immigrant parents . At 17 he enrolled at the National Military Academy to study civil engineering , and his early military career was as an officer in the engineering branch . As well as rising through the ranks of the Military , he continued his studies in engineering until the mid-1950s . In 1958 , he became a professor of engineering at the Senior War College .   Galtieri was married to Lucía Noemí Gentili , and the couple had one son and two daughters .   Rise to power ( edit )   In 1975 , after more than 25 years as a combat engineer , Galtieri became commander of the Argentine engineering corps . He was an enthusiastic supporter of the military coup that started the self - styled National Reorganisation Process in 1976 and rose further , becoming a major general in 1977 , and commander - in - chief in 1980 with the rank of lieutenant general . During the junta 's rule , Congress was suspended , trade unions , political parties , and provincial governments were banned , and in what became known as the Dirty War , between 9,000 and 30,000 people deemed left - wing subversives disappeared from society . Torture and mass executions were both commonplace . The economy , which had been in dire condition prior to the coup , recovered for a short time , then deteriorated further .   In March 1981 , Galtieri visited the United States and was warmly received , as the Reagan administration viewed the regime as a bulwark against communism . National Security Advisor Richard V. Allen described him as a `` majestic general '' . An adherent to the Argentine military 's Cold War - era doctrine of `` ideological frontiers '' , Galtieri secured his country 's support for rebel groups opposing the government in Nicaragua , the Contras ; in August , he sent advisers to help organize the Nicaraguan Democratic Force ( FDN , for a time the principal Contra group ) , as well as training FDN leaders in Argentine bases . His support for this initiative allowed Galtieri to remove a number of rival generals . In December 1981 , he rose to the Presidency of Argentina in a coup that ousted General Roberto Viola . Argentine support became the principal sou ...

# %%
for hit in res['hits']['hits']:
    print(hit['_score'])
# Out:
# 8.69899
# 8.698753
# 8.678847
# 8.66811
# 8.602217

# %%
a = es.search(index=index_name, body=query)

# %%
es.indices.stats(index_name)
# Out:
# {'_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_all': {'primaries': {'docs': {'count': 0, 'deleted': 0},
#    'store': {'size_in_bytes': 41164},
#    'indexing': {'index_total': 4,
#     'index_time_in_millis': 129,
#     'index_current': 0,
#     'index_failed': 0,
#     'delete_total': 0,
#     'delete_time_in_millis': 0,
#     'delete_current': 0,
#     'noop_update_total': 0,
#     'is_throttled': False,
#     'throttle_time_in_millis': 0},
#    'get': {'total': 0,
#     'time_in_millis': 0,
#     'exists_total': 0,
#     'exists_time_in_millis': 0,
#     'missing_total': 0,
#     'missing_time_in_millis': 0,
#     'current': 0},
#    'search': {'open_contexts': 0,
#     'query_total': 0,
#     'query_time_in_millis': 0,
#     'query_current': 0,
#     'fetch_total': 0,
#     'fetch_time_in_millis': 0,
#     'fetch_current': 0,
#     'scroll_total': 0,
#     'scroll_time_in_millis': 0,
#     'scroll_current': 0,
#     'suggest_total': 0,
#     'suggest_time_in_millis': 0,
#     'suggest_current': 0},
#    'merges': {'current': 0,
#     'current_docs': 0,
#     'current_size_in_bytes': 0,
#     'total': 0,
#     'total_time_in_millis': 0,
#     'total_docs': 0,
#     'total_size_in_bytes': 0,
#     'total_stopped_time_in_millis': 0,
#     'total_throttled_time_in_millis': 0,
#     'total_auto_throttle_in_bytes': 20971520},
#    'refresh': {'total': 2,
#     'total_time_in_millis': 0,
#     'external_total': 2,
#     'external_total_time_in_millis': 0,
#     'listeners': 0},
#    'flush': {'total': 0, 'periodic': 0, 'total_time_in_millis': 0},
#    'warmer': {'current': 0, 'total': 1, 'total_time_in_millis': 0},
#    'query_cache': {'memory_size_in_bytes': 0,
#     'total_count': 0,
#     'hit_count': 0,
#     'miss_count': 0,
#     'cache_size': 0,
#     'cache_count': 0,
#     'evictions': 0},
#    'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#    'completion': {'size_in_bytes': 0},
#    'segments': {'count': 0,
#     'memory_in_bytes': 0,
#     'terms_memory_in_bytes': 0,
#     'stored_fields_memory_in_bytes': 0,
#     'term_vectors_memory_in_bytes': 0,
#     'norms_memory_in_bytes': 0,
#     'points_memory_in_bytes': 0,
#     'doc_values_memory_in_bytes': 0,
#     'index_writer_memory_in_bytes': 321760,
#     'version_map_memory_in_bytes': 234,
#     'fixed_bit_set_memory_in_bytes': 0,
#     'max_unsafe_auto_id_timestamp': -1,
#     'file_sizes': {}},
#    'translog': {'operations': 4,
#     'size_in_bytes': 75185,
#     'uncommitted_operations': 4,
#     'uncommitted_size_in_bytes': 75185,
#     'earliest_last_modified_age': 0},
#    'request_cache': {'memory_size_in_bytes': 0,
#     'evictions': 0,
#     'hit_count': 0,
#     'miss_count': 0},
#    'recovery': {'current_as_source': 0,
#     'current_as_target': 0,
#     'throttle_time_in_millis': 0}},
#   'total': {'docs': {'count': 0, 'deleted': 0},
#    'store': {'size_in_bytes': 41164},
#    'indexing': {'index_total': 4,
#     'index_time_in_millis': 129,
#     'index_current': 0,
#     'index_failed': 0,
#     'delete_total': 0,
#     'delete_time_in_millis': 0,
#     'delete_current': 0,
#     'noop_update_total': 0,
#     'is_throttled': False,
#     'throttle_time_in_millis': 0},
#    'get': {'total': 0,
#     'time_in_millis': 0,
#     'exists_total': 0,
#     'exists_time_in_millis': 0,
#     'missing_total': 0,
#     'missing_time_in_millis': 0,
#     'current': 0},
#    'search': {'open_contexts': 0,
#     'query_total': 0,
#     'query_time_in_millis': 0,
#     'query_current': 0,
#     'fetch_total': 0,
#     'fetch_time_in_millis': 0,
#     'fetch_current': 0,
#     'scroll_total': 0,
#     'scroll_time_in_millis': 0,
#     'scroll_current': 0,
#     'suggest_total': 0,
#     'suggest_time_in_millis': 0,
#     'suggest_current': 0},
#    'merges': {'current': 0,
#     'current_docs': 0,
#     'current_size_in_bytes': 0,
#     'total': 0,
#     'total_time_in_millis': 0,
#     'total_docs': 0,
#     'total_size_in_bytes': 0,
#     'total_stopped_time_in_millis': 0,
#     'total_throttled_time_in_millis': 0,
#     'total_auto_throttle_in_bytes': 20971520},
#    'refresh': {'total': 2,
#     'total_time_in_millis': 0,
#     'external_total': 2,
#     'external_total_time_in_millis': 0,
#     'listeners': 0},
#    'flush': {'total': 0, 'periodic': 0, 'total_time_in_millis': 0},
#    'warmer': {'current': 0, 'total': 1, 'total_time_in_millis': 0},
#    'query_cache': {'memory_size_in_bytes': 0,
#     'total_count': 0,
#     'hit_count': 0,
#     'miss_count': 0,
#     'cache_size': 0,
#     'cache_count': 0,
#     'evictions': 0},
#    'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#    'completion': {'size_in_bytes': 0},
#    'segments': {'count': 0,
#     'memory_in_bytes': 0,
#     'terms_memory_in_bytes': 0,
#     'stored_fields_memory_in_bytes': 0,
#     'term_vectors_memory_in_bytes': 0,
#     'norms_memory_in_bytes': 0,
#     'points_memory_in_bytes': 0,
#     'doc_values_memory_in_bytes': 0,
#     'index_writer_memory_in_bytes': 321760,
#     'version_map_memory_in_bytes': 234,
#     'fixed_bit_set_memory_in_bytes': 0,
#     'max_unsafe_auto_id_timestamp': -1,
#     'file_sizes': {}},
#    'translog': {'operations': 4,
#     'size_in_bytes': 75185,
#     'uncommitted_operations': 4,
#     'uncommitted_size_in_bytes': 75185,
#     'earliest_last_modified_age': 0},
#    'request_cache': {'memory_size_in_bytes': 0,
#     'evictions': 0,
#     'hit_count': 0,
#     'miss_count': 0},
#    'recovery': {'current_as_source': 0,
#     'current_as_target': 0,
#     'throttle_time_in_millis': 0}}},
#  'indices': {'nq_wiki_data': {'uuid': 'rYD81NC6RHeVxP4YYC-L4A',
#    'primaries': {'docs': {'count': 0, 'deleted': 0},
#     'store': {'size_in_bytes': 41164},
#     'indexing': {'index_total': 4,
#      'index_time_in_millis': 129,
#      'index_current': 0,
#      'index_failed': 0,
#      'delete_total': 0,
#      'delete_time_in_millis': 0,
#      'delete_current': 0,
#      'noop_update_total': 0,
#      'is_throttled': False,
#      'throttle_time_in_millis': 0},
#     'get': {'total': 0,
#      'time_in_millis': 0,
#      'exists_total': 0,
#      'exists_time_in_millis': 0,
#      'missing_total': 0,
#      'missing_time_in_millis': 0,
#      'current': 0},
#     'search': {'open_contexts': 0,
#      'query_total': 0,
#      'query_time_in_millis': 0,
#      'query_current': 0,
#      'fetch_total': 0,
#      'fetch_time_in_millis': 0,
#      'fetch_current': 0,
#      'scroll_total': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_current': 0,
#      'suggest_total': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_current': 0},
#     'merges': {'current': 0,
#      'current_docs': 0,
#      'current_size_in_bytes': 0,
#      'total': 0,
#      'total_time_in_millis': 0,
#      'total_docs': 0,
#      'total_size_in_bytes': 0,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 0,
#      'total_auto_throttle_in_bytes': 20971520},
#     'refresh': {'total': 2,
#      'total_time_in_millis': 0,
#      'external_total': 2,
#      'external_total_time_in_millis': 0,
#      'listeners': 0},
#     'flush': {'total': 0, 'periodic': 0, 'total_time_in_millis': 0},
#     'warmer': {'current': 0, 'total': 1, 'total_time_in_millis': 0},
#     'query_cache': {'memory_size_in_bytes': 0,
#      'total_count': 0,
#      'hit_count': 0,
#      'miss_count': 0,
#      'cache_size': 0,
#      'cache_count': 0,
#      'evictions': 0},
#     'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#     'completion': {'size_in_bytes': 0},
#     'segments': {'count': 0,
#      'memory_in_bytes': 0,
#      'terms_memory_in_bytes': 0,
#      'stored_fields_memory_in_bytes': 0,
#      'term_vectors_memory_in_bytes': 0,
#      'norms_memory_in_bytes': 0,
#      'points_memory_in_bytes': 0,
#      'doc_values_memory_in_bytes': 0,
#      'index_writer_memory_in_bytes': 321760,
#      'version_map_memory_in_bytes': 234,
#      'fixed_bit_set_memory_in_bytes': 0,
#      'max_unsafe_auto_id_timestamp': -1,
#      'file_sizes': {}},
#     'translog': {'operations': 4,
#      'size_in_bytes': 75185,
#      'uncommitted_operations': 4,
#      'uncommitted_size_in_bytes': 75185,
#      'earliest_last_modified_age': 0},
#     'request_cache': {'memory_size_in_bytes': 0,
#      'evictions': 0,
#      'hit_count': 0,
#      'miss_count': 0},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0}},
#    'total': {'docs': {'count': 0, 'deleted': 0},
#     'store': {'size_in_bytes': 41164},
#     'indexing': {'index_total': 4,
#      'index_time_in_millis': 129,
#      'index_current': 0,
#      'index_failed': 0,
#      'delete_total': 0,
#      'delete_time_in_millis': 0,
#      'delete_current': 0,
#      'noop_update_total': 0,
#      'is_throttled': False,
#      'throttle_time_in_millis': 0},
#     'get': {'total': 0,
#      'time_in_millis': 0,
#      'exists_total': 0,
#      'exists_time_in_millis': 0,
#      'missing_total': 0,
#      'missing_time_in_millis': 0,
#      'current': 0},
#     'search': {'open_contexts': 0,
#      'query_total': 0,
#      'query_time_in_millis': 0,
#      'query_current': 0,
#      'fetch_total': 0,
#      'fetch_time_in_millis': 0,
#      'fetch_current': 0,
#      'scroll_total': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_current': 0,
#      'suggest_total': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_current': 0},
#     'merges': {'current': 0,
#      'current_docs': 0,
#      'current_size_in_bytes': 0,
#      'total': 0,
#      'total_time_in_millis': 0,
#      'total_docs': 0,
#      'total_size_in_bytes': 0,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 0,
#      'total_auto_throttle_in_bytes': 20971520},
#     'refresh': {'total': 2,
#      'total_time_in_millis': 0,
#      'external_total': 2,
#      'external_total_time_in_millis': 0,
#      'listeners': 0},
#     'flush': {'total': 0, 'periodic': 0, 'total_time_in_millis': 0},
#     'warmer': {'current': 0, 'total': 1, 'total_time_in_millis': 0},
#     'query_cache': {'memory_size_in_bytes': 0,
#      'total_count': 0,
#      'hit_count': 0,
#      'miss_count': 0,
#      'cache_size': 0,
#      'cache_count': 0,
#      'evictions': 0},
#     'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#     'completion': {'size_in_bytes': 0},
#     'segments': {'count': 0,
#      'memory_in_bytes': 0,
#      'terms_memory_in_bytes': 0,
#      'stored_fields_memory_in_bytes': 0,
#      'term_vectors_memory_in_bytes': 0,
#      'norms_memory_in_bytes': 0,
#      'points_memory_in_bytes': 0,
#      'doc_values_memory_in_bytes': 0,
#      'index_writer_memory_in_bytes': 321760,
#      'version_map_memory_in_bytes': 234,
#      'fixed_bit_set_memory_in_bytes': 0,
#      'max_unsafe_auto_id_timestamp': -1,
#      'file_sizes': {}},
#     'translog': {'operations': 4,
#      'size_in_bytes': 75185,
#      'uncommitted_operations': 4,
#      'uncommitted_size_in_bytes': 75185,
#      'earliest_last_modified_age': 0},
#     'request_cache': {'memory_size_in_bytes': 0,
#      'evictions': 0,
#      'hit_count': 0,
#      'miss_count': 0},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0}}}}}

# %% [markdown]
# ## Analyze ES Retreival Performance

# %% [markdown]
# #### Load QA data

# %%
file_path = '../data/eval_data/'
file_name = 'slim_extracted_data_records.pkl'

with open(file_path+file_name, 'rb') as f:
    
    slim_data = pickle.load(f)

# %%
slim_data[0]
# Out:
# {'example_id': 5655493461695504401,
#  'document_url': 'https://en.wikipedia.org//w/index.php?title=Email_marketing&amp;oldid=814071202',
#  'question_text': 'which is the most common use of opt-in e-mail marketing',
#  'short_answer': "a newsletter sent to an advertising firm 's customers"}

# %% [markdown]
# #### Analyze QA's

# %%
def analyze_retriever_recall(es_object, index_name, qa_data):
    
    results = []
    
    for i, qa in enumerate(tqdm(qa_data)):
        
        question = qa['question_text']
        answer = qa['short_answer']
        ex_id = qa['example_id']
        truth_url = qa['document_url']
        
        # construct query
        query = {
            'query': {
                'query_string': {
                    'query': re.sub('[^A-Za-z0-9]+', ' ', question),
                    'default_field': 'document_text_clean'
                    }
                }
            }
        
        # execute query
        res = es_object.search(index=index_name, body=query, size=5)
        
        # extract response info
        n_hits = res['hits']['total']['value']
        max_score = res['hits']['max_score']
        duration = res['took']
        
        # check if answer is present in results
        
        ans_in_res = int(any([answer.lower() in doc['_source']['document_text_clean'].lower() for doc in res['hits']['hits']]))
        
#         ans_in_res = int(any([truth_url == doc['_source']['document_url'] for doc in res['hits']['hits']]))
        
        
        rec = (ex_id, question, answer, n_hits, max_score, duration, ans_in_res)
        results.append(rec)
        
    return results

# %%
# match of lowercase answer string in answer
test_results = analyze_retriever_recall(es, index_name, slim_data)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=106848.0), HTML(value='')))

# %%
cols = ['Example_ID', 'Question', 'Answer', 'Number_Records_Returned', 'Max_Score', 'Query_Duration', 'Answer_Present']
test_results_df = pd.DataFrame(test_results, columns=cols)

# %%
test_results_df.Answer_Present.value_counts()
# Out:
# 1    80624
# 0    26224
# Name: Answer_Present, dtype: int64

# %%
test_results_df.Answer_Present.value_counts(normalize=True)
# Out:
# 1    0.754567
# 0    0.245433
# Name: Answer_Present, dtype: float64

# %%
test_results_df.shape
# Out:
# (106848, 7)

# %%
test_results_df.head()
# Out:
#             Example_ID                                           Question  \
# 0  5655493461695504401  which is the most common use of opt-in e-mail ...
# 1  5328212470870865242            how i.met your mother who is the mother
# 2  5289242154789678439                   who had the most wins in the nfl
# 3 -2500044561429484630        who played mantis guardians of the galaxy 2
# 4   212419696952141239  the nashville sound brought a polished and cos...
#
#                                               Answer  Number_Records_Returned  \
# 0  a newsletter sent to an advertising firm 's cu...                    10000
# 1                                    Tracy McConnell                    10000
# 2                                          Tom Brady                    10000
# 3                                    Pom Klementieff                    10000
# 4  the use of lush string arrangements with a rea...                    10000
#
#    Max_Score  Query_Duration  Answer_Present
# 0  21.880262              22               1
# 1  13.217962              31               1
# 2  11.294436              22               1
# 3  26.414034              14               1
# 4  21.313108              33               0

# %%
test_results_df.Answer_Present.value_counts()
# Out:
# 1    3776
# 0    1225
# Name: Answer_Present, dtype: int64

# %%
test_results[0]
# Out:
# (5655493461695504401,
#  'which is the most common use of opt-in e-mail marketing',
#  "a newsletter sent to an advertising firm 's customers",
#  10000,
#  21.880262,
#  94,
#  0)

# %%
slim_data[23]
# Out:
# {'example_id': -6432014180752712230,
#  'document_url': 'https://en.wikipedia.org//w/index.php?title=Falklands_War&amp;oldid=865589436',
#  'question_text': 'why did argentina attack the falklands/malvinas islands',
#  'short_answer': 'an attempt to establish the sovereignty it had claimed over them'}

# %%
slim_data
# Out:
# [{'example_id': 5655493461695504401,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Email_marketing&amp;oldid=814071202',
#   'question_text': 'which is the most common use of opt-in e-mail marketing',
#   'short_answer': "a newsletter sent to an advertising firm 's customers"},
#  {'example_id': 5328212470870865242,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Mother_(How_I_Met_Your_Mother)&amp;oldid=802354471',
#   'question_text': 'how i.met your mother who is the mother',
#   'short_answer': 'Tracy McConnell'},
#  {'example_id': 5289242154789678439,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_National_Football_League_career_quarterback_wins_leaders&amp;oldid=818143757',
#   'question_text': 'who had the most wins in the nfl',
#   'short_answer': 'Tom Brady'},
#  {'example_id': -2500044561429484630,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Pom_Klementieff&amp;oldid=829523540',
#   'question_text': 'who played mantis guardians of the galaxy 2',
#   'short_answer': 'Pom Klementieff'},
#  {'example_id': 212419696952141239,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Nashville_sound&amp;oldid=787335589',
#   'question_text': 'the nashville sound brought a polished and cosmopolitan sound to country music by',
#   'short_answer': 'the use of lush string arrangements with a real orchestra and often , background vocals provided by a choir'},
#  {'example_id': -1706790511507651062,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Premier_League_broadcasters&amp;oldid=808611916',
#   'question_text': 'what channel is the premier league on in france',
#   'short_answer': 'SFR Sport'},
#  {'example_id': -1446769669686008214,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Learner%27s_permit&amp;oldid=837013508',
#   'question_text': 'who needs to be in the car with a permit driver',
#   'short_answer': 'an adult licensed driver who is at least 21 years of age or older and in the passenger seat of the vehicle at all times'},
#  {'example_id': -7491001389340565191,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=God%27s_Not_Dead:_A_Light_in_Darkness&amp;oldid=845133328',
#   'question_text': "god's not dead a light in the darkness release date",
#   'short_answer': 'March 30 , 2018'},
#  {'example_id': -341902602485554777,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=President_of_the_United_Nations_General_Assembly&amp;oldid=807429262',
#   'question_text': 'who is the current president of un general assembly',
#   'short_answer': 'Miroslav Lajčák of Slovakia'},
#  {'example_id': 4828269869422443677,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Powerball&amp;oldid=807097187',
#   'question_text': 'when do they pull the powerball numbers 2016',
#   'short_answer': 'every Wednesday and Saturday evening at 10 : 59 p.m. Eastern Time'},
#  {'example_id': 4706363175863681196,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Solar_eclipse_of_August_21,_2017&amp;oldid=808994059',
#   'question_text': 'when do the eclipse supposed to take place',
#   'short_answer': 'August 21 , 2017'},
#  {'example_id': 108744506445139712,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Dubai&amp;oldid=821745147',
#   'question_text': 'what is the name of the sea surrounding dubai',
#   'short_answer': 'Persian Gulf'},
#  {'example_id': 7051526329122856082,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_National_Basketball_Association_career_scoring_leaders&amp;oldid=834470586',
#   'question_text': 'who holds the nba record for most points in a career',
#   'short_answer': 'Kareem Abdul - Jabbar'},
#  {'example_id': -1983496953136147279,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Maze_Runner:_The_Death_Cure&amp;oldid=828322653',
#   'question_text': 'when did the new maze runner movie come out',
#   'short_answer': 'January 26 , 2018'},
#  {'example_id': 1976060692212147490,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Box_lacrosse&amp;oldid=853641547',
#   'question_text': 'how many players on a box lacrosse team',
#   'short_answer': 'six'},
#  {'example_id': 4035615966981436342,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Olympic_Games_host_cities&amp;oldid=843272486',
#   'question_text': 'where are the upcoming olympics to be held',
#   'short_answer': 'Tokyo for the 2020 Summer Olympics'},
#  {'example_id': 2631758144006095110,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Three_seconds_rule&amp;oldid=812463632',
#   'question_text': 'when did the nba 3 second rule start',
#   'short_answer': '1936'},
#  {'example_id': 2247147696318105126,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=So_You_Think_You_Can_Dance:_The_Next_Generation_(U.S._TV_series)&amp;oldid=828543040',
#   'question_text': 'who won so you think you can dance 2016',
#   'short_answer': "Leon `` Kida '' Burns"},
#  {'example_id': 9160648621472984761,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Bates_Motel_(TV_series)&amp;oldid=843200389',
#   'question_text': 'who plays norman bates in the tv show',
#   'short_answer': 'Freddie Highmore'},
#  {'example_id': -7401067941606033172,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Left-_and_right-hand_traffic&amp;oldid=815780618',
#   'question_text': 'when did usa start driving on the right',
#   'short_answer': 'late 1700s'},
#  {'example_id': 6742722067045398734,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Central_nervous_system&amp;oldid=843023739',
#   'question_text': 'name some components of the central nervous system (cns)',
#   'short_answer': 'brain'},
#  {'example_id': 8507052179618710162,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Price_Is_Right_(U.S._game_show)&amp;oldid=807380000',
#   'question_text': "who's the director of the price is right",
#   'short_answer': 'Adam Sandler'},
#  {'example_id': 8862597567788562881,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Bridge_on_the_River_Kwai&amp;oldid=828189495',
#   'question_text': 'bridge on the river kwai fact or fiction',
#   'short_answer': 'fiction'},
#  {'example_id': -6432014180752712230,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Falklands_War&amp;oldid=865589436',
#   'question_text': 'why did argentina attack the falklands/malvinas islands',
#   'short_answer': 'an attempt to establish the sovereignty it had claimed over them'},
#  {'example_id': -1892041621667788534,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Prime_Minister_of_Mauritius&amp;oldid=843271260',
#   'question_text': 'who is the prime minister of republic of mauritius',
#   'short_answer': 'Pravind Jugnauth'},
#  {'example_id': 6823139846656798944,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=2018_FA_Cup_Final&amp;oldid=842824259',
#   'question_text': 'what teams are in the fa cup final',
#   'short_answer': 'Manchester United'},
#  {'example_id': 3775759080678919462,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=A_Midsummer_Night%27s_Dream&amp;oldid=805426408',
#   'question_text': "where is a midsummer night's dream set",
#   'short_answer': 'in the woodland and in the realm of Fairyland'},
#  {'example_id': 7099476635664167392,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Neil_Armstrong&amp;oldid=855702024',
#   'question_text': 'who is the first person who went to moon',
#   'short_answer': 'Neil Alden Armstrong'},
#  {'example_id': -6529916509543370832,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Lego_films_and_TV_series&amp;oldid=803674018',
#   'question_text': 'when did the first lego movie come out',
#   'short_answer': 'The Lego Movie'},
#  {'example_id': 341989533800524779,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Metal&amp;oldid=815651738',
#   'question_text': 'are pure metals made of atoms or ions',
#   'short_answer': 'atoms'},
#  {'example_id': -5723504820435724792,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_songs_in_Victorious&amp;oldid=822275932',
#   'question_text': 'what episode in victorious is give it up',
#   'short_answer': 'Freak the Freak Out'},
#  {'example_id': 5038774084416466796,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Active_transport&amp;oldid=839384184',
#   'question_text': 'movement of molecules across a membrane powered by atp',
#   'short_answer': 'primary active transport'},
#  {'example_id': 1866510146610611920,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Peter_Minuit&amp;oldid=845627939',
#   'question_text': 'who sold manhattan to the dutch in 1626',
#   'short_answer': 'Seyseys , chief of the Canarsees'},
#  {'example_id': -7766157450214546755,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Deuces_(film)&amp;oldid=815906240',
#   'question_text': 'what year did the movie deuces come out',
#   'short_answer': '2017'},
#  {'example_id': -7571963873134787869,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Ministry_of_Youth_Affairs_and_Sports&amp;oldid=806968548',
#   'question_text': 'who is the present sport minister of india',
#   'short_answer': 'Rajyavardhan Singh Rathore'},
#  {'example_id': 5459588345445146692,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_most-followed_Instagram_accounts&amp;oldid=843654586',
#   'question_text': 'who has the most followers on instagram in the world',
#   'short_answer': 'Instagram'},
#  {'example_id': -6638952910263008958,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Life_or_Something_Like_It&amp;oldid=799936084',
#   'question_text': 'where was life or something like it filmed',
#   'short_answer': 'Seattle , Washington'},
#  {'example_id': 7309730471932385366,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Karnataka_Police&amp;oldid=827735308',
#   'question_text': 'the highest post in police department of karnataka state is',
#   'short_answer': 'The Director General and Inspector General of Police ( DG&IGP )'},
#  {'example_id': 6507043059195332190,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_wealthiest_organizations&amp;oldid=865819845',
#   'question_text': 'what is the worth of the catholic church',
#   'short_answer': '$140 billion +'},
#  {'example_id': 3548433606803532214,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Black_Dirt_Region&amp;oldid=793364067',
#   'question_text': 'where is the best farming soil in the us and where did all the dirt come from',
#   'short_answer': 'The Black Dirt Region'},
#  {'example_id': 969150327819152892,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Tabla&amp;oldid=857033146',
#   'question_text': 'the pair of hand drums used in indian classical music is called',
#   'short_answer': 'tabla'},
#  {'example_id': 3663531336951024522,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Petty_officer&amp;oldid=807097820',
#   'question_text': 'where does the term petty officer come from',
#   'short_answer': 'Age of Sail'},
#  {'example_id': -1335149629485629865,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Israel&amp;oldid=803902748',
#   'question_text': 'where is israel located on the world map',
#   'short_answer': 'the Middle East , on the southeastern shore of the Mediterranean Sea and the northern shore of the Red Sea'},
#  {'example_id': -90069278949046872,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Tinker_Tailor_Soldier_Spy_(film)&amp;oldid=809053594',
#   'question_text': 'who played smiley in tinker tailor soldier spy',
#   'short_answer': 'Gary Oldman'},
#  {'example_id': 1831925935427359666,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Temperance_%22Bones%22_Brennan&amp;oldid=853896998',
#   'question_text': 'when does brennan get pregnant the first time',
#   'short_answer': 'season six finale'},
#  {'example_id': 3858528398184026534,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Handmaid%27s_Tale_(TV_series)&amp;oldid=855805173',
#   'question_text': "when did season 2 of handmaid's tale start",
#   'short_answer': 'April 25 , 2018'},
#  {'example_id': 943042523042217090,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Dead_zone_(ecology)&amp;oldid=846165468',
#   'question_text': 'what causes a dead zone in the ocean',
#   'short_answer': 'excessive nutrient pollution from human activities coupled with other factors that deplete the oxygen'},
#  {'example_id': 933848034334224962,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Alejandro_Garc%C3%ADa_Padilla&amp;oldid=806947485',
#   'question_text': 'who is the present governor of puerto rico',
#   'short_answer': 'Alejandro Javier García Padilla'},
#  {'example_id': -8893375982061384676,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Neuromuscular_junction&amp;oldid=825334810',
#   'question_text': 'what affect does acetylcholine have on the sarcolemma',
#   'short_answer': 'can depolarize the muscle fiber , causing a cascade that eventually results in muscle contraction'},
#  {'example_id': -7138164833139291351,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Claire_Underwood&amp;oldid=808564257',
#   'question_text': "who plays claire underwood's mom on house of cards",
#   'short_answer': 'Ellen Burstyn'},
#  {'example_id': 3500591375797927439,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=2017_All-Ireland_Senior_Football_Championship_Final&amp;oldid=840534261',
#   'question_text': 'who won the all ireland football final 2017',
#   'short_answer': 'Dublin'},
#  {'example_id': -37045737725693627,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=My_Three_Sons&amp;oldid=804982671',
#   'question_text': 'who played robbie douglas wife on my three sons',
#   'short_answer': 'Tina Cole'},
#  {'example_id': -4929768916782793834,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=NBA_regular_season_records&amp;oldid=826336400',
#   'question_text': 'who hit the most 3 pointers in a nba game',
#   'short_answer': '13'},
#  {'example_id': 4158175306918787233,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Torrens_title&amp;oldid=862701733',
#   'question_text': 'the most common system of land title in australia',
#   'short_answer': 'Torrens title'},
#  {'example_id': -8103142725367912762,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Load-Out&amp;oldid=817942820',
#   'question_text': 'who sings with jackson brown on the load out',
#   'short_answer': 'Rosemary Butler'},
#  {'example_id': 5849682738867223756,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Derek_Shepherd&amp;oldid=807598253',
#   'question_text': "what happens to dr shepherd on grey's",
#   'short_answer': 'a fatal car accident'},
#  {'example_id': 2948950426674493761,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_100_(novel_series)&amp;oldid=864702888',
#   'question_text': 'when does book 2 of the 100 come out',
#   'short_answer': 'on September 25 , 2014'},
#  {'example_id': -952865350317764420,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Nissan_Armada&amp;oldid=841251596',
#   'question_text': 'when did the nissan armada body style change',
#   'short_answer': '2016'},
#  {'example_id': -6322508215120021793,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Down_syndrome&amp;oldid=800296742',
#   'question_text': 'where does the name down syndrome come from',
#   'short_answer': 'John Langdon Down , the British doctor who fully described the syndrome in 1866'},
#  {'example_id': 1878103752796630343,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Kiss_Me_thru_the_Phone&amp;oldid=844690605',
#   'question_text': 'the number on kiss me thru the phone',
#   'short_answer': '678 - 999 - 8212'},
#  {'example_id': 6288315334279365140,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=2017_NFL_season&amp;oldid=808996709',
#   'question_text': 'when does the regular football season start for nfl',
#   'short_answer': 'September 7 , 2017'},
#  {'example_id': 3709223798353122419,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=College_World_Series&amp;oldid=848708627',
#   'question_text': 'who does oregon state play in the college world series',
#   'short_answer': 'Arkansas'},
#  {'example_id': 6773093503551906644,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Talk:Best-selling_music_artist&amp;oldid=829542229',
#   'question_text': 'who sold more albums elvis or micheal jackson',
#   'short_answer': 'Michael Jackson'},
#  {'example_id': 9031499328718693227,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Santa_Clarita_Diet&amp;oldid=843290856',
#   'question_text': 'who plays officer garcia in santa clarita diet',
#   'short_answer': 'Natalie Morales'},
#  {'example_id': 8439419537951745210,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Great_Pyramid_of_Giza&amp;oldid=812631109',
#   'question_text': 'when was the great pyramid of giza created',
#   'short_answer': '10 to 20 - year period concluding around 2560 BC'},
#  {'example_id': -486666742702414275,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Rat_in_Mi_Kitchen&amp;oldid=834007981',
#   'question_text': 'who sang theres a rat in my kitchen',
#   'short_answer': 'UB40'},
#  {'example_id': 4180504611031164157,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Agriculture_in_India&amp;oldid=817715313',
#   'question_text': "the contribution of agriculture in india's gross domestic product is",
#   'short_answer': '13.7 % of the GDP'},
#  {'example_id': -3004924164988825720,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Super_Bowl_LII_halftime_show&amp;oldid=832806565',
#   'question_text': "who's doing the halftime show in 2018",
#   'short_answer': 'Justin Timberlake'},
#  {'example_id': 6693314673223715568,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Arroyo_Seco_Parkway&amp;oldid=795615569',
#   'question_text': 'when was the first freeway built in los angeles',
#   'short_answer': '1940'},
#  {'example_id': -5314958556249190860,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Wizard_of_Oz_(1939_film)&amp;oldid=801227682',
#   'question_text': 'when was the wizard of oz made in technicolor',
#   'short_answer': '1939'},
#  {'example_id': 6688943019362193045,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=2018_FIFA_World_Cup_disciplinary_record&amp;oldid=850906212',
#   'question_text': 'number of red card in world cup 2018',
#   'short_answer': '4'},
#  {'example_id': -5445819378004852366,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Solar_eclipse_of_August_21,_2017&amp;oldid=805009813',
#   'question_text': 'where does the solar eclipse start and end',
#   'short_answer': 'Pacific to the Atlantic coasts'},
#  {'example_id': -8077664172064245955,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=1938_in_the_United_States&amp;oldid=840944242',
#   'question_text': 'who was president of the united states in 1938',
#   'short_answer': 'Franklin D. Roosevelt'},
#  {'example_id': -1966227417665071507,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Uzo_Aduba&amp;oldid=815299615',
#   'question_text': 'who played warren in orange is the new black',
#   'short_answer': "Uzoamaka Nwanneka `` Uzo '' Aduba"},
#  {'example_id': 373104127868528520,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=England_at_the_FIFA_World_Cup&amp;oldid=856208693',
#   'question_text': 'when was last time england were in a world cup semi final',
#   'short_answer': '2018'},
#  {'example_id': 4007864640422927547,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Bataan_Death_March&amp;oldid=861756114',
#   'question_text': 'where did the bataan death march take place',
#   'short_answer': "from Saysain Point , Bagac , Bataan and Mariveles to Camp O'Donnell , Capas , Tarlac , via San Fernando , Pampanga , where the prisoners were loaded onto trains"},
#  {'example_id': 6916874456878908637,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Vince_Carter&amp;oldid=815988290',
#   'question_text': 'vince carter career high points in a game',
#   'short_answer': '51'},
#  {'example_id': 1942414039609292120,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Microchip_implant_(animal)&amp;oldid=845141206',
#   'question_text': 'where do they put the chip in dogs',
#   'short_answer': 'usually inserted below the skin at the back of the neck between the shoulder blades on the dorsal midline'},
#  {'example_id': 4938033218617022183,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Oort_cloud&amp;oldid=826115019',
#   'question_text': 'how long will it take voyager to pass through the oort cloud',
#   'short_answer': 'about 30,000 years'},
#  {'example_id': -8300738936662890425,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Scottish_Cup_finals&amp;oldid=851597684',
#   'question_text': 'when did rangers last win the scottish cup',
#   'short_answer': '2008 -- 09'},
#  {'example_id': -4338100494146837657,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Reye_syndrome&amp;oldid=806293414',
#   'question_text': 'an idiopathic condition associated with asprin treatment during certain viral infections',
#   'short_answer': 'Reye syndrome'},
#  {'example_id': 7784256323703412095,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Dr._Quinn,_Medicine_Woman&amp;oldid=824965049',
#   'question_text': 'who played anthony on dr quinn medicine woman',
#   'short_answer': 'Brenden Jefferson'},
#  {'example_id': 3726025565157976907,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Devil%27s_food_cake&amp;oldid=848047123',
#   'question_text': "what is the difference between devil's food and chocolate",
#   'short_answer': 'traditionally has more chocolate than a regular chocolate cake'},
#  {'example_id': -6160705439872736185,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=We_Belong_Together&amp;oldid=864847481',
#   'question_text': 'who is mariah carey talking about in we belong together',
#   'short_answer': 'her 1993 marriage to Tommy Mottola'},
#  {'example_id': -9111510312671706854,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=David_(Michelangelo)&amp;oldid=845314604',
#   'question_text': 'where is the original statue of david in italy',
#   'short_answer': "Florence 's Galleria dell'Accademia"},
#  {'example_id': -2094402239816792717,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Teton_Dam&amp;oldid=846244772',
#   'question_text': 'when did the teton dam break in idaho',
#   'short_answer': 'June 5 , 1976'},
#  {'example_id': 2951900109165683565,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Stand_by_Me_(film)&amp;oldid=834438054',
#   'question_text': 'when was the movie stand by me made',
#   'short_answer': '1986'},
#  {'example_id': -2708293033878648629,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Northern_Ireland_Open_(snooker)&amp;oldid=828579343',
#   'question_text': 'who won the northern ireland open snooker championship',
#   'short_answer': 'Mark Williams'},
#  {'example_id': 640359320151406496,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Eiffel_Tower&amp;oldid=805055507',
#   'question_text': 'is the eiffel tower made of steel or iron',
#   'short_answer': 'wrought iron'},
#  {'example_id': -5784654886324135475,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Fort_Myers,_Florida&amp;oldid=842850023',
#   'question_text': 'where is fort myers florida located in florida',
#   'short_answer': 'Coordinates : 26 ° 37 ′ N 81 ° 50 ′ W \ufeff / \ufeff 26.617 ° N 81.833 ° W \ufeff / 26.617 ; - 81.833 Coordinates : 26 ° 37 ′ N 81 ° 50 ′ W \ufeff / \ufeff 26.617 ° N 81.833 ° W'},
#  {'example_id': 8192163520121594104,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Hermaphroditus&amp;oldid=817492691',
#   'question_text': 'what is the name of the youth loved by salmacis',
#   'short_answer': 'Hermaphroditus'},
#  {'example_id': -6737088599889907252,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Magisterium_Series&amp;oldid=802276536',
#   'question_text': 'when is the next magisterium book coming out',
#   'short_answer': 'October 26 , 2017'},
#  {'example_id': -7356892532961931225,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=2018_Winter_Olympics_opening_ceremony&amp;oldid=835559840',
#   'question_text': 'who is performing at the 2018 olympics opening ceremony',
#   'short_answer': 'Ha Hyun - woo of the band Guckkasten'},
#  {'example_id': 998343663695069946,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Don%27t_You_(Forget_About_Me)&amp;oldid=807402542',
#   'question_text': "what film has the song don't you forget about me",
#   'short_answer': 'The Breakfast Club'},
#  {'example_id': -8182356273345535832,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=U.S._state_temperature_extremes&amp;oldid=826696733',
#   'question_text': 'what is the lowest temperature ever recorded in vermont',
#   'short_answer': '− 50 ° F / − 46 ° C'},
#  {'example_id': -8891996223650850662,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=1980_eruption_of_Mount_St._Helens&amp;oldid=850419882',
#   'question_text': 'when was the last time mount saint helens exploded',
#   'short_answer': 'May 18 , 1980'},
#  {'example_id': -2790870107266443659,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=7-Eleven&amp;oldid=856407655',
#   'question_text': 'how many 7 elevens are in the world',
#   'short_answer': '66,579'},
#  {'example_id': 4281649555568533553,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Temperance_%22Bones%22_Brennan&amp;oldid=853896998',
#   'question_text': 'when do booth and brennan become a couple',
#   'short_answer': 'At the start of Season 7'},
#  {'example_id': -3028639272116459845,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Nice_One_Cyril&amp;oldid=834486208',
#   'question_text': 'who sang nice one cyril nice one son',
#   'short_answer': 'Cockerel Chorus'},
#  {'example_id': 2514742258159466667,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Red_Red_Wine&amp;oldid=799903038',
#   'question_text': "who sang red red wine in the 80's",
#   'short_answer': 'Neil Diamond'},
#  {'example_id': 1838262396312467632,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Do_You_Hear_What_I_Hear%3F&amp;oldid=821387821',
#   'question_text': 'who wrote the christmas carol do you hear what i hear',
#   'short_answer': 'Noël Regney'},
#  {'example_id': 5962403166375658603,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Mariska_Hargitay&amp;oldid=836961989',
#   'question_text': 'who plays olivia benson on law and order',
#   'short_answer': 'Mariska Magdolna Hargitay'},
#  {'example_id': 4022670427899821671,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Fifty_Shades_of_Grey&amp;oldid=828409293',
#   'question_text': 'how many copies did fifty shades of grey sell',
#   'short_answer': 'over 125 million copies'},
#  {'example_id': 4066719445086111688,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Green_Bay,_Wisconsin&amp;oldid=800500003',
#   'question_text': 'when was the city of green bay founded',
#   'short_answer': '1634'},
#  {'example_id': 863627759632302847,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Hip_bone&amp;oldid=861010162',
#   'question_text': 'where do the ilium the ischium and the pubis meet',
#   'short_answer': 'acetabulum'},
#  {'example_id': -5429682726587441256,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Pak%27nSave&amp;oldid=807800248',
#   'question_text': 'who is the founder of pak n save',
#   'short_answer': 'Foodstuffs'},
#  {'example_id': -3401407261038960654,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Flora_of_India&amp;oldid=846651026',
#   'question_text': 'how many species of plants are found in india',
#   'short_answer': 'more than 50,000'},
#  {'example_id': -7501833780057394635,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Automotive_industry_in_the_United_Kingdom&amp;oldid=808145122',
#   'question_text': 'which non-british company owns both the famous british rolls- royce and mini brands',
#   'short_answer': 'BMW'},
#  {'example_id': 2143094671427392949,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Los_Angeles_Dodgers&amp;oldid=818470224',
#   'question_text': 'how many times have the dodgers gone to world series',
#   'short_answer': '19'},
#  {'example_id': -2934770478441635359,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Clavicle&amp;oldid=825173615',
#   'question_text': 'at what level is the clavicle with reference to the ribs',
#   'short_answer': 'directly above the first rib'},
#  {'example_id': 8277099848696406393,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Habeas_corpus_in_the_United_States&amp;oldid=834116611',
#   'question_text': 'when was the writ of habeas corpus created',
#   'short_answer': '1679'},
#  {'example_id': 2932920397550774009,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=John_Deere_Classic&amp;oldid=852767348',
#   'question_text': 'where are they playing the john deere classic golf tournament',
#   'short_answer': 'TPC Deere Run in the Quad Cities community of Silvis , Illinois'},
#  {'example_id': 3426780426941104126,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Covalent_bond&amp;oldid=800817761',
#   'question_text': 'what types of elements are involved in covalent bonding',
#   'short_answer': 'electron'},
#  {'example_id': 7732119899417519346,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Presidents_who_didn%27t_win_reelection&amp;oldid=850701399',
#   'question_text': 'when was the last time an incumbent president lost',
#   'short_answer': '1992'},
#  {'example_id': 6811068406378420022,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Baily_Bridge&amp;oldid=756566675',
#   'question_text': 'name the highest bridge in the world built by indian army',
#   'short_answer': 'Baily Bridge'},
#  {'example_id': -8172208811783219257,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=How_to_Pay_for_the_War:_A_Radical_Plan_for_the_Chancellor_of_the_Exchequer&amp;oldid=812162533',
#   'question_text': 'who wrote an article on war finance titled how to pay for the war',
#   'short_answer': 'John Maynard Keynes'},
#  {'example_id': -8198530274280695397,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Quicken_Loans_Arena&amp;oldid=815991043',
#   'question_text': 'where did the cavs play before the gund arena',
#   'short_answer': 'the Richfield Coliseum'},
#  {'example_id': -5087815032692832740,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Nuclear_arms_race&amp;oldid=841682830',
#   'question_text': 'who won the arms race in the cold war',
#   'short_answer': 'The United States'},
#  {'example_id': -4150603382042328900,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Autograph&amp;oldid=804990859',
#   'question_text': 'what is the proper term used for the signature given by celebrities to their fans',
#   'short_answer': 'Autograph'},
#  {'example_id': -2916958674789839650,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Willy_Wonka_%26_the_Chocolate_Factory&amp;oldid=800521727',
#   'question_text': 'who owns willy wonka and the chocolate factory',
#   'short_answer': 'Warner Bros.'},
#  {'example_id': 3597979053667756194,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Sign_of_the_Times_(Harry_Styles_song)&amp;oldid=818217077',
#   'question_text': 'who directed sign of the times music video',
#   'short_answer': 'Woodkid'},
#  {'example_id': -6893485745127069197,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Once_Upon_a_Time_(season_7)&amp;oldid=812223586',
#   'question_text': 'who plays cinderella in once upon a time 2017',
#   'short_answer': 'Dania Ramirez'},
#  {'example_id': 2355714216626604489,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Kit_Harington&amp;oldid=834335566',
#   'question_text': 'who plays jon snow in game of thrones',
#   'short_answer': "Christopher Catesby `` Kit '' Harington"},
#  {'example_id': -6724298500307671701,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Probability&amp;oldid=841773849',
#   'question_text': 'which term is defined as the chance that a given event will occur',
#   'short_answer': 'Probability'},
#  {'example_id': -5062521394110418171,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=90210_(season_3)&amp;oldid=814900085',
#   'question_text': 'when do they find out about emily 90210',
#   'short_answer': 'Blue Naomi'},
#  {'example_id': 4727928732038147507,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=CONCACAF_Gold_Cup&amp;oldid=796438157',
#   'question_text': 'who has won the most concacaf gold cups',
#   'short_answer': 'Mexico'},
#  {'example_id': 4383825374809762664,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Guardians_of_the_Galaxy_(1969_team)&amp;oldid=806919664',
#   'question_text': 'when did guardians of the galaxy comic book come out',
#   'short_answer': 'Jan. 1969'},
#  {'example_id': 168812018115981912,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Sea_level&amp;oldid=805024335',
#   'question_text': 'where is sea level measured in the uk',
#   'short_answer': 'Newlyn in Cornwall between 1915 and 1921'},
#  {'example_id': 2993933252209268267,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Flight_of_the_Navigator&amp;oldid=854971824',
#   'question_text': "80's movie about a kid in a spaceship",
#   'short_answer': 'Flight of the Navigator'},
#  {'example_id': -3474241572583305206,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Texas_Revolution_battles&amp;oldid=825807040',
#   'question_text': 'where did the first battle of the texas revolution take place',
#   'short_answer': 'Gonzales'},
#  {'example_id': -2441087096771363581,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Nucleotide&amp;oldid=824125987',
#   'question_text': 'what are the basic components of a nucleotide',
#   'short_answer': 'a nitrogenous base , a five - carbon sugar ( ribose or deoxyribose ) , and at least one phosphate group'},
#  {'example_id': 8871621576322140311,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Due_Process_Clause&amp;oldid=852967821',
#   'question_text': 'where is the due process clause found in the constitution',
#   'short_answer': 'The Fifth and Fourteenth Amendments'},
#  {'example_id': -4959914091392415423,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Blake_Gibbons&amp;oldid=777092160',
#   'question_text': 'who plays the stunt man in the geico commercial',
#   'short_answer': 'Blake Gibbons'},
#  {'example_id': -8349982966820050308,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_mother_of_parliaments_(expression)&amp;oldid=832418982',
#   'question_text': 'why is the british parliament known as the mother of parliaments',
#   'short_answer': 'because of the adoption of the Westminster model of parliamentary democracy by many countries of the former British Empire'},
#  {'example_id': -5545578579438779177,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Madam_Secretary_(TV_series)&amp;oldid=866241179',
#   'question_text': 'who plays the cia director on madam secretary',
#   'short_answer': 'Patrick Breen'},
#  {'example_id': 7217081375609975040,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Religion_in_the_Soviet_Union&amp;oldid=843536747',
#   'question_text': 'what was the official religion of the soviet union',
#   'short_answer': 'atheism'},
#  {'example_id': 2285135311574954905,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Crazy_Little_Thing_Called_Love&amp;oldid=865517342',
#   'question_text': 'who wrote crazy little thing called love original artist',
#   'short_answer': 'Freddie Mercury'},
#  {'example_id': 7445075245440727123,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Good_Doctor_(TV_series)&amp;oldid=816158324',
#   'question_text': 'who is the actor that plays the good dr',
#   'short_answer': 'Freddie Highmore'},
#  {'example_id': -1902033174435166138,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Resource-based_view&amp;oldid=799437966',
#   'question_text': 'the resourced based view of the firm (rbv school) is',
#   'short_answer': 'an economic tool used to determine the strategic resources available to a firm'},
#  {'example_id': 573136243499292804,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Myelin&amp;oldid=857137138',
#   'question_text': 'the myelin sheath that covers many cns axons is formed by',
#   'short_answer': 'the concentric wrapping of an oligodendrocyte or Schwann cell process around the axon'},
#  {'example_id': -4796448679885090319,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Wasp_Factory&amp;oldid=836190834',
#   'question_text': 'who does frank kill in the wasp factory',
#   'short_answer': 'three of his relatives : two cousins and his younger brother'},
#  {'example_id': -1345429915217925219,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_National_Basketball_Association_career_scoring_leaders&amp;oldid=866403138',
#   'question_text': 'who is the leading scorer in the nba',
#   'short_answer': 'Kareem Abdul - Jabbar'},
#  {'example_id': 1494709351134236162,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=When_Calls_the_Heart&amp;oldid=852814232',
#   'question_text': 'who plays mr coulter on when calls the heart',
#   'short_answer': 'Kavan Smith'},
#  {'example_id': -7860701981144002382,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Gone_with_the_Wind_(film)&amp;oldid=850467743',
#   'question_text': 'where does the movie gone with the wind take place',
#   'short_answer': 'the American South'},
#  {'example_id': 7933393583242822413,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Three-point_field_goal&amp;oldid=804387919',
#   'question_text': 'when did the nba institute the 3 point shot',
#   'short_answer': '1979 -- 80 season'},
#  {'example_id': 527510741729495693,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Chennai_Super_Kings&amp;oldid=801236737',
#   'question_text': 'who is the captain of chennai super king',
#   'short_answer': 'Mahendra Singh Dhoni'},
#  {'example_id': -5260945611712174436,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=See_You_Again_(Miley_Cyrus_song)&amp;oldid=816896243',
#   'question_text': 'who wrote see you again by miley cyrus',
#   'short_answer': 'Miley Cyrus'},
#  {'example_id': 1737560198485185802,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Clifford_the_Big_Red_Dog_(TV_series)&amp;oldid=841291185',
#   'question_text': 'who is the voice for clifford the big red dog',
#   'short_answer': 'John Ritter'},
#  {'example_id': 6554423586005355606,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Super_Bowl_LII&amp;oldid=835694389',
#   'question_text': 'where is the super bowl being played at this year',
#   'short_answer': 'U.S. Bank Stadium in Minneapolis , Minnesota'},
#  {'example_id': 6182731490713533255,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Tiger_Woods&amp;oldid=834033270',
#   'question_text': 'when did tiger woods win his last pga tournament',
#   'short_answer': '2007'},
#  {'example_id': -3182539626890716082,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Waybury_Inn&amp;oldid=751560913',
#   'question_text': 'where was the newhart show filmed in vermont',
#   'short_answer': 'The Waybury Inn'},
#  {'example_id': 595320554055391627,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Edelweiss_(song)&amp;oldid=864844062',
#   'question_text': 'who sings the song in the man in the high castle',
#   'short_answer': 'Jeanette Olsson'},
#  {'example_id': -787607155911348838,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Whose_Line_Is_It_Anyway%3F_(U.S._TV_series)&amp;oldid=801983645',
#   'question_text': "who's line is it anyway original cast",
#   'short_answer': 'Colin Mochrie'},
#  {'example_id': 2607445319782135485,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=United_States_Department_of_Education&amp;oldid=823664408',
#   'question_text': 'how many employees does department of education have',
#   'short_answer': 'approximately 4,400'},
#  {'example_id': 8476233861273398770,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Beanie_Babies&amp;oldid=835128148',
#   'question_text': 'when did the first beanie baby come out',
#   'short_answer': '1993'},
#  {'example_id': -4273721796149572327,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Economy_of_Argentina&amp;oldid=856922351',
#   'question_text': 'how much money does argentina make from tourism',
#   'short_answer': 'over US $22 billion'},
#  {'example_id': 689672303808888709,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Macy%27s_Thanksgiving_Day_Parade&amp;oldid=807068910',
#   'question_text': "where is the macy's thanksgiving day parade held",
#   'short_answer': 'Manhattan'},
#  {'example_id': -6990397748475583488,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=New_England_Colonies&amp;oldid=826760958',
#   'question_text': 'what religious groups lived in the new england colonies',
#   'short_answer': 'Puritans'},
#  {'example_id': -4619130173101810856,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Blood_lipids&amp;oldid=788307668',
#   'question_text': 'where do long-chain fatty acids first enter the bloodstream',
#   'short_answer': 'Blood lipids ( or blood fats ) are lipids in the blood , either free or bound to other molecules . They are mostly transported in a protein capsule , and the density of the lipids and type of protein determines the fate of the particle and its influence on metabolism . The concentration of blood lipids depends on intake and excretion from the intestine , and uptake and secretion from cells . Blood lipids are mainly fatty acids and cholesterol . Hyperlipidemia is the presence of elevated or abnormal levels of lipids and / or lipoproteins in the blood , and is a major risk factor for cardiovascular disease .'},
#  {'example_id': -7507801968180617961,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Retina&amp;oldid=856647523',
#   'question_text': 'where is the retina located in the eye',
#   'short_answer': "innermost , light - sensitive layer , or `` coat '' , of shell tissue of the eye"},
#  {'example_id': -5471096204349170309,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Elsa_(Disney)&amp;oldid=806165100',
#   'question_text': 'who did the voice for elsa in frozen',
#   'short_answer': 'Eva Bella'},
#  {'example_id': -3586117030178166108,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Pam_Beesly&amp;oldid=865561578',
#   'question_text': 'what episode in season 3 do jim and pam get together',
#   'short_answer': "the season finale , `` The Job , ''"},
#  {'example_id': 4061616414492078240,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_best-selling_music_artists&amp;oldid=857086123',
#   'question_text': 'who has sold the most records to date',
#   'short_answer': 'The Beatles'},
#  {'example_id': -4848056930689862624,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=God_of_War_(2018_video_game)&amp;oldid=843493176',
#   'question_text': 'when does god of war come out for pc',
#   'short_answer': 'April 20 , 2018'},
#  {'example_id': 1715877442937695025,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Article_Five_of_the_United_States_Constitution&amp;oldid=844853035',
#   'question_text': 'how do you pass an amendment to the constitution',
#   'short_answer': 'must be ratified by either -- as determined by Congress -- the legislatures of three - quarters of the states or state ratifying conventions in three - quarters of the states'},
#  {'example_id': -9058380106399547915,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Croatia_national_football_team&amp;oldid=854574405',
#   'question_text': 'when did croatia finish 3rd in the world cup',
#   'short_answer': '1998'},
#  {'example_id': -8663891343543535834,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=I%27m_a_Celebrity...Get_Me_Out_of_Here!_(Australian_TV_series)&amp;oldid=836890836',
#   'question_text': 'who won i am a celebrity get me out of here australia',
#   'short_answer': "Fiona O'Loughlin"},
#  {'example_id': 8341815299893034731,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Mother_India&amp;oldid=845388904',
#   'question_text': 'nominated in the best foreign film category at the oscars mother india lost to',
#   'short_answer': 'Nights of Cabiria'},
#  {'example_id': -1714809098348772549,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=National_Guard_of_the_United_States&amp;oldid=850261289',
#   'question_text': 'how many members of the national guard are there',
#   'short_answer': '450,100'},
#  {'example_id': -7346815694834390822,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Naked_Truth_(How_I_Met_Your_Mother)&amp;oldid=808186979',
#   'question_text': 'who played edward 40 hands how i met your mother',
#   'short_answer': 'Marshall'},
#  {'example_id': -8942693796004139638,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_House_on_Mango_Street&amp;oldid=843822997',
#   'question_text': 'where does esperanza live in the house on mango street',
#   'short_answer': 'Chicago'},
#  {'example_id': 4091422228616325266,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Minor_Details&amp;oldid=850826593',
#   'question_text': 'who is making everyone sick in minor details',
#   'short_answer': 'Mia'},
#  {'example_id': 1015729085850235489,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Maslow%27s_hierarchy_of_needs&amp;oldid=832879603',
#   'question_text': 'at the bottom of the hierarchy of needs is',
#   'short_answer': 'Physiological needs'},
#  {'example_id': 6005064217427271376,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Tidal_range&amp;oldid=805593009',
#   'question_text': 'the greatest range between consecutive high and low tides occurs at which lunar phase',
#   'short_answer': '( full moon ) .'},
#  {'example_id': -8969973848417416015,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=If_You_Don%27t_Know_Me_by_Now&amp;oldid=811610595',
#   'question_text': "when did if you don't know me by now come out",
#   'short_answer': 'in 1972'},
#  {'example_id': -8594976734343038386,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Kansas_City_Chiefs&amp;oldid=810012462',
#   'question_text': 'when is the last time the kansas city chiefs went to the superbowl',
#   'short_answer': '1969'},
#  {'example_id': 7347798047808818529,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Light-independent_reactions&amp;oldid=833363610',
#   'question_text': 'where does the calvin cycle (dark reactions) take place',
#   'short_answer': 'in the stroma'},
#  {'example_id': -8541939311087736548,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=IW_engine&amp;oldid=848955243',
#   'question_text': 'what engine does call of duty run on',
#   'short_answer': 'The IW engine'},
#  {'example_id': 2427033971503973493,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_K.C._Undercover_episodes&amp;oldid=809052509',
#   'question_text': 'when does kc undercover come back on 2017',
#   'short_answer': 'July 7 , 2017'},
#  {'example_id': 1966953596481400380,
# ...
#   'short_answer': 'along 15 blocks of Hollywood Boulevard and three blocks of Vine Street in Hollywood , California'},
#  {'example_id': 4404765836893587819,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Freedom_Day_(South_Africa)&amp;oldid=857169559',
#   'question_text': 'what is the significance of april 27 1994 in south africa',
#   'short_answer': 'first post-apartheid elections'},
#  {'example_id': -927805218867163489,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Timeline_of_the_Manhattan_Project&amp;oldid=833835334',
#   'question_text': 'when did the manhattan project began and end',
#   'short_answer': 'From 1942 to 1946'},
#  {'example_id': -1751554621674852268,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Susan_Banks&amp;oldid=858508984',
#   'question_text': 'who is playing susan banks on days of our lives august 2018',
#   'short_answer': 'Stacy Haiduk'},
#  {'example_id': -2268197813367676764,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Cotton_Fields&amp;oldid=794743678',
#   'question_text': 'who sang the song cotton fields back home',
#   'short_answer': 'Huddie Ledbetter'},
#  {'example_id': -5726624501264261924,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Intestinal_epithelium&amp;oldid=841903199',
#   'question_text': 'role of epithelial tissue in the digestive system',
#   'short_answer': 'absorbing helpful substances and providing a barrier against harmful substances'},
#  {'example_id': 2189733729430875816,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Bold_and_the_Beautiful_cast_members&amp;oldid=856427210',
#   'question_text': 'who is zoey on the bold and beautiful',
#   'short_answer': 'Kiara Barnes'},
#  {'example_id': -2777281230452740129,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Demographics_of_New_Zealand&amp;oldid=802122376',
#   'question_text': 'what is the total population of new zealand',
#   'short_answer': '4,693,000'},
#  {'example_id': -6117582494045478038,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Kurtz_(Heart_of_Darkness)&amp;oldid=846609846',
#   'question_text': 'who is mr kurtz in heart of darkness',
#   'short_answer': 'A trader of ivory in Africa and commander of a trading post'},
#  {'example_id': -5613061131190838684,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=1st_Lok_Sabha&amp;oldid=789008180',
#   'question_text': 'who was the first speaker of the lok sabha',
#   'short_answer': 'Ganesh Vasudev Mavlankar'},
#  {'example_id': -3969327344205719788,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Planet_of_the_Apes&amp;oldid=815057334',
#   'question_text': 'when did planet of the apes come out',
#   'short_answer': 'July 14 , 2017'},
#  {'example_id': -5498799115628829352,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=(There%27s)_Always_Something_There_to_Remind_Me&amp;oldid=864591212',
#   'question_text': 'who sang always something there to remind me original',
#   'short_answer': 'Lou Johnson'},
#  {'example_id': -2805706455618792742,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Minister_of_Railways_(India)&amp;oldid=804544085',
#   'question_text': 'who is recently appointed as union railway minister',
#   'short_answer': 'Piyush Goyal'},
#  {'example_id': -9124097907989779648,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=I_Wanna_Talk_About_Me&amp;oldid=798270646',
#   'question_text': 'who sings i want to talk about me',
#   'short_answer': 'Toby Keith'},
#  {'example_id': 8829494174902690646,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Politics_of_Texas&amp;oldid=842285418',
#   'question_text': 'when was the last time texas was a democratic state',
#   'short_answer': 'the mid-1990s'},
#  {'example_id': 4106651356247856458,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=One-child_policy&amp;oldid=809905757',
#   'question_text': 'when did china adopt the one child policy',
#   'short_answer': '1979'},
#  {'example_id': 7034798587250911824,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Stapes&amp;oldid=841842044',
#   'question_text': 'the medical term for removal of the stapes is',
#   'short_answer': 'stapedectomy'},
#  {'example_id': -782287682246517661,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=John_DiMaggio&amp;oldid=797516195',
#   'question_text': 'who does the voice of jake the dog',
#   'short_answer': 'John William DiMaggio'},
#  {'example_id': -7858921775443798478,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Merry_Clayton&amp;oldid=865457286',
#   'question_text': 'who sings with the rolling stones gimme shelter',
#   'short_answer': 'Merry Clayton'},
#  {'example_id': 6014669771832375597,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Helena_(song)&amp;oldid=805184872',
#   'question_text': 'meaning of the song helena by my chemical romance',
#   'short_answer': "about the band members Gerard Way and Mikey Way 's late grandmother"},
#  {'example_id': -3242764249922422987,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=I_Don%27t_Wanna_Lose_Your_Love&amp;oldid=830409320',
#   'question_text': "who sings i don't want to lose your love tonight",
#   'short_answer': "John O'Banion"},
#  {'example_id': -7436989877306560462,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Presidents_of_Iowa_State_University&amp;oldid=811479369',
#   'question_text': 'who is the president of iowa state university',
#   'short_answer': 'Wendy Wintersteen'},
#  {'example_id': -2480770367294256783,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Dionysia&amp;oldid=831872679',
#   'question_text': 'what would the winner of the greek theater contest win',
#   'short_answer': 'a wreath of ivy'},
#  {'example_id': 5491898328495714208,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Tenochtitlan&amp;oldid=808750406',
#   'question_text': 'what was the capital city of the aztec empire',
#   'short_answer': 'Tenochtitlan'},
#  {'example_id': 1460150908755325945,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Middle_Island_(Lake_Erie)&amp;oldid=822967039',
#   'question_text': 'what is the southern most point in canada',
#   'short_answer': 'Middle Island'},
#  {'example_id': 8686783819023863930,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Women%27s_College_World_Series&amp;oldid=804115562',
#   'question_text': 'where is the college softball world series played',
#   'short_answer': 'Oklahoma City'},
#  {'example_id': -8007745231644537044,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Star_Wars:_Galaxy%27s_Edge&amp;oldid=843571732',
#   'question_text': 'when will star wars land be finished at disneyland',
#   'short_answer': 'Summer 2019'},
#  {'example_id': 1296506107351859987,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Man_from_Snowy_River_(1982_film)&amp;oldid=798106384',
#   'question_text': 'who played jessica in man from snowy river',
#   'short_answer': 'Sigrid Thornton'},
#  {'example_id': 5012042454151241130,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Jurassic_World:_Fallen_Kingdom&amp;oldid=821843627',
#   'question_text': 'when does the second jurassic world come out',
#   'short_answer': 'June 22 , 2018'},
#  {'example_id': -3063389654233276673,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=RuPaul%27s_Drag_Race&amp;oldid=856610328',
#   'question_text': "what's the latest season of rupaul's drag race",
#   'short_answer': '10'},
#  {'example_id': 5933013167263716451,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Our_Story_(book)&amp;oldid=704880132',
#   'question_text': 'who had the rights to the krays book',
#   'short_answer': 'Sidgwick & Jackson'},
#  {'example_id': -1086885244372707200,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Living_presidents_and_vice_presidents_of_the_United_States&amp;oldid=828011596',
#   'question_text': 'who are the living presidents of the united states',
#   'short_answer': 'George H.W. Bush'},
#  {'example_id': 5094013686681021739,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Shawshank_Redemption&amp;oldid=804573297',
#   'question_text': 'where did andy go at the end of shawshank redemption',
#   'short_answer': 'Zihuatanejo'},
#  {'example_id': -206400180029996332,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=French_and_Indian_War&amp;oldid=806908111',
#   'question_text': 'where did the french and indian war start',
#   'short_answer': 'Pennsylvania'},
#  {'example_id': -3744536841397751583,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Saudi_Arabian-led_intervention_in_Yemen&amp;oldid=816147702',
#   'question_text': 'what is the reason of war between saudi and yemen',
#   'short_answer': 'influence the outcome of the Yemeni Civil War in favour of the government of President Abdrabbuh Mansur Hadi'},
#  {'example_id': -363114973648833575,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Big_Mac&amp;oldid=835808197',
#   'question_text': "what is mcdonald's special sauce on the big mac",
#   'short_answer': 'store - bought mayonnaise , sweet pickle relish and yellow mustard whisked together with vinegar , garlic powder , onion powder and paprika'},
#  {'example_id': 4643481838911894154,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Mukurthi_National_Park&amp;oldid=777762325',
#   'question_text': 'mukkurthi national park in nilgiri hills is the sanctuary for',
#   'short_answer': 'the Nilgiri tahr'},
#  {'example_id': -8278674475676302791,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Joshua_Jackson&amp;oldid=808310206',
#   'question_text': 'who played charlie conway in the mighty ducks',
#   'short_answer': 'Joshua Browning Carter Jackson'},
#  {'example_id': -965537606789995861,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Interphase&amp;oldid=825294844',
#   'question_text': 'what happens during the s stage of interphase',
#   'short_answer': 'the cell duplicates its DNA'},
#  {'example_id': -6038991383946787631,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Billy_Redden&amp;oldid=831658916',
#   'question_text': 'who was the boy that played the banjo in the movie deliverance',
#   'short_answer': 'Billy Redden'},
#  {'example_id': 3628211598376266653,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Secretariat_(horse)&amp;oldid=807501615',
#   'question_text': 'who is the greatest horse that ever lived',
#   'short_answer': 'Secretariat'},
#  {'example_id': 9051471004291157776,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Michael_Myers_(Halloween)&amp;oldid=833070258',
#   'question_text': 'who played the original michael myers on halloween',
#   'short_answer': 'Nick Castle for most of the film , with Tony Moran and Tommy Lee Wallace substituting in during the final scenes'},
#  {'example_id': 3560137892924688215,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=John_Rowland_(Desperate_Housewives)&amp;oldid=841966528',
#   'question_text': 'when does carlos find out about the affair',
#   'short_answer': 'the first season finale'},
#  {'example_id': 7105550231026063554,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Mamma_Mia!_(film)&amp;oldid=855683099',
#   'question_text': 'when did mamma mia film first come out',
#   'short_answer': 'June 30 , 2008'},
#  {'example_id': -2629193999423027513,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Indo-Pakistani_War_of_1965&amp;oldid=854374707',
#   'question_text': 'who is the real winner of 1965 war',
#   'short_answer': 'India'},
#  {'example_id': 4396807448961702946,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=List_of_Hannah_Montana_characters&amp;oldid=807598335',
#   'question_text': 'who plays the school nurse in hannah montana forever',
#   'short_answer': 'Christine Taylor'},
#  {'example_id': 3087569062326276413,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Jazz_Age&amp;oldid=835331519',
#   'question_text': 'when did jazz became popular in the united states',
#   'short_answer': 'a period in the 1920s and 1930s'},
#  {'example_id': -996212718451075990,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Masters_Tournament&amp;oldid=843394256',
#   'question_text': 'what is the cut for the masters golf',
#   'short_answer': 'in the top 50 places ( ties counting )'},
#  {'example_id': -91301088758385947,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Neha_Mehta&amp;oldid=803108910',
#   'question_text': 'anjali tarak mehta ka ooltah chashmah real name',
#   'short_answer': 'Neha Mehta'},
#  {'example_id': 6353775553793434720,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Union_budget_of_India&amp;oldid=840658083',
#   'question_text': 'the govt of india presents its annual budget in the',
#   'short_answer': 'Finance bill'},
#  {'example_id': -832719739792822768,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Percy_Jackson:_Sea_of_Monsters&amp;oldid=800200009',
#   'question_text': 'who played thalia in the sea of monsters',
#   'short_answer': 'Paloma Kwiatkowski'},
#  {'example_id': -5799458352751876470,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Curate&amp;oldid=810680297',
#   'question_text': 'what is a curate in the anglican church',
#   'short_answer': 'priests ( or , in the first year , transitional deacons ) who are in their first post after ordination ( usually for four years ) , and are completing their training ( not unlike an apprenticeship )'},
#  {'example_id': -2082062085870211435,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=White_House_Christmas_tree&amp;oldid=814230523',
#   'question_text': 'where did the white house christmas tree come from this year',
#   'short_answer': 'Octono , Wisconsin'},
#  {'example_id': -4692634889885009991,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Ivan_L._Moody&amp;oldid=832188573',
#   'question_text': 'who is the lead singer in five finger death punch',
#   'short_answer': 'Ivan L. Moody'},
#  {'example_id': -5071339221364584790,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Atmosphere_of_Jupiter&amp;oldid=813126722',
#   'question_text': 'what physical effect causes circulation in the atmosphere of jupiter',
#   'short_answer': 'convection'},
#  {'example_id': -8522330958978003137,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Field_goal&amp;oldid=804364049',
#   'question_text': 'who holds the record for the longest field goal',
#   'short_answer': 'Matt Prater'},
#  {'example_id': -7286162320826223772,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Riverdale_(2017_TV_series)&amp;oldid=801135000',
#   'question_text': 'when are they coming out with season 2 of riverdale',
#   'short_answer': 'October 11 , 2017'},
#  {'example_id': 6683099208215685252,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Book_of_Eli&amp;oldid=852397103',
#   'question_text': 'when did the book of eli come out',
#   'short_answer': '2010'},
#  {'example_id': 1596063567785174214,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Grateful_Dead&amp;oldid=800333759',
#   'question_text': 'how many songs did the grateful dead play',
#   'short_answer': 'songs documented to have been played by the band exceeds 500'},
#  {'example_id': 1869348386967965728,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=Game_of_Thrones_(season_7)&amp;oldid=807526721',
#   'question_text': 'what season of the game of thrones is it',
#   'short_answer': 'seventh season'},
#  {'example_id': 7316836837270285322,
#   'document_url': 'https://en.wikipedia.org//w/index.php?title=The_Breakfast_Club_(radio_show)&amp;oldid=833213489',
#   'question_text': 'what station is the breakfast club on iheartradio',
#   'short_answer': 'Power 105.1'},
#  ...]

# %%
test = ['blah blah blah', 'bleh yikes', 'loud car', 'angry dog']

# %%
test
# Out:
# ['blah blah blah', 'bleh yikes', 'loud car', 'angry dog']

# %%
int('yikes' in test)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
any(['yikes' in substring for substring in test])
# Out:
# True

# %%
['Alice may not have a MUA on her computer' in doc['_source']['document_text_clean'] for doc in res['hits']['hits']]
# Out:
# [True, True, False, False, False]

# %%
# ms
res
# Out:
# {'took': 15,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1627, 'relation': 'eq'},
#   'max_score': 8.69899,
#   'hits': [{'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '21875',
#     '_score': 8.69899,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email&amp;oldid=843387842',
#      'document_title': 'Email',
#      'document_text_clean': "Email - wikipedia  Email  Jump to : navigation , search This article is about the communications medium . For the former manufacturing conglomerate , see Email Limited . `` Inbox '' redirects here . For the Google product , see Inbox by Gmail . This screenshot shows the `` Inbox '' page of an email client , where users can see new emails and take actions , such as reading , deleting , saving , or responding to these messages The at sign , a part of every SMTP email address  Electronic mail ( email or e-mail ) is a method of exchanging messages ( `` mail '' ) between people using electronic devices . Email first entered limited use in the 1960s and by the mid-1970s had taken the form now recognized as email . Email operates across computer networks , which today is primarily the Internet . Some early email systems required the author and the recipient to both be online at the same time , in common with instant messaging . Today 's email systems are based on a store - and - forward model . Email servers accept , forward , deliver , and store messages . Neither the users nor their computers are required to be online simultaneously ; they need to connect only briefly , typically to a mail server or a webmail interface , for as long as it takes to send or receive messages .   Originally an ASCII text - only communications medium , Internet email was extended by Multipurpose Internet Mail Extensions ( MIME ) to carry text in other character sets and multimedia content attachments . International email , with internationalized email addresses using UTF - 8 , has been standardized , but as of 2017 it has not been widely adopted .   The history of modern Internet email services reaches back to the early ARPANET , with standards for encoding email messages published as early as 1973 ( RFC 561 ) . An email message sent in the early 1970s looks very similar to a basic email sent today . Email had an important role in creating the Internet , and the conversion from ARPANET to the Internet in the early 1980s produced the core of the current services .     Contents  ( hide )   1 Terminology   2 Origin   3 Operation   4 Message format   4.1 Message header   4.1. 1 Header fields     4.2 Message body   4.2. 1 Content encoding   4.2. 2 Plain text and HTML       5 Servers and client applications   5.1 Filename extensions   5.2 URI scheme mailto     6 Types   6.1 Web - based email   6.2 POP3 email services   6.3 IMAP email servers   6.4 MAPI email servers     7 Uses   7.1 Business and organizational use   7.1. 1 Email marketing     7.2 Personal use   7.2. 1 Personal computer   7.2. 2 Mobile   7.2. 3 Declining use among young people       8 Issues   8.1 Attachment size limitation   8.2 Information overload   8.3 Spam   8.4 Malware   8.5 Email spoofing   8.6 Email bombing   8.7 Privacy concerns   8.8 Flaming   8.9 Email bankruptcy   8.10 Internationalization   8.11 Tracking of sent mail     9 See also   10 References   11 Further reading   12 External links      Terminology ( edit )   Historically , the term electronic mail was used generically for any electronic document transmission . For example , several writers in the early 1970s used the term to describe fax document transmission . As a result , it is difficult to find the first citation for the use of the term with the more specific meaning it has today .   Electronic mail has been most commonly called email or e-mail since around 1993 , but variations of the spelling have been used :    email is the most common form used online , and is required by IETF Requests for Comments ( RFC ) and working groups and increasingly by style guides . This spelling also appears in most dictionaries .   e-mail is the format that sometimes appears in edited , published American English and British English writing as reflected in the Corpus of Contemporary American English data , but is falling out of favor in some style guides .   mail was the form used in the original protocol st ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '76097',
#     '_score': 8.698753,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email&amp;oldid=849062629',
#      'document_title': 'Email',
#      'document_text_clean': "Email - wikipedia  Email  This article is about the communications medium . For the former manufacturing conglomerate , see Email Limited . `` Inbox '' redirects here . For the Google product , see Inbox by Gmail . This screenshot shows the `` Inbox '' page of an email client , where users can see new emails and take actions , such as reading , deleting , saving , or responding to these messages The at sign , a part of every SMTP email address  Electronic mail ( email or e-mail ) is a method of exchanging messages ( `` mail '' ) between people using electronic devices . Invented by Ray Tomlinson , email first entered limited use in the 1960s and by the mid-1970s had taken the form now recognized as email . Email operates across computer networks , which today is primarily the Internet . Some early email systems required the author and the recipient to both be online at the same time , in common with instant messaging . Today 's email systems are based on a store - and - forward model . Email servers accept , forward , deliver , and store messages . Neither the users nor their computers are required to be online simultaneously ; they need to connect only briefly , typically to a mail server or a webmail interface , for as long as it takes to send or receive messages .   Originally an ASCII text - only communications medium , Internet email was extended by Multipurpose Internet Mail Extensions ( MIME ) to carry text in other character sets and multimedia content attachments . International email , with internationalized email addresses using UTF - 8 , has been standardized , but as of 2017 it has not been widely adopted .   The history of modern Internet email services reaches back to the early ARPANET , with standards for encoding email messages published as early as 1973 ( RFC 561 ) . An email message sent in the early 1970s looks very similar to a basic email sent today . Email had an important role in creating the Internet , and the conversion from ARPANET to the Internet in the early 1980s produced the core of the current services .   Contents  ( hide )   1 Terminology   2 Origin   3 Operation   4 Message format   4.1 Message header   4.1. 1 Header fields     4.2 Message body   4.2. 1 Content encoding   4.2. 2 Plain text and HTML       5 Servers and client applications   5.1 Filename extensions   5.2 URI scheme mailto     6 Types   6.1 Web - based email   6.2 POP3 email services   6.3 IMAP email servers   6.4 MAPI email servers     7 Uses   7.1 Business and organizational use   7.1. 1 Email marketing     7.2 Personal use   7.2. 1 Personal computer   7.2. 2 Mobile   7.2. 3 Declining use among young people       8 Issues   8.1 Attachment size limitation   8.2 Information overload   8.3 Spam   8.4 Malware   8.5 Email spoofing   8.6 Email bombing   8.7 Privacy concerns   8.8 Flaming   8.9 Email bankruptcy   8.10 Internationalization   8.11 Tracking of sent mail     9 See also   10 References   11 Further reading   12 External links    Terminology ( edit )   Historically , the term electronic mail was used generically for any electronic document transmission . For example , several writers in the early 1970s used the term to describe fax document transmission . As a result , it is difficult to find the first citation for the use of the term with the more specific meaning it has today .   Electronic mail has been most commonly called email or e-mail since around 1993 , but variations of the spelling have been used :    email is the most common form used online , and is required by IETF Requests for Comments ( RFC ) and working groups and increasingly by style guides . This spelling also appears in most dictionaries .   e-mail is the format that sometimes appears in edited , published American English and British English writing as reflected in the Corpus of Contemporary American English data , but is falling out of favor in some style guides .   mail was the form used in the original protocol standard ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '0',
#     '_score': 8.678847,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email_marketing&amp;oldid=814071202',
#      'document_title': 'Email_marketing',
#      'document_text_clean': "Email marketing - Wikipedia  Email marketing  Jump to : navigation , search      ( hide ) This article has multiple issues . Please help improve it or discuss these issues on the talk page . ( Learn how and when to remove these template messages )      This article needs additional citations for verification . Please help improve this article by adding citations to reliable sources . Unsourced material may be challenged and removed . ( September 2014 ) ( Learn how and when to remove this template message )         This article possibly contains original research . Please improve it by verifying the claims made and adding inline citations . Statements consisting only of original research should be removed . ( January 2015 ) ( Learn how and when to remove this template message )    ( Learn how and when to remove this template message )       Part of a series on     Internet marketing       Search engine optimization   Local search engine optimisation   Social media marketing   Email marketing   Referral marketing   Content marketing   Native advertising       Search engine marketing       Pay - per - click   Cost per impression   Search analytics   Web analytics       Display advertising       Ad blocking   Contextual advertising   Behavioral targeting       Affiliate marketing       Cost per action   Revenue sharing       Mobile advertising                 Email marketing is the act of sending a commercial message , typically to a group of people , using email . In its broadest sense , every email sent to a potential or current customer could be considered email marketing . It usually involves using email to send advertisements , request business , or solicit sales or donations , and is meant to build loyalty , trust , or brand awareness . Marketing emails can be sent to a purchased lead list or a current customer database . The term usually refers to sending email messages with the purpose of enhancing a merchant 's relationship with current or previous customers , encouraging customer loyalty and repeat business , acquiring new customers or convincing current customers to purchase something immediately , and sharing third - party ads .     Contents  ( hide )   1 History   2 Types   2.1 Transactional emails   2.2 Direct emails   2.2. 1 Mobile email marketing       3 Comparison to traditional mail   3.1 Advantages   3.2 Disadvantages     4 Opt - in email advertising   5 Legal requirements   5.1 Australia   5.2 Canada   5.3 European Union   5.4 United States     6 See also   7 References      History   Email marketing has evolved rapidly alongside the technological growth of the 21st century . Prior to this growth , when emails were novelties to the majority of customers , email marketing was not as effective . In 1978 , Gary Thuerk of Digital Equipment Corporation ( DEC ) sent out the first mass email to approximately 400 potential clients via the Advanced Research Projects Agency Network ( ARPANET ) . This email resulted in $13 million worth of sales in DEC products , and highlighted the potential of marketing through mass emails . However , as email marketing developed as an effective means of direct communication , users began blocking out content from emails with filters and blocking programs . In order to effectively communicate a message through email , marketers had to develop a way of pushing content through to the end user , without being cut out by automatic filters and spam removing software . This resulted in the birth of triggered marketing emails , which are sent to specific users based on their tracked online browsing patterns .   Historically , it has been difficult to measure the effectiveness of marketing campaigns because target markets can not be adequately defined . Email marketing carries the benefit of allowing marketers to identify returns on investment and measure and improve efficiency . Email marketing allows marketers to see feedback from users in real time , and to monit ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '26732',
#     '_score': 8.66811,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email_address&amp;oldid=827895690',
#      'document_title': 'Email_address',
#      'document_text_clean': "Email address - wikipedia  Email address  Jump to : navigation , search Example of an email address  An email address identifies an email box to which email messages are delivered . A wide variety of formats were used in early email systems , but only a single format is used today , following the standards developed for Internet mail systems since the 1980s . This article uses the term email address to refer to the addr - spec defined in RFC 5322 , not to the address that is commonly used ; the difference is that an address may contain a display name , a comment , or both .   An email address such as John.Smith@example.com is made up of a local - part , an @ symbol , then a case - insensitive domain . Although the standard specifies the local part to be case - sensitive , in practice the mail system at example.com may treat John. Smith as equivalent to JohnSmith or even as johnsmith , and mail systems often limit their users ' choice of name to a subset of the technically valid characters . In some cases they also limit which addresses it is possible to send mail to .   With the introduction of internationalized domain names , efforts are progressing to permit non-ASCII characters in email addresses .     Contents  ( hide )   1 Overview   2 Syntax   2.1 Local - part   2.2 Domain   2.3 Examples     3 Common local - part semantics   3.1 Local - part normalization   3.2 Subaddressing     4 Validation and verification   4.1 Identity validation     5 Internationalization   5.1 Internationalization examples   5.2 Internationalization support     6 Standards documents   7 See also   8 References   9 External links      Overview ( edit )   The transmission of electronic mail within the Internet uses the Simple Mail Transfer Protocol ( SMTP ) , defined in Internet standards RFC 5321 and RFC 5322 , and extensions like RFC 6531 . The mailboxes may be accessed and managed by users with the Post Office Protocol ( POP ) or the Internet Message Access Protocol ( IMAP ) with email client software that runs on a personal computer , mobile device , or with webmail systems that render the messages on a screen or on paper printouts .   The general format of an email address is local-part@domain , and a specific example is jsmith@example.com . An address consists of two parts . The part before the @ symbol ( local - part ) identifies the name of a mailbox . This is often the username of the recipient , e.g. , jsmith . The part after the @ symbol ( domain ) is a domain name that represents the administrative realm for the mail box , e.g. , a company 's domain name , example.com .   When delivering email , a mail server ( mail transfer agent : MTA ) uses the domain name system ( DNS ) to look up the mail exchanger record ( MX record ) for the recipient 's domain ( the part of the email address on the right of @ ) . The returned MX record contains the name of the recipient 's mailserver . The MTA next connects to this server as an SMTP client .   The local part of an email address has no significance for intermediate mail relay systems other than the final mailbox host . Email senders and intermediate relay systems must not assume it to be case - insensitive , since the final mailbox host may or may not treat it as such . A single mailbox may receive mail for multiple email addresses , if configured by the administrator . Conversely , a single email address may be the alias to a distribution list to many mailboxes . Email aliases , electronic mailing lists , sub-addressing , and catch - all addresses , the latter being mailboxes that receive messages regardless of the local part , are common patterns for achieving a variety of delivery goals .   The addresses found in the header fields of an email message are not directly used by mail exchangers to deliver the message . An email message also contains a message envelope that contains the information for mail routing . While envelope and header addresses may be equal , forg ...
#    {'_index': 'nq_wiki_data',
#     '_type': '_doc',
#     '_id': '66736',
#     '_score': 8.602217,
#     '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email_alias&amp;oldid=711886122',
#      'document_title': 'Email_alias',
#      'document_text_clean': "Email alias - wikipedia  Email alias  Jump to : navigation , search  An email alias is simply a forwarding email address . The term alias expansion is sometimes used to indicate a specific mode of email forwarding , thereby implying a more generic meaning of the term email alias as an address that is forwarded in a simplistic fashion .     Contents  ( hide )   1 Usage   2 Control issue   3 Abuse issue   4 See also   5 Notes      Usage ( edit )   Email aliases can be created on a mail server . The mail server simply forwards email messages addressed to an email alias on to another , the specified email address . An email alias may be used to create a simple replacement for a long or difficult - to - remember email address . It can also be used to create a generic email address such as webmaster@example.com and info@example.com .   On UNIX - like systems , email aliases may be placed into the file / etc / aliases and have the form :    local - alias - name : adifferentlocaluser , anotherlocaluser , an@external.user.example.com    Control issue ( edit )   Messages forwarded through an email alias retain the original SMTP envelope sender and recipient . If the message is a blind carbon copy , the recipient can only tell whether the message was forwarded through the alias by examining the message headers . However , the standard does not mandate mentioning the envelope recipient in the headers . Therefore , recipients of a message may not be able to recover what email address has been used by the sender to eventually deliver the message to their mailbox .   Recipients who can not trace what address the sender used are unable to ask the sender to stop sending , because the sender most likely will not be able to associate their current email address with the one used for sending . Even if users are able to learn the exact address used for sending , their mail client may not provide a convenient way to submit a reply using the latter as the sender address of the response . In other words , aliasing is not reversible . This is particularly relevant in opt - out situations where the sender does not provide a reliable mechanism in the body of the message . Typically , newsletters sent to undisclosed recipients can be sent submitting the body once along with a list of recipients , which is much less resource intensive than submitting a different body for each recipient . However , if VERP or BATV are being used ( e.g. to prevent email backscatter ) , the electronic mailing list software will send individual messages to each recipient with a different SMTP FROM address .   Abuse issue ( edit )   The recipient 's SMTP server sees only the forwarding system 's IP address . In general it has no reason to trust the Received : headerfield generated by the forwarding system and does not know the originating system 's IP address . Therefore , recipients can not reliably distinguish spam to the alias address from spam generated on the forwarding system . When a recipient reports a message to his ISP as spam , the ISP credits that spam to the forwarding system . ISPs with low abuse thresholds may begin blocking email from the forwarding system .   See also ( edit )    Email forwarding    Notes ( edit )    Jump up ^ RFC 5321 defines alias expansion as opposed to the list expansion of mailing lists , noting that the replacement of the address to whom bounce messages are returned makes a key difference . An email alias is different from a contact group , or distribution list . According to Microsoft , a contact group is `` a grouping of e-mail addresses collected under one name . A message sent to a contact group goes to all recipients listed in the group . ''   Retrieved from `` https://en.wikipedia.org/w/index.php?title=Email_alias&oldid=711886122 '' Categories :   Email   Hidden categories :   Pages using RFC magic links           Talk                                           Contents                   About Wikipedia  ...

# %%
res['hits']['hits'][0]
# Out:
# {'_index': 'nq_wiki_data',
#  '_type': '_doc',
#  '_id': '21875',
#  '_score': 8.69899,
#  '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email&amp;oldid=843387842',
#   'document_title': 'Email',
#   'document_text_clean': "Email - wikipedia  Email  Jump to : navigation , search This article is about the communications medium . For the former manufacturing conglomerate , see Email Limited . `` Inbox '' redirects here . For the Google product , see Inbox by Gmail . This screenshot shows the `` Inbox '' page of an email client , where users can see new emails and take actions , such as reading , deleting , saving , or responding to these messages The at sign , a part of every SMTP email address  Electronic mail ( email or e-mail ) is a method of exchanging messages ( `` mail '' ) between people using electronic devices . Email first entered limited use in the 1960s and by the mid-1970s had taken the form now recognized as email . Email operates across computer networks , which today is primarily the Internet . Some early email systems required the author and the recipient to both be online at the same time , in common with instant messaging . Today 's email systems are based on a store - and - forward model . Email servers accept , forward , deliver , and store messages . Neither the users nor their computers are required to be online simultaneously ; they need to connect only briefly , typically to a mail server or a webmail interface , for as long as it takes to send or receive messages .   Originally an ASCII text - only communications medium , Internet email was extended by Multipurpose Internet Mail Extensions ( MIME ) to carry text in other character sets and multimedia content attachments . International email , with internationalized email addresses using UTF - 8 , has been standardized , but as of 2017 it has not been widely adopted .   The history of modern Internet email services reaches back to the early ARPANET , with standards for encoding email messages published as early as 1973 ( RFC 561 ) . An email message sent in the early 1970s looks very similar to a basic email sent today . Email had an important role in creating the Internet , and the conversion from ARPANET to the Internet in the early 1980s produced the core of the current services .     Contents  ( hide )   1 Terminology   2 Origin   3 Operation   4 Message format   4.1 Message header   4.1. 1 Header fields     4.2 Message body   4.2. 1 Content encoding   4.2. 2 Plain text and HTML       5 Servers and client applications   5.1 Filename extensions   5.2 URI scheme mailto     6 Types   6.1 Web - based email   6.2 POP3 email services   6.3 IMAP email servers   6.4 MAPI email servers     7 Uses   7.1 Business and organizational use   7.1. 1 Email marketing     7.2 Personal use   7.2. 1 Personal computer   7.2. 2 Mobile   7.2. 3 Declining use among young people       8 Issues   8.1 Attachment size limitation   8.2 Information overload   8.3 Spam   8.4 Malware   8.5 Email spoofing   8.6 Email bombing   8.7 Privacy concerns   8.8 Flaming   8.9 Email bankruptcy   8.10 Internationalization   8.11 Tracking of sent mail     9 See also   10 References   11 Further reading   12 External links      Terminology ( edit )   Historically , the term electronic mail was used generically for any electronic document transmission . For example , several writers in the early 1970s used the term to describe fax document transmission . As a result , it is difficult to find the first citation for the use of the term with the more specific meaning it has today .   Electronic mail has been most commonly called email or e-mail since around 1993 , but variations of the spelling have been used :    email is the most common form used online , and is required by IETF Requests for Comments ( RFC ) and working groups and increasingly by style guides . This spelling also appears in most dictionaries .   e-mail is the format that sometimes appears in edited , published American English and British English writing as reflected in the Corpus of Contemporary American English data , but is falling out of favor in some style guides .   mail was the form used in the original protocol stand ...

# %%
res['hits']['hits'][1]
# Out:
# {'_index': 'nq_wiki_data',
#  '_type': '_doc',
#  '_id': '76097',
#  '_score': 8.698753,
#  '_source': {'document_url': 'https://en.wikipedia.org//w/index.php?title=Email&amp;oldid=849062629',
#   'document_title': 'Email',
#   'document_text_clean': "Email - wikipedia  Email  This article is about the communications medium . For the former manufacturing conglomerate , see Email Limited . `` Inbox '' redirects here . For the Google product , see Inbox by Gmail . This screenshot shows the `` Inbox '' page of an email client , where users can see new emails and take actions , such as reading , deleting , saving , or responding to these messages The at sign , a part of every SMTP email address  Electronic mail ( email or e-mail ) is a method of exchanging messages ( `` mail '' ) between people using electronic devices . Invented by Ray Tomlinson , email first entered limited use in the 1960s and by the mid-1970s had taken the form now recognized as email . Email operates across computer networks , which today is primarily the Internet . Some early email systems required the author and the recipient to both be online at the same time , in common with instant messaging . Today 's email systems are based on a store - and - forward model . Email servers accept , forward , deliver , and store messages . Neither the users nor their computers are required to be online simultaneously ; they need to connect only briefly , typically to a mail server or a webmail interface , for as long as it takes to send or receive messages .   Originally an ASCII text - only communications medium , Internet email was extended by Multipurpose Internet Mail Extensions ( MIME ) to carry text in other character sets and multimedia content attachments . International email , with internationalized email addresses using UTF - 8 , has been standardized , but as of 2017 it has not been widely adopted .   The history of modern Internet email services reaches back to the early ARPANET , with standards for encoding email messages published as early as 1973 ( RFC 561 ) . An email message sent in the early 1970s looks very similar to a basic email sent today . Email had an important role in creating the Internet , and the conversion from ARPANET to the Internet in the early 1980s produced the core of the current services .   Contents  ( hide )   1 Terminology   2 Origin   3 Operation   4 Message format   4.1 Message header   4.1. 1 Header fields     4.2 Message body   4.2. 1 Content encoding   4.2. 2 Plain text and HTML       5 Servers and client applications   5.1 Filename extensions   5.2 URI scheme mailto     6 Types   6.1 Web - based email   6.2 POP3 email services   6.3 IMAP email servers   6.4 MAPI email servers     7 Uses   7.1 Business and organizational use   7.1. 1 Email marketing     7.2 Personal use   7.2. 1 Personal computer   7.2. 2 Mobile   7.2. 3 Declining use among young people       8 Issues   8.1 Attachment size limitation   8.2 Information overload   8.3 Spam   8.4 Malware   8.5 Email spoofing   8.6 Email bombing   8.7 Privacy concerns   8.8 Flaming   8.9 Email bankruptcy   8.10 Internationalization   8.11 Tracking of sent mail     9 See also   10 References   11 Further reading   12 External links    Terminology ( edit )   Historically , the term electronic mail was used generically for any electronic document transmission . For example , several writers in the early 1970s used the term to describe fax document transmission . As a result , it is difficult to find the first citation for the use of the term with the more specific meaning it has today .   Electronic mail has been most commonly called email or e-mail since around 1993 , but variations of the spelling have been used :    email is the most common form used online , and is required by IETF Requests for Comments ( RFC ) and working groups and increasingly by style guides . This spelling also appears in most dictionaries .   e-mail is the format that sometimes appears in edited , published American English and British English writing as reflected in the Corpus of Contemporary American English data , but is falling out of favor in some style guides .   mail was the form used in the original protocol standard ,  ...

# %%
type(es)
# Out:
# elasticsearch.client.Elasticsearch

# %%
try:
    jump
except:

# %% [markdown]
# # How to handle reserved characters in input string??
